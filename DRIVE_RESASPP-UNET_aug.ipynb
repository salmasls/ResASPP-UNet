# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install albumentations opencv-python
# Out:
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (2.0.8)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.13.0.92)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.12/dist-packages (from albumentations) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from albumentations) (1.16.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from albumentations) (6.0.3)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations) (2.12.3)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations) (4.13.0.92)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (4.6.0)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (6.5.16)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.4.2)

# %%
import os
import glob
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

# %%
def preprocess_green_clahe(image):
    green = image[:, :, 1]

    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    enhanced = clahe.apply(green)

    # jadi 1 channel
    enhanced = np.expand_dims(enhanced, axis=-1)
    return enhanced

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2

train_transform = A.Compose([
    A.Resize(512, 512),
    A.HorizontalFlip(p=0.7),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.7),
    A.RandomBrightnessContrast(p=0.7),
    A.Normalize(mean=(0.5,), std=(0.5,)),  # untuk 1 channel
    ToTensorV2()
])

test_transform = A.Compose([
    A.Resize(512, 512),
    A.Normalize(mean=(0.5,), std=(0.5,)),
    ToTensorV2()
])

# %%
import cv2
import numpy as np
from torch.utils.data import Dataset
from PIL import Image

class DRIVEDataset(Dataset):
    def __init__(self, image_paths, mask_paths, transform=None):
        self.image_paths = image_paths
        self.mask_paths = mask_paths
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        # === LOAD IMAGE ===
        image = cv2.imread(self.image_paths[idx])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # === PREPROCESSING (BENAR DI SINI) ===
        image = preprocess_green_clahe(image)

        mask = Image.open(self.mask_paths[idx]).convert("L")
        mask = np.array(mask)

        # === BINARISASI MASK (WAJIB) ===
        mask = (mask > 0).astype(np.float32)

        # === AUGMENTATION ===
        if self.transform:
            augmented = self.transform(image=image, mask=mask)
            image = augmented['image']
            mask  = augmented['mask']

        if mask.ndim == 2:
            mask = mask.unsqueeze(0)

        return image, mask

# %%
# Direktori input dan output
img_dir = "/content/drive/MyDrive/Colab Notebooks/DRIVE/training/images"
mask_dir = "/content/drive/MyDrive/Colab Notebooks/DRIVE/training/1st_manual"


from glob import glob
import os

train_imgs = sorted(glob(os.path.join(img_dir, "*.tif")))
train_masks = sorted(glob(os.path.join(mask_dir, "*.gif")))

test_imgs = sorted(glob("/content/drive/MyDrive/Colab Notebooks/DRIVE/test/images/*.tif"))
test_masks = sorted(glob("/content/drive/MyDrive/Colab Notebooks/DRIVE/test/masks/*.gif"))

# %%
print("Train images:", len(train_imgs))
print("Train masks:", len(train_masks))
print("Test images:", len(test_imgs))
print("Test masks:", len(test_masks))
# Out:
# Train images: 20
# Train masks: 20
# Test images: 20
# Test masks: 20

# %%
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader

kf = KFold(n_splits=10, shuffle=True, random_state=42)

for fold, (train_idx, val_idx) in enumerate(kf.split(train_imgs)):

    train_fold_imgs = [train_imgs[i] for i in train_idx]
    train_fold_masks = [train_masks[i] for i in train_idx]

    val_fold_imgs = [train_imgs[i] for i in val_idx]
    val_fold_masks = [train_masks[i] for i in val_idx]

    train_dataset = DRIVEDataset(
        train_fold_imgs,
        train_fold_masks,
        transform=train_transform   # AUGMENTASI DI SINI
    )

    val_dataset = DRIVEDataset(
        val_fold_imgs,
        val_fold_masks,
        transform=test_transform    # TANPA AUGMENTASI
    )

    train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=4)
    val_loader   = DataLoader(val_dataset, batch_size=4, shuffle=False)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()

# %%
test_dataset = DRIVEDataset(test_imgs, test_masks, transform=test_transform)
test_loader  = DataLoader(test_dataset, batch_size=4, shuffle=False)

# %%
print(len(train_fold_imgs), len(val_fold_imgs))
# Out:
# 18 2

# %%
import matplotlib.pyplot as plt

# ambil 1 sample dari train_dataset (yang sudah diaugmentasi)
image, mask = train_dataset[0]

# ubah tensor → numpy
image = image.permute(1, 2, 0).cpu().numpy()
mask = mask.squeeze().cpu().numpy()

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(image, cmap='gray' if image.shape[2]==1 else None)
plt.title("Augmented Image")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(mask, cmap='gray')
plt.title("Mask")
plt.axis('off')

plt.show()

# %%
# === HITUNG JUMLAH DATA TRAINING & VALIDATION ===
print("========================================")
# Define all_files by combining training and test image paths
all_files = train_imgs + test_imgs
print("Jumlah total data:", len(all_files))
print("Jumlah data training :", len(train_dataset))
print("Jumlah data validation :", len(val_dataset))
print("Jumlah data test :", len(test_dataset))
print("========================================")
# Out:
# ========================================
# Jumlah total data: 40
# Jumlah data training : 18
# Jumlah data validation : 2
# Jumlah data test : 20
# ========================================

# %%
# === LOAD IMAGE ===
img = cv2.imread("/content/drive/MyDrive/Colab Notebooks/DRIVE/training/images/21_training.tif")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# === PREPROCESSING ===
preprocessed = preprocess_green_clahe(img)

if preprocessed.ndim == 2:
    preprocessed = preprocessed[..., None]

# === LOAD MASK ===
mask = cv2.imread("/content/drive/MyDrive/Colab Notebooks/DRIVE/training/1st_manual/21_manual1.gif", cv2.IMREAD_GRAYSCALE)
mask = (mask > 0).astype("float32")
mask = mask[..., None]

# === AUGMENTATION ===
augmented = train_transform(image=preprocessed, mask=mask)

aug_img = augmented["image"]
aug_mask = augmented["mask"]

# === CONVERT UNTUK VISUALISASI ===
aug_img_np = aug_img.permute(1, 2, 0).cpu().numpy()
aug_mask_np = aug_mask.squeeze().cpu().numpy()

# === PLOT ===
plt.figure(figsize=(18, 6))

plt.subplot(1, 4, 1)
plt.imshow(img)
plt.title("Original")
plt.axis("off")

plt.subplot(1, 4, 2)
plt.imshow(preprocessed.squeeze(), cmap='gray')
plt.title("Preprocessing (Green + CLAHE)")
plt.axis("off")

plt.subplot(1, 4, 3)
plt.imshow(aug_img_np.squeeze(), cmap='gray')
plt.title("Augmented Image")
plt.axis("off")

plt.subplot(1, 4, 4)
plt.imshow(aug_mask_np, cmap='gray')
plt.title("Augmented Mask")
plt.axis("off")

plt.show()

# %%
batch = next(iter(train_loader))
imgs, masks = batch

img = imgs[0]
mask = masks[0]

img_np = img.permute(1, 2, 0).cpu().numpy()
mask_np = mask.squeeze().cpu().numpy()

# undo normalize
mean = 0.5
std = 0.5
img_np = (img_np * std) + mean
img_np = np.clip(img_np, 0, 1)

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
if img_np.shape[2] == 1:
    plt.imshow(img_np.squeeze(), cmap='gray')
else:
    plt.imshow(img_np)
plt.title("Sample Image (DataLoader)")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(mask_np, cmap="gray")
plt.title("Mask")
plt.axis("off")

plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()

# %%
image, mask = train_dataset[0]
print(image.shape)
# Out:
# torch.Size([1, 512, 512])

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models

# === DeepLabV3 Encoder: ResNet Backbone ===
class DeepLabEncoder(nn.Module):
    def __init__(self):
        super().__init__()
        resnet = models.resnet50(pretrained=True)
        resnet.conv1 = nn.Conv2d(
            1, 64, kernel_size=7, stride=2, padding=3, bias=False
        )
        self.initial = nn.Sequential(
            resnet.conv1,
            resnet.bn1,
            resnet.relu,
            resnet.maxpool
        )

        self.layer1 = resnet.layer1  # 256  # CHANGED (comment)
        self.layer2 = resnet.layer2  # 512  # CHANGED (comment)
        self.layer3 = resnet.layer3  # 1024 # CHANGED (comment)
        self.layer4 = resnet.layer4  # 2048 # CHANGED (comment)

    def forward(self, x):
        x0 = self.initial(x)
        x1 = self.layer1(x0)  # 256
        x2 = self.layer2(x1)  # 512
        x3 = self.layer3(x2)  # 1024
        x4 = self.layer4(x3)  # 2048
        return x1, x2, x3, x4


# === ASPP Module ===
class ASPP(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.atrous1 = nn.Conv2d(in_channels, out_channels, 1, padding=0, dilation=1)
        self.atrous6 = nn.Conv2d(in_channels, out_channels, 3, padding=6, dilation=6)
        self.atrous12 = nn.Conv2d(in_channels, out_channels, 3, padding=12, dilation=12)
        self.atrous18 = nn.Conv2d(in_channels, out_channels, 3, padding=18, dilation=18)
        self.global_pool = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(in_channels, out_channels, 1),
            nn.ReLU()
        )
        self.conv_out = nn.Conv2d(out_channels * 5, out_channels, 1)

    def forward(self, x):
        size = x.shape[2:]
        f1 = self.atrous1(x)
        f2 = self.atrous6(x)
        f3 = self.atrous12(x)
        f4 = self.atrous18(x)
        f5 = self.global_pool(x)
        f5 = F.interpolate(f5, size=size, mode='bilinear', align_corners=False)
        x = torch.cat([f1, f2, f3, f4, f5], dim=1)
        return self.conv_out(x)


class UNetDecoder(nn.Module):
    def __init__(self):
        super().__init__()

        # Correct skip channels for ResNet50
        # bridge (ASPP) out_channels = 256
        # x4 = 2048, x3 = 1024, x2 = 512, x1 = 256
        self.up1 = self.block(256, 2048, 256)  # bridge + x4
        self.up2 = self.block(256, 1024, 128)  # up1 + x3
        self.up3 = self.block(128, 512, 64)    # up2 + x2
        self.up4 = self.block(64, 256, 32)     # up3 + x1

        self.final = nn.Conv2d(32, 1, 1)

    def block(self, in_channels, skip_channels, out_channels):
        return nn.Sequential(
            nn.Conv2d(in_channels + skip_channels, out_channels, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, 3, padding=1),
            nn.ReLU(inplace=True),
        )

    def forward(self, x, skips):
        x1, x2, x3, x4 = skips

        # === UP 1 === (bridge + x4)
        x = F.interpolate(x, scale_factor=2, mode='bilinear', align_corners=False)
        if x4.shape[2:] != x.shape[2:]:
            x4 = F.interpolate(x4, size=x.shape[2:], mode='bilinear', align_corners=False)
        x = self.up1(torch.cat([x, x4], dim=1))

        # === UP 2 === (up1 + x3)
        x = F.interpolate(x, scale_factor=2, mode='bilinear', align_corners=False)
        if x3.shape[2:] != x.shape[2:]:
            x3 = F.interpolate(x3, size=x.shape[2:], mode='bilinear', align_corners=False)
        x = self.up2(torch.cat([x, x3], dim=1))

        # === UP 3 === (up2 + x2)
        x = F.interpolate(x, scale_factor=2, mode='bilinear', align_corners=False)
        if x2.shape[2:] != x.shape[2:]:
            x2 = F.interpolate(x2, size=x.shape[2:], mode='bilinear', align_corners=False)
        x = self.up3(torch.cat([x, x2], dim=1))

        # === UP 4 === (up3 + x1)
        x = F.interpolate(x, scale_factor=2, mode='bilinear', align_corners=False)
        if x1.shape[2:] != x.shape[2:]:
            x1 = F.interpolate(x1, size=x.shape[2:], mode='bilinear', align_corners=False)
        x = self.up4(torch.cat([x, x1], dim=1))

        x = F.interpolate(x, size=(512, 512), mode='bilinear', align_corners=False)

        return self.final(x)


# === Hybrid Model ===
class ResASPP_UNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = DeepLabEncoder()
        self.aspp = ASPP(2048, 256)
        self.decoder = UNetDecoder()

    def forward(self, x):
        x1, x2, x3, x4 = self.encoder(x)
        bridge = self.aspp(x4)
        out = self.decoder(bridge, [x1, x2, x3, x4])  # CHANGED
        return out

# %%
import torch.nn as nn
import torch.nn.functional as F

class DiceLoss(nn.Module):
    def __init__(self, smooth=1e-6):
        super().__init__()
        self.smooth = smooth

    def forward(self, pred, target):
        pred = torch.sigmoid(pred)
        intersection = (pred * target).sum(dim=(2,3))
        union = pred.sum(dim=(2,3)) + target.sum(dim=(2,3))
        dice = (2 * intersection + self.smooth) / (union + self.smooth)
        return 1 - dice.mean()


class BoundaryLoss(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, pred, target):
        pred = torch.sigmoid(pred)

        sobel_x = torch.tensor([[1,0,-1],[2,0,-2],[1,0,-1]],
                               dtype=torch.float32).to(pred.device).view(1,1,3,3)
        sobel_y = sobel_x.permute(0,1,3,2)

        pred_edge = F.conv2d(pred, sobel_x, padding=1) + F.conv2d(pred, sobel_y, padding=1)
        target_edge = F.conv2d(target, sobel_x, padding=1) + F.conv2d(target, sobel_y, padding=1)

        return F.l1_loss(pred_edge, target_edge)


class TopologyLoss(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, pred, target):
        pred = torch.sigmoid(pred)
        return F.binary_cross_entropy(pred, target)


class HybridLoss(nn.Module):
    def __init__(self, w_dice=1.0, w_boundary=0.5, w_topo=0.3):
        super().__init__()
        self.dice = DiceLoss()
        self.boundary = BoundaryLoss()
        self.topo = TopologyLoss()

        self.w_dice = w_dice
        self.w_boundary = w_boundary
        self.w_topo = w_topo

    def forward(self, pred, target):
        return (
            self.w_dice * self.dice(pred, target) +
            self.w_boundary * self.boundary(pred, target) +
            self.w_topo * self.topo(pred, target)
        )

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import time # Import the time module


def dice_score(preds, targets, threshold=0.5):
    preds = (preds > threshold).float()
    intersection = (preds * targets).sum()
    return (2. * intersection) / (preds.sum() + targets.sum() + 1e-8)

def accuracy_score(preds, targets, threshold=0.5):
    preds = (preds > threshold).float()
    correct = (preds == targets).float().sum()
    total = torch.numel(targets)
    return correct / total

def train_model(model, train_loader, val_loader, epochs=30, lr=1e-4, device='cuda'):
    model.to(device)
    criterion = HybridLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)

    history = {
        "train_loss": [],
        "val_loss": [],
        "train_acc": [],
        "val_acc": [],
        "train_dice": [],
        "val_dice": []
    }

    start_time = time.time()

    for epoch in range(epochs):
        model.train()
        running_loss = 0
        running_acc = 0
        running_dice = 0

        for images, masks in train_loader:
            images, masks = images.to(device), masks.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, masks)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            running_acc  += accuracy_score(outputs, masks).item()
            running_dice += dice_score(outputs, masks).item()

        train_loss = running_loss / len(train_loader)
        train_acc  = running_acc  / len(train_loader)
        train_dice = running_dice / len(train_loader)

        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['train_dice'].append(train_dice)


        # ==========================
        # VALIDATION
        # ==========================
        model.eval()
        val_loss = 0
        total_dice = 0
        total_acc = 0

        with torch.no_grad():
            for images, masks in val_loader:
                images, masks = images.to(device), masks.to(device)
                outputs = model(images)

                loss = criterion(outputs, masks)
                val_loss += loss.item()

                total_dice += dice_score(outputs, masks).item()
                total_acc  += accuracy_score(outputs, masks).item()

        val_loss /= len(val_loader)
        val_dice = total_dice / len(val_loader)
        val_acc  = total_acc  / len(val_loader)

        history['val_loss'].append(val_loss)
        history['val_dice'].append(val_dice)
        history['val_acc'].append(val_acc)

        print(f"Epoch {epoch+1}/{epochs} | "
              f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | "
              f"Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f} | "
              f"Train Dice: {train_dice:.4f} | Val Dice: {val_dice:.4f}")


    end_time = time.time() # Record the end time
    total_training_time = end_time - start_time
    print(f"\nTotal Training Time: {total_training_time:.2f} seconds")

    return model, history

# %%
import matplotlib.pyplot as plt

def plot_history(history):
    plt.figure(figsize=(18, 5))


    # Plot Loss
    plt.subplot(1,3,1)
    plt.plot(history['train_loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Val Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Plot Accuracy
    plt.subplot(1,3,2)
    plt.plot(history['train_acc'], label='Train Accuracy')
    plt.plot(history['val_acc'], label='Val Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Dice Score
    plt.subplot(1, 3, 3)
    plt.plot(history['train_dice'], label='Train Dice', color='blue')
    plt.plot(history['val_dice'], label='Val Dice', color='orange')
    plt.title('Dice Score per Epoch')
    plt.xlabel('Epoch')
    plt.ylabel('Dice')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# %%
def plot_history(history, title_suffix=""):
    plt.figure(figsize=(18, 5))

    # Loss
    plt.subplot(1,3,1)
    plt.plot(history['train_loss'], label='Train Loss')
    if 'val_loss' in history:
        plt.plot(history['val_loss'], label='Val Loss')
    plt.title(f'Loss {title_suffix}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Accuracy
    plt.subplot(1,3,2)
    plt.plot(history['train_acc'], label='Train Acc')
    if 'val_acc' in history:
        plt.plot(history['val_acc'], label='Val Acc')
    plt.title(f'Accuracy {title_suffix}')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Dice
    plt.subplot(1,3,3)
    plt.plot(history['train_dice'], label='Train Dice')
    if 'val_dice' in history:
        plt.plot(history['val_dice'], label='Val Dice')
    plt.title(f'Dice Score {title_suffix}')
    plt.xlabel('Epoch')
    plt.ylabel('Dice')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# %%
pip install torchinfo
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.12/dist-packages (1.8.0)

# %%
def evaluate_test(model, loader, device):
    model.eval()

    total_loss = 0
    # total_dice = 0 # These are not explicitly used in the return, removed for clarity
    # total_acc  = 0 # These are not explicitly used in the return, removed for clarity

    criterion = HybridLoss()


    TP, TN, FP, FN = 0, 0, 0, 0
    dice_total, iou_total, n = 0, 0, 0

    with torch.no_grad():
        for images, masks in loader:
            images, masks = images.to(device), masks.to(device)

            outputs = model(images)
            preds = (torch.sigmoid(outputs) > 0.5).float()

            loss = criterion(outputs, masks) # Calculate loss
            total_loss += loss.item() # Accumulate loss

            TP += ((preds == 1) & (masks == 1)).sum().item()
            TN += ((preds == 0) & (masks == 0)).sum().item()
            FP += ((preds == 1) & (masks == 0)).sum().item()
            FN += ((preds == 0) & (masks == 1)).sum().item()

            intersection = (preds * masks).sum(dim=(2,3))
            union = preds.sum(dim=(2,3)) + masks.sum(dim=(2,3))

            dice = (2 * intersection + 1e-6) / (union + 1e-6)
            iou = (intersection + 1e-6) / (union - intersection + 1e-6)

            dice_total += dice.mean().item()
            iou_total += iou.mean().item()
            n += 1

    return {
        "loss": total_loss / n, # Added loss to the return dictionary
        "Accuracy": (TP + TN) / (TP + TN + FP + FN + 1e-6),
        "Sensitivity": TP / (TP + FN + 1e-6),
        "Specificity": TN / (TN + FP + 1e-6),
        "Dice": dice_total / n,
        "IoU": iou_total / n
    }

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

fold_results = []

import os

# Folder penyimpanan
save_dir = "/content/drive/MyDrive/Colab Notebooks/DRIVE/"
os.makedirs(save_dir, exist_ok=True)

for fold, (train_idx, val_idx) in enumerate(kf.split(train_imgs)):
    print(f"\n===== FOLD {fold+1} ====")

    train_fold_imgs = [train_imgs[i] for i in train_idx]
    train_fold_masks = [train_masks[i] for i in train_idx]

    val_fold_imgs = [train_imgs[i] for i in val_idx]
    val_fold_masks = [train_masks[i] for i in val_idx]

    # Dataset
    train_dataset = DRIVEDataset(train_fold_imgs, train_fold_masks, transform=train_transform)
    val_dataset   = DRIVEDataset(val_fold_imgs, val_fold_masks, transform=test_transform)

    train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=4)
    val_loader   = DataLoader(val_dataset, batch_size=4, shuffle=False, num_workers=4)

    model = ResASPP_UNet().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
    criterion = HybridLoss()

    num_epochs = 100

    #History
    history = {
        "train_loss": [],
        "val_loss": [],
        "train_dice": [],
        "val_dice": [],
        "train_acc": [],
        "val_acc": []
    }

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0
        running_dice = 0
        running_acc  = 0

        for images, masks in train_loader:
            images, masks = images.to(device), masks.to(device)

            outputs = model(images)
            preds = torch.sigmoid(outputs)

            loss = criterion(outputs, masks)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            running_dice += dice_score(preds, masks).item()
            running_acc  += accuracy_score(preds, masks).item()

        # === TRAIN METRICS ===
        train_loss = running_loss / len(train_loader)
        train_dice = running_dice / len(train_loader)
        train_acc  = running_acc  / len(train_loader)

        # === VALIDATION ===
        val_metrics = evaluate_test(model, val_loader, device)

        # === SIMPAN HISTORY ===
        history["train_loss"].append(train_loss)
        history["train_dice"].append(train_dice)
        history["train_acc"].append(train_acc)

        history["val_loss"].append(val_metrics["loss"])
        history["val_dice"].append(val_metrics["Dice"])
        history["val_acc"].append(val_metrics["Accuracy"])

        # Print train model
        print(f"Fold {fold+1} | Epoch {epoch+1}/{num_epochs} | "
              f"Train Loss: {train_loss:.4f} | Val Loss: {val_metrics['loss']:.4f} | "
              f"Train Acc: {train_acc:.4f} | Val Acc: {val_metrics['Accuracy']:.4f} | "
              f"Train Dice: {train_dice:.4f} | Val Dice: {val_metrics['Dice']:.4f}")
# Out:
# ===== FOLD 1 ====
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Fold 1 | Epoch 1/100 | Train Loss: 1.2254 | Val Loss: 1.2146 | Train Acc: 0.9133 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 2/100 | Train Loss: 1.1989 | Val Loss: 1.1608 | Train Acc: 0.9110 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 3/100 | Train Loss: 1.1291 | Val Loss: 1.3412 | Train Acc: 0.9114 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 4/100 | Train Loss: 1.0891 | Val Loss: 1.2336 | Train Acc: 0.9130 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 5/100 | Train Loss: 1.0722 | Val Loss: 1.2929 | Train Acc: 0.9114 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 6/100 | Train Loss: 1.0519 | Val Loss: 1.2367 | Train Acc: 0.9145 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 7/100 | Train Loss: 1.0424 | Val Loss: 1.0962 | Train Acc: 0.9132 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 8/100 | Train Loss: 1.0255 | Val Loss: 1.1163 | Train Acc: 0.9137 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 9/100 | Train Loss: 1.0052 | Val Loss: 1.0320 | Train Acc: 0.9124 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 10/100 | Train Loss: 0.9832 | Val Loss: 0.9913 | Train Acc: 0.9115 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 11/100 | Train Loss: 0.9497 | Val Loss: 0.9574 | Train Acc: 0.9118 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 12/100 | Train Loss: 0.9273 | Val Loss: 0.9309 | Train Acc: 0.9125 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 13/100 | Train Loss: 0.8994 | Val Loss: 0.8919 | Train Acc: 0.9118 | Val Acc: 0.9195 | Train Dice: 0.0002 | Val Dice: 0.0009
# Fold 1 | Epoch 14/100 | Train Loss: 0.8801 | Val Loss: 0.8534 | Train Acc: 0.9181 | Val Acc: 0.9323 | Train Dice: 0.1227 | Val Dice: 0.3128
# Fold 1 | Epoch 15/100 | Train Loss: 0.8556 | Val Loss: 0.8202 | Train Acc: 0.9336 | Val Acc: 0.9408 | Train Dice: 0.4550 | Val Dice: 0.4870
# Fold 1 | Epoch 16/100 | Train Loss: 0.8299 | Val Loss: 0.7913 | Train Acc: 0.9408 | Val Acc: 0.9459 | Train Dice: 0.5738 | Val Dice: 0.5746
# Fold 1 | Epoch 17/100 | Train Loss: 0.8015 | Val Loss: 0.7564 | Train Acc: 0.9415 | Val Acc: 0.9484 | Train Dice: 0.6058 | Val Dice: 0.6705
# Fold 1 | Epoch 18/100 | Train Loss: 0.7674 | Val Loss: 0.7159 | Train Acc: 0.9425 | Val Acc: 0.9455 | Train Dice: 0.6337 | Val Dice: 0.6760
# Fold 1 | Epoch 19/100 | Train Loss: 0.7226 | Val Loss: 0.6596 | Train Acc: 0.9411 | Val Acc: 0.9489 | Train Dice: 0.6596 | Val Dice: 0.6744
# Fold 1 | Epoch 20/100 | Train Loss: 0.6723 | Val Loss: 0.6231 | Train Acc: 0.9424 | Val Acc: 0.9466 | Train Dice: 0.6699 | Val Dice: 0.6765
# Fold 1 | Epoch 21/100 | Train Loss: 0.6422 | Val Loss: 0.6152 | Train Acc: 0.9419 | Val Acc: 0.9417 | Train Dice: 0.6687 | Val Dice: 0.6745
# Fold 1 | Epoch 22/100 | Train Loss: 0.6244 | Val Loss: 0.5896 | Train Acc: 0.9415 | Val Acc: 0.9508 | Train Dice: 0.6715 | Val Dice: 0.6825
# Fold 1 | Epoch 23/100 | Train Loss: 0.6133 | Val Loss: 0.6004 | Train Acc: 0.9442 | Val Acc: 0.9520 | Train Dice: 0.6767 | Val Dice: 0.6644
# Fold 1 | Epoch 24/100 | Train Loss: 0.6125 | Val Loss: 0.5742 | Train Acc: 0.9424 | Val Acc: 0.9499 | Train Dice: 0.6771 | Val Dice: 0.6927
# Fold 1 | Epoch 25/100 | Train Loss: 0.5969 | Val Loss: 0.5921 | Train Acc: 0.9482 | Val Acc: 0.9422 | Train Dice: 0.6859 | Val Dice: 0.6840
# Fold 1 | Epoch 26/100 | Train Loss: 0.5867 | Val Loss: 0.5729 | Train Acc: 0.9489 | Val Acc: 0.9471 | Train Dice: 0.6947 | Val Dice: 0.6961
# Fold 1 | Epoch 27/100 | Train Loss: 0.5760 | Val Loss: 0.5563 | Train Acc: 0.9485 | Val Acc: 0.9541 | Train Dice: 0.7052 | Val Dice: 0.7007
# Fold 1 | Epoch 28/100 | Train Loss: 0.5780 | Val Loss: 0.5502 | Train Acc: 0.9475 | Val Acc: 0.9524 | Train Dice: 0.7001 | Val Dice: 0.7062
# Fold 1 | Epoch 29/100 | Train Loss: 0.5630 | Val Loss: 0.5723 | Train Acc: 0.9504 | Val Acc: 0.9443 | Train Dice: 0.7081 | Val Dice: 0.6966
# Fold 1 | Epoch 30/100 | Train Loss: 0.5599 | Val Loss: 0.5393 | Train Acc: 0.9501 | Val Acc: 0.9522 | Train Dice: 0.7109 | Val Dice: 0.7118
# Fold 1 | Epoch 31/100 | Train Loss: 0.5545 | Val Loss: 0.5365 | Train Acc: 0.9497 | Val Acc: 0.9563 | Train Dice: 0.7151 | Val Dice: 0.7085
# Fold 1 | Epoch 32/100 | Train Loss: 0.5516 | Val Loss: 0.5321 | Train Acc: 0.9518 | Val Acc: 0.9522 | Train Dice: 0.7141 | Val Dice: 0.7181
# Fold 1 | Epoch 33/100 | Train Loss: 0.5638 | Val Loss: 0.5495 | Train Acc: 0.9507 | Val Acc: 0.9469 | Train Dice: 0.7057 | Val Dice: 0.7081
# Fold 1 | Epoch 34/100 | Train Loss: 0.5473 | Val Loss: 0.5308 | Train Acc: 0.9497 | Val Acc: 0.9569 | Train Dice: 0.7178 | Val Dice: 0.7100
# Fold 1 | Epoch 35/100 | Train Loss: 0.5571 | Val Loss: 0.5325 | Train Acc: 0.9490 | Val Acc: 0.9511 | Train Dice: 0.7095 | Val Dice: 0.7161
# Fold 1 | Epoch 36/100 | Train Loss: 0.5398 | Val Loss: 0.5233 | Train Acc: 0.9535 | Val Acc: 0.9528 | Train Dice: 0.7183 | Val Dice: 0.7222
# Fold 1 | Epoch 37/100 | Train Loss: 0.5339 | Val Loss: 0.5151 | Train Acc: 0.9533 | Val Acc: 0.9541 | Train Dice: 0.7259 | Val Dice: 0.7271
# Fold 1 | Epoch 38/100 | Train Loss: 0.5270 | Val Loss: 0.5127 | Train Acc: 0.9533 | Val Acc: 0.9559 | Train Dice: 0.7286 | Val Dice: 0.7258
# Fold 1 | Epoch 39/100 | Train Loss: 0.5245 | Val Loss: 0.5198 | Train Acc: 0.9540 | Val Acc: 0.9529 | Train Dice: 0.7286 | Val Dice: 0.7244
# Fold 1 | Epoch 40/100 | Train Loss: 0.5242 | Val Loss: 0.5077 | Train Acc: 0.9536 | Val Acc: 0.9555 | Train Dice: 0.7284 | Val Dice: 0.7283
# Fold 1 | Epoch 41/100 | Train Loss: 0.5208 | Val Loss: 0.5076 | Train Acc: 0.9528 | Val Acc: 0.9567 | Train Dice: 0.7327 | Val Dice: 0.7267
# Fold 1 | Epoch 42/100 | Train Loss: 0.5251 | Val Loss: 0.5098 | Train Acc: 0.9536 | Val Acc: 0.9550 | Train Dice: 0.7279 | Val Dice: 0.7291
# Fold 1 | Epoch 43/100 | Train Loss: 0.5108 | Val Loss: 0.5010 | Train Acc: 0.9561 | Val Acc: 0.9566 | Train Dice: 0.7358 | Val Dice: 0.7358
# Fold 1 | Epoch 44/100 | Train Loss: 0.5139 | Val Loss: 0.5061 | Train Acc: 0.9555 | Val Acc: 0.9546 | Train Dice: 0.7367 | Val Dice: 0.7334
# Fold 1 | Epoch 45/100 | Train Loss: 0.5199 | Val Loss: 0.5001 | Train Acc: 0.9534 | Val Acc: 0.9572 | Train Dice: 0.7353 | Val Dice: 0.7299
# Fold 1 | Epoch 46/100 | Train Loss: 0.5255 | Val Loss: 0.4945 | Train Acc: 0.9529 | Val Acc: 0.9571 | Train Dice: 0.7288 | Val Dice: 0.7362
# Fold 1 | Epoch 47/100 | Train Loss: 0.5114 | Val Loss: 0.4952 | Train Acc: 0.9553 | Val Acc: 0.9565 | Train Dice: 0.7384 | Val Dice: 0.7378
# Fold 1 | Epoch 48/100 | Train Loss: 0.5037 | Val Loss: 0.5007 | Train Acc: 0.9558 | Val Acc: 0.9581 | Train Dice: 0.7405 | Val Dice: 0.7280
# Fold 1 | Epoch 49/100 | Train Loss: 0.5064 | Val Loss: 0.4985 | Train Acc: 0.9560 | Val Acc: 0.9579 | Train Dice: 0.7369 | Val Dice: 0.7289
# Fold 1 | Epoch 50/100 | Train Loss: 0.5133 | Val Loss: 0.4950 | Train Acc: 0.9543 | Val Acc: 0.9557 | Train Dice: 0.7347 | Val Dice: 0.7365
# Fold 1 | Epoch 51/100 | Train Loss: 0.5108 | Val Loss: 0.4984 | Train Acc: 0.9554 | Val Acc: 0.9550 | Train Dice: 0.7366 | Val Dice: 0.7363
# Fold 1 | Epoch 52/100 | Train Loss: 0.4967 | Val Loss: 0.4905 | Train Acc: 0.9564 | Val Acc: 0.9576 | Train Dice: 0.7457 | Val Dice: 0.7371
# Fold 1 | Epoch 53/100 | Train Loss: 0.5008 | Val Loss: 0.5137 | Train Acc: 0.9564 | Val Acc: 0.9518 | Train Dice: 0.7435 | Val Dice: 0.7292
# Fold 1 | Epoch 54/100 | Train Loss: 0.5023 | Val Loss: 0.4925 | Train Acc: 0.9556 | Val Acc: 0.9565 | Train Dice: 0.7437 | Val Dice: 0.7379
# Fold 1 | Epoch 55/100 | Train Loss: 0.4986 | Val Loss: 0.4880 | Train Acc: 0.9556 | Val Acc: 0.9582 | Train Dice: 0.7467 | Val Dice: 0.7395
# Fold 1 | Epoch 56/100 | Train Loss: 0.4861 | Val Loss: 0.4940 | Train Acc: 0.9577 | Val Acc: 0.9578 | Train Dice: 0.7511 | Val Dice: 0.7328
# Fold 1 | Epoch 57/100 | Train Loss: 0.4974 | Val Loss: 0.4895 | Train Acc: 0.9566 | Val Acc: 0.9573 | Train Dice: 0.7435 | Val Dice: 0.7390
# Fold 1 | Epoch 58/100 | Train Loss: 0.4902 | Val Loss: 0.4939 | Train Acc: 0.9576 | Val Acc: 0.9554 | Train Dice: 0.7489 | Val Dice: 0.7394
# Fold 1 | Epoch 59/100 | Train Loss: 0.4870 | Val Loss: 0.4956 | Train Acc: 0.9579 | Val Acc: 0.9553 | Train Dice: 0.7509 | Val Dice: 0.7372
# Fold 1 | Epoch 60/100 | Train Loss: 0.4902 | Val Loss: 0.4918 | Train Acc: 0.9570 | Val Acc: 0.9565 | Train Dice: 0.7518 | Val Dice: 0.7388
# Fold 1 | Epoch 61/100 | Train Loss: 0.4863 | Val Loss: 0.4901 | Train Acc: 0.9575 | Val Acc: 0.9560 | Train Dice: 0.7513 | Val Dice: 0.7410
# Fold 1 | Epoch 62/100 | Train Loss: 0.4867 | Val Loss: 0.4868 | Train Acc: 0.9573 | Val Acc: 0.9589 | Train Dice: 0.7521 | Val Dice: 0.7365
# Fold 1 | Epoch 63/100 | Train Loss: 0.4915 | Val Loss: 0.4857 | Train Acc: 0.9566 | Val Acc: 0.9591 | Train Dice: 0.7490 | Val Dice: 0.7383
# Fold 1 | Epoch 64/100 | Train Loss: 0.4879 | Val Loss: 0.4988 | Train Acc: 0.9580 | Val Acc: 0.9541 | Train Dice: 0.7498 | Val Dice: 0.7386
# Fold 1 | Epoch 65/100 | Train Loss: 0.4852 | Val Loss: 0.4860 | Train Acc: 0.9575 | Val Acc: 0.9595 | Train Dice: 0.7527 | Val Dice: 0.7378
# Fold 1 | Epoch 66/100 | Train Loss: 0.4913 | Val Loss: 0.4861 | Train Acc: 0.9566 | Val Acc: 0.9567 | Train Dice: 0.7502 | Val Dice: 0.7426
# Fold 1 | Epoch 67/100 | Train Loss: 0.4784 | Val Loss: 0.5100 | Train Acc: 0.9594 | Val Acc: 0.9515 | Train Dice: 0.7561 | Val Dice: 0.7320
# Fold 1 | Epoch 68/100 | Train Loss: 0.4882 | Val Loss: 0.4809 | Train Acc: 0.9569 | Val Acc: 0.9591 | Train Dice: 0.7525 | Val Dice: 0.7411
# Fold 1 | Epoch 69/100 | Train Loss: 0.4746 | Val Loss: 0.4854 | Train Acc: 0.9592 | Val Acc: 0.9569 | Train Dice: 0.7596 | Val Dice: 0.7430
# Fold 1 | Epoch 70/100 | Train Loss: 0.4824 | Val Loss: 0.4780 | Train Acc: 0.9583 | Val Acc: 0.9588 | Train Dice: 0.7539 | Val Dice: 0.7440
# Fold 1 | Epoch 71/100 | Train Loss: 0.4745 | Val Loss: 0.4792 | Train Acc: 0.9580 | Val Acc: 0.9598 | Train Dice: 0.7593 | Val Dice: 0.7405
# Fold 1 | Epoch 72/100 | Train Loss: 0.4777 | Val Loss: 0.4891 | Train Acc: 0.9588 | Val Acc: 0.9555 | Train Dice: 0.7573 | Val Dice: 0.7428
# Fold 1 | Epoch 73/100 | Train Loss: 0.4792 | Val Loss: 0.4756 | Train Acc: 0.9588 | Val Acc: 0.9585 | Train Dice: 0.7551 | Val Dice: 0.7482
# Fold 1 | Epoch 74/100 | Train Loss: 0.4779 | Val Loss: 0.4686 | Train Acc: 0.9576 | Val Acc: 0.9596 | Train Dice: 0.7603 | Val Dice: 0.7507
# Fold 1 | Epoch 75/100 | Train Loss: 0.4679 | Val Loss: 0.4790 | Train Acc: 0.9598 | Val Acc: 0.9576 | Train Dice: 0.7620 | Val Dice: 0.7463
# Fold 1 | Epoch 76/100 | Train Loss: 0.4692 | Val Loss: 0.4789 | Train Acc: 0.9594 | Val Acc: 0.9579 | Train Dice: 0.7637 | Val Dice: 0.7460
# Fold 1 | Epoch 77/100 | Train Loss: 0.4717 | Val Loss: 0.4742 | Train Acc: 0.9589 | Val Acc: 0.9586 | Train Dice: 0.7604 | Val Dice: 0.7468
# Fold 1 | Epoch 78/100 | Train Loss: 0.4666 | Val Loss: 0.4747 | Train Acc: 0.9597 | Val Acc: 0.9589 | Train Dice: 0.7617 | Val Dice: 0.7460
# Fold 1 | Epoch 79/100 | Train Loss: 0.4626 | Val Loss: 0.4868 | Train Acc: 0.9595 | Val Acc: 0.9592 | Train Dice: 0.7654 | Val Dice: 0.7349
# Fold 1 | Epoch 80/100 | Train Loss: 0.4668 | Val Loss: 0.4717 | Train Acc: 0.9598 | Val Acc: 0.9592 | Train Dice: 0.7618 | Val Dice: 0.7476
# Fold 1 | Epoch 81/100 | Train Loss: 0.4686 | Val Loss: 0.4847 | Train Acc: 0.9599 | Val Acc: 0.9554 | Train Dice: 0.7619 | Val Dice: 0.7456
# Fold 1 | Epoch 82/100 | Train Loss: 0.4759 | Val Loss: 0.4709 | Train Acc: 0.9585 | Val Acc: 0.9597 | Train Dice: 0.7592 | Val Dice: 0.7479
# Fold 1 | Epoch 83/100 | Train Loss: 0.4619 | Val Loss: 0.4670 | Train Acc: 0.9599 | Val Acc: 0.9594 | Train Dice: 0.7654 | Val Dice: 0.7525
# Fold 1 | Epoch 84/100 | Train Loss: 0.4603 | Val Loss: 0.4792 | Train Acc: 0.9610 | Val Acc: 0.9564 | Train Dice: 0.7666 | Val Dice: 0.7486
# Fold 1 | Epoch 85/100 | Train Loss: 0.4657 | Val Loss: 0.4777 | Train Acc: 0.9601 | Val Acc: 0.9571 | Train Dice: 0.7628 | Val Dice: 0.7487
# Fold 1 | Epoch 86/100 | Train Loss: 0.4628 | Val Loss: 0.4916 | Train Acc: 0.9590 | Val Acc: 0.9603 | Train Dice: 0.7662 | Val Dice: 0.7254
# Fold 1 | Epoch 87/100 | Train Loss: 0.4703 | Val Loss: 0.4784 | Train Acc: 0.9593 | Val Acc: 0.9563 | Train Dice: 0.7601 | Val Dice: 0.7489
# Fold 1 | Epoch 88/100 | Train Loss: 0.4650 | Val Loss: 0.4646 | Train Acc: 0.9599 | Val Acc: 0.9595 | Train Dice: 0.7655 | Val Dice: 0.7542
# Fold 1 | Epoch 89/100 | Train Loss: 0.4627 | Val Loss: 0.4697 | Train Acc: 0.9595 | Val Acc: 0.9603 | Train Dice: 0.7657 | Val Dice: 0.7469
# Fold 1 | Epoch 90/100 | Train Loss: 0.4552 | Val Loss: 0.4759 | Train Acc: 0.9612 | Val Acc: 0.9585 | Train Dice: 0.7697 | Val Dice: 0.7479
# Fold 1 | Epoch 91/100 | Train Loss: 0.4596 | Val Loss: 0.4691 | Train Acc: 0.9604 | Val Acc: 0.9588 | Train Dice: 0.7664 | Val Dice: 0.7522
# Fold 1 | Epoch 92/100 | Train Loss: 0.4636 | Val Loss: 0.4588 | Train Acc: 0.9596 | Val Acc: 0.9605 | Train Dice: 0.7681 | Val Dice: 0.7565
# Fold 1 | Epoch 93/100 | Train Loss: 0.4584 | Val Loss: 0.4633 | Train Acc: 0.9600 | Val Acc: 0.9603 | Train Dice: 0.7702 | Val Dice: 0.7521
# Fold 1 | Epoch 94/100 | Train Loss: 0.4534 | Val Loss: 0.4619 | Train Acc: 0.9607 | Val Acc: 0.9605 | Train Dice: 0.7697 | Val Dice: 0.7539
# Fold 1 | Epoch 95/100 | Train Loss: 0.4497 | Val Loss: 0.4646 | Train Acc: 0.9613 | Val Acc: 0.9598 | Train Dice: 0.7728 | Val Dice: 0.7526
# Fold 1 | Epoch 96/100 | Train Loss: 0.4491 | Val Loss: 0.4834 | Train Acc: 0.9616 | Val Acc: 0.9552 | Train Dice: 0.7723 | Val Dice: 0.7474
# Fold 1 | Epoch 97/100 | Train Loss: 0.4605 | Val Loss: 0.4609 | Train Acc: 0.9598 | Val Acc: 0.9601 | Train Dice: 0.7687 | Val Dice: 0.7543
# Fold 1 | Epoch 98/100 | Train Loss: 0.4522 | Val Loss: 0.4670 | Train Acc: 0.9610 | Val Acc: 0.9588 | Train Dice: 0.7710 | Val Dice: 0.7521
# Fold 1 | Epoch 99/100 | Train Loss: 0.4451 | Val Loss: 0.4716 | Train Acc: 0.9620 | Val Acc: 0.9581 | Train Dice: 0.7753 | Val Dice: 0.7514
# Fold 1 | Epoch 100/100 | Train Loss: 0.4495 | Val Loss: 0.4639 | Train Acc: 0.9611 | Val Acc: 0.9602 | Train Dice: 0.7735 | Val Dice: 0.7511
#
# ===== FOLD 2 ====
# Fold 2 | Epoch 1/100 | Train Loss: 1.2275 | Val Loss: 1.2327 | Train Acc: 0.9150 | Val Acc: 0.9005 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 2 | Epoch 2/100 | Train Loss: 1.1933 | Val Loss: 1.2014 | Train Acc: 0.9151 | Val Acc: 0.9005 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 2 | Epoch 3/100 | Train Loss: 1.1242 | Val Loss: 1.3206 | Train Acc: 0.9139 | Val Acc: 0.9005 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 2 | Epoch 4/100 | Train Loss: 1.0826 | Val Loss: 1.1619 | Train Acc: 0.9149 | Val Acc: 0.9005 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 2 | Epoch 5/100 | Train Loss: 1.0594 | Val Loss: 1.1412 | Train Acc: 0.9155 | Val Acc: 0.9005 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 2 | Epoch 6/100 | Train Loss: 1.0470 | Val Loss: 1.1062 | Train Acc: 0.9146 | Val Acc: 0.9005 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 2 | Epoch 7/100 | Train Loss: 1.0287 | Val Loss: 1.0853 | Train Acc: 0.9146 | Val Acc: 0.9005 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 2 | Epoch 8/100 | Train Loss: 1.0167 | Val Loss: 1.0599 | Train Acc: 0.9134 | Val Acc: 0.9005 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 2 | Epoch 9/100 | Train Loss: 0.9940 | Val Loss: 1.0248 | Train Acc: 0.9160 | Val Acc: 0.9005 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 2 | Epoch 10/100 | Train Loss: 0.9671 | Val Loss: 0.9920 | Train Acc: 0.9214 | Val Acc: 0.9065 | Train Dice: 0.1661 | Val Dice: 0.1381
# Fold 2 | Epoch 11/100 | Train Loss: 0.9455 | Val Loss: 0.9574 | Train Acc: 0.9299 | Val Acc: 0.9205 | Train Dice: 0.4408 | Val Dice: 0.4050
# Fold 2 | Epoch 12/100 | Train Loss: 0.9064 | Val Loss: 0.9202 | Train Acc: 0.9303 | Val Acc: 0.9263 | Train Dice: 0.4906 | Val Dice: 0.5203
# Fold 2 | Epoch 13/100 | Train Loss: 0.8654 | Val Loss: 0.8751 | Train Acc: 0.9320 | Val Acc: 0.9262 | Train Dice: 0.5399 | Val Dice: 0.5795
# Fold 2 | Epoch 14/100 | Train Loss: 0.8237 | Val Loss: 0.8368 | Train Acc: 0.9312 | Val Acc: 0.9155 | Train Dice: 0.5597 | Val Dice: 0.6009
# Fold 2 | Epoch 15/100 | Train Loss: 0.7890 | Val Loss: 0.7915 | Train Acc: 0.9277 | Val Acc: 0.9145 | Train Dice: 0.5733 | Val Dice: 0.6026
# Fold 2 | Epoch 16/100 | Train Loss: 0.7413 | Val Loss: 0.7533 | Train Acc: 0.9290 | Val Acc: 0.9245 | Train Dice: 0.5916 | Val Dice: 0.6141
# Fold 2 | Epoch 17/100 | Train Loss: 0.7049 | Val Loss: 0.7399 | Train Acc: 0.9350 | Val Acc: 0.9290 | Train Dice: 0.6179 | Val Dice: 0.6105
# Fold 2 | Epoch 18/100 | Train Loss: 0.6894 | Val Loss: 0.7169 | Train Acc: 0.9371 | Val Acc: 0.9287 | Train Dice: 0.6245 | Val Dice: 0.6310
# Fold 2 | Epoch 19/100 | Train Loss: 0.6809 | Val Loss: 0.7324 | Train Acc: 0.9350 | Val Acc: 0.9331 | Train Dice: 0.6300 | Val Dice: 0.6032
# Fold 2 | Epoch 20/100 | Train Loss: 0.6679 | Val Loss: 0.6923 | Train Acc: 0.9390 | Val Acc: 0.9325 | Train Dice: 0.6402 | Val Dice: 0.6486
# Fold 2 | Epoch 21/100 | Train Loss: 0.6513 | Val Loss: 0.6821 | Train Acc: 0.9413 | Val Acc: 0.9323 | Train Dice: 0.6500 | Val Dice: 0.6595
# Fold 2 | Epoch 22/100 | Train Loss: 0.6349 | Val Loss: 0.6638 | Train Acc: 0.9439 | Val Acc: 0.9354 | Train Dice: 0.6623 | Val Dice: 0.6698
# Fold 2 | Epoch 23/100 | Train Loss: 0.6329 | Val Loss: 0.6822 | Train Acc: 0.9427 | Val Acc: 0.9387 | Train Dice: 0.6661 | Val Dice: 0.6440
# Fold 2 | Epoch 24/100 | Train Loss: 0.6203 | Val Loss: 0.6746 | Train Acc: 0.9429 | Val Acc: 0.9400 | Train Dice: 0.6741 | Val Dice: 0.6499
# Fold 2 | Epoch 25/100 | Train Loss: 0.6185 | Val Loss: 0.6495 | Train Acc: 0.9448 | Val Acc: 0.9355 | Train Dice: 0.6697 | Val Dice: 0.6790
# Fold 2 | Epoch 26/100 | Train Loss: 0.6130 | Val Loss: 0.6412 | Train Acc: 0.9469 | Val Acc: 0.9382 | Train Dice: 0.6731 | Val Dice: 0.6849
# Fold 2 | Epoch 27/100 | Train Loss: 0.5940 | Val Loss: 0.6376 | Train Acc: 0.9463 | Val Acc: 0.9426 | Train Dice: 0.6921 | Val Dice: 0.6797
# Fold 2 | Epoch 28/100 | Train Loss: 0.5880 | Val Loss: 0.6293 | Train Acc: 0.9484 | Val Acc: 0.9392 | Train Dice: 0.6913 | Val Dice: 0.6892
# Fold 2 | Epoch 29/100 | Train Loss: 0.5822 | Val Loss: 0.6325 | Train Acc: 0.9489 | Val Acc: 0.9429 | Train Dice: 0.6922 | Val Dice: 0.6838
# Fold 2 | Epoch 30/100 | Train Loss: 0.5750 | Val Loss: 0.6406 | Train Acc: 0.9481 | Val Acc: 0.9444 | Train Dice: 0.6995 | Val Dice: 0.6728
# Fold 2 | Epoch 31/100 | Train Loss: 0.5798 | Val Loss: 0.6030 | Train Acc: 0.9482 | Val Acc: 0.9435 | Train Dice: 0.6947 | Val Dice: 0.7070
# Fold 2 | Epoch 32/100 | Train Loss: 0.5674 | Val Loss: 0.6064 | Train Acc: 0.9512 | Val Acc: 0.9455 | Train Dice: 0.7022 | Val Dice: 0.7022
# Fold 2 | Epoch 33/100 | Train Loss: 0.5599 | Val Loss: 0.6084 | Train Acc: 0.9508 | Val Acc: 0.9447 | Train Dice: 0.7077 | Val Dice: 0.7014
# Fold 2 | Epoch 34/100 | Train Loss: 0.5600 | Val Loss: 0.5990 | Train Acc: 0.9507 | Val Acc: 0.9451 | Train Dice: 0.7077 | Val Dice: 0.7070
# Fold 2 | Epoch 35/100 | Train Loss: 0.5526 | Val Loss: 0.6016 | Train Acc: 0.9516 | Val Acc: 0.9464 | Train Dice: 0.7105 | Val Dice: 0.6999
# Fold 2 | Epoch 36/100 | Train Loss: 0.5478 | Val Loss: 0.6010 | Train Acc: 0.9518 | Val Acc: 0.9460 | Train Dice: 0.7129 | Val Dice: 0.6985
# Fold 2 | Epoch 37/100 | Train Loss: 0.5489 | Val Loss: 0.5894 | Train Acc: 0.9521 | Val Acc: 0.9467 | Train Dice: 0.7114 | Val Dice: 0.7099
# Fold 2 | Epoch 38/100 | Train Loss: 0.5412 | Val Loss: 0.5830 | Train Acc: 0.9531 | Val Acc: 0.9438 | Train Dice: 0.7198 | Val Dice: 0.7179
# Fold 2 | Epoch 39/100 | Train Loss: 0.5469 | Val Loss: 0.6398 | Train Acc: 0.9512 | Val Acc: 0.9458 | Train Dice: 0.7140 | Val Dice: 0.6657
# Fold 2 | Epoch 40/100 | Train Loss: 0.5502 | Val Loss: 0.5820 | Train Acc: 0.9506 | Val Acc: 0.9480 | Train Dice: 0.7139 | Val Dice: 0.7180
# Fold 2 | Epoch 41/100 | Train Loss: 0.5419 | Val Loss: 0.5767 | Train Acc: 0.9536 | Val Acc: 0.9469 | Train Dice: 0.7170 | Val Dice: 0.7215
# Fold 2 | Epoch 42/100 | Train Loss: 0.5284 | Val Loss: 0.5965 | Train Acc: 0.9542 | Val Acc: 0.9487 | Train Dice: 0.7265 | Val Dice: 0.7032
# Fold 2 | Epoch 43/100 | Train Loss: 0.5274 | Val Loss: 0.5749 | Train Acc: 0.9543 | Val Acc: 0.9480 | Train Dice: 0.7255 | Val Dice: 0.7192
# Fold 2 | Epoch 44/100 | Train Loss: 0.5239 | Val Loss: 0.5739 | Train Acc: 0.9551 | Val Acc: 0.9466 | Train Dice: 0.7272 | Val Dice: 0.7202
# Fold 2 | Epoch 45/100 | Train Loss: 0.5377 | Val Loss: 0.5771 | Train Acc: 0.9527 | Val Acc: 0.9492 | Train Dice: 0.7203 | Val Dice: 0.7155
# Fold 2 | Epoch 46/100 | Train Loss: 0.5229 | Val Loss: 0.5821 | Train Acc: 0.9541 | Val Acc: 0.9494 | Train Dice: 0.7282 | Val Dice: 0.7117
# Fold 2 | Epoch 47/100 | Train Loss: 0.5249 | Val Loss: 0.5646 | Train Acc: 0.9539 | Val Acc: 0.9484 | Train Dice: 0.7250 | Val Dice: 0.7252
# Fold 2 | Epoch 48/100 | Train Loss: 0.5159 | Val Loss: 0.5579 | Train Acc: 0.9563 | Val Acc: 0.9491 | Train Dice: 0.7320 | Val Dice: 0.7299
# Fold 2 | Epoch 49/100 | Train Loss: 0.5106 | Val Loss: 0.5658 | Train Acc: 0.9554 | Val Acc: 0.9489 | Train Dice: 0.7346 | Val Dice: 0.7232
# Fold 2 | Epoch 50/100 | Train Loss: 0.5175 | Val Loss: 0.5625 | Train Acc: 0.9548 | Val Acc: 0.9490 | Train Dice: 0.7325 | Val Dice: 0.7254
# Fold 2 | Epoch 51/100 | Train Loss: 0.5034 | Val Loss: 0.5706 | Train Acc: 0.9568 | Val Acc: 0.9499 | Train Dice: 0.7401 | Val Dice: 0.7164
# Fold 2 | Epoch 52/100 | Train Loss: 0.5106 | Val Loss: 0.5741 | Train Acc: 0.9555 | Val Acc: 0.9495 | Train Dice: 0.7352 | Val Dice: 0.7136
# Fold 2 | Epoch 53/100 | Train Loss: 0.5187 | Val Loss: 0.5577 | Train Acc: 0.9551 | Val Acc: 0.9472 | Train Dice: 0.7344 | Val Dice: 0.7305
# Fold 2 | Epoch 54/100 | Train Loss: 0.5143 | Val Loss: 0.5564 | Train Acc: 0.9555 | Val Acc: 0.9488 | Train Dice: 0.7360 | Val Dice: 0.7287
# Fold 2 | Epoch 55/100 | Train Loss: 0.5126 | Val Loss: 0.5792 | Train Acc: 0.9545 | Val Acc: 0.9503 | Train Dice: 0.7349 | Val Dice: 0.7082
# Fold 2 | Epoch 56/100 | Train Loss: 0.5134 | Val Loss: 0.5665 | Train Acc: 0.9556 | Val Acc: 0.9441 | Train Dice: 0.7390 | Val Dice: 0.7279
# Fold 2 | Epoch 57/100 | Train Loss: 0.5009 | Val Loss: 0.5798 | Train Acc: 0.9564 | Val Acc: 0.9495 | Train Dice: 0.7405 | Val Dice: 0.7089
# Fold 2 | Epoch 58/100 | Train Loss: 0.5013 | Val Loss: 0.5435 | Train Acc: 0.9566 | Val Acc: 0.9499 | Train Dice: 0.7406 | Val Dice: 0.7389
# Fold 2 | Epoch 59/100 | Train Loss: 0.4991 | Val Loss: 0.5743 | Train Acc: 0.9568 | Val Acc: 0.9501 | Train Dice: 0.7405 | Val Dice: 0.7120
# Fold 2 | Epoch 60/100 | Train Loss: 0.5007 | Val Loss: 0.5608 | Train Acc: 0.9565 | Val Acc: 0.9502 | Train Dice: 0.7427 | Val Dice: 0.7233
# Fold 2 | Epoch 61/100 | Train Loss: 0.5026 | Val Loss: 0.5528 | Train Acc: 0.9571 | Val Acc: 0.9505 | Train Dice: 0.7383 | Val Dice: 0.7293
# Fold 2 | Epoch 62/100 | Train Loss: 0.5064 | Val Loss: 0.5545 | Train Acc: 0.9572 | Val Acc: 0.9496 | Train Dice: 0.7349 | Val Dice: 0.7296
# Fold 2 | Epoch 63/100 | Train Loss: 0.5097 | Val Loss: 0.5576 | Train Acc: 0.9547 | Val Acc: 0.9508 | Train Dice: 0.7363 | Val Dice: 0.7252
# Fold 2 | Epoch 64/100 | Train Loss: 0.5008 | Val Loss: 0.5481 | Train Acc: 0.9566 | Val Acc: 0.9509 | Train Dice: 0.7430 | Val Dice: 0.7333
# Fold 2 | Epoch 65/100 | Train Loss: 0.4957 | Val Loss: 0.5499 | Train Acc: 0.9569 | Val Acc: 0.9496 | Train Dice: 0.7462 | Val Dice: 0.7323
# Fold 2 | Epoch 66/100 | Train Loss: 0.4881 | Val Loss: 0.5551 | Train Acc: 0.9576 | Val Acc: 0.9510 | Train Dice: 0.7478 | Val Dice: 0.7237
# Fold 2 | Epoch 67/100 | Train Loss: 0.4888 | Val Loss: 0.5529 | Train Acc: 0.9576 | Val Acc: 0.9514 | Train Dice: 0.7479 | Val Dice: 0.7262
# Fold 2 | Epoch 68/100 | Train Loss: 0.4874 | Val Loss: 0.5520 | Train Acc: 0.9584 | Val Acc: 0.9458 | Train Dice: 0.7487 | Val Dice: 0.7355
# Fold 2 | Epoch 69/100 | Train Loss: 0.4937 | Val Loss: 0.5631 | Train Acc: 0.9565 | Val Acc: 0.9508 | Train Dice: 0.7446 | Val Dice: 0.7204
# Fold 2 | Epoch 70/100 | Train Loss: 0.4887 | Val Loss: 0.5404 | Train Acc: 0.9570 | Val Acc: 0.9509 | Train Dice: 0.7496 | Val Dice: 0.7384
# Fold 2 | Epoch 71/100 | Train Loss: 0.4830 | Val Loss: 0.5410 | Train Acc: 0.9588 | Val Acc: 0.9507 | Train Dice: 0.7501 | Val Dice: 0.7387
# Fold 2 | Epoch 72/100 | Train Loss: 0.4841 | Val Loss: 0.5729 | Train Acc: 0.9575 | Val Acc: 0.9501 | Train Dice: 0.7527 | Val Dice: 0.7120
# Fold 2 | Epoch 73/100 | Train Loss: 0.4897 | Val Loss: 0.5370 | Train Acc: 0.9578 | Val Acc: 0.9494 | Train Dice: 0.7464 | Val Dice: 0.7432
# Fold 2 | Epoch 74/100 | Train Loss: 0.4858 | Val Loss: 0.5382 | Train Acc: 0.9583 | Val Acc: 0.9516 | Train Dice: 0.7503 | Val Dice: 0.7381
# Fold 2 | Epoch 75/100 | Train Loss: 0.4872 | Val Loss: 0.5695 | Train Acc: 0.9564 | Val Acc: 0.9511 | Train Dice: 0.7502 | Val Dice: 0.7129
# Fold 2 | Epoch 76/100 | Train Loss: 0.4836 | Val Loss: 0.5356 | Train Acc: 0.9599 | Val Acc: 0.9492 | Train Dice: 0.7478 | Val Dice: 0.7438
# Fold 2 | Epoch 77/100 | Train Loss: 0.4828 | Val Loss: 0.5491 | Train Acc: 0.9582 | Val Acc: 0.9520 | Train Dice: 0.7514 | Val Dice: 0.7293
# Fold 2 | Epoch 78/100 | Train Loss: 0.4840 | Val Loss: 0.5411 | Train Acc: 0.9581 | Val Acc: 0.9517 | Train Dice: 0.7540 | Val Dice: 0.7358
# Fold 2 | Epoch 79/100 | Train Loss: 0.4733 | Val Loss: 0.5457 | Train Acc: 0.9596 | Val Acc: 0.9516 | Train Dice: 0.7566 | Val Dice: 0.7308
# Fold 2 | Epoch 80/100 | Train Loss: 0.4712 | Val Loss: 0.5422 | Train Acc: 0.9597 | Val Acc: 0.9506 | Train Dice: 0.7582 | Val Dice: 0.7366
# Fold 2 | Epoch 81/100 | Train Loss: 0.4686 | Val Loss: 0.5417 | Train Acc: 0.9604 | Val Acc: 0.9517 | Train Dice: 0.7594 | Val Dice: 0.7337
# Fold 2 | Epoch 82/100 | Train Loss: 0.4722 | Val Loss: 0.5389 | Train Acc: 0.9597 | Val Acc: 0.9492 | Train Dice: 0.7596 | Val Dice: 0.7403
# Fold 2 | Epoch 83/100 | Train Loss: 0.4740 | Val Loss: 0.5607 | Train Acc: 0.9587 | Val Acc: 0.9513 | Train Dice: 0.7566 | Val Dice: 0.7171
# Fold 2 | Epoch 84/100 | Train Loss: 0.4773 | Val Loss: 0.5493 | Train Acc: 0.9588 | Val Acc: 0.9516 | Train Dice: 0.7525 | Val Dice: 0.7269
# Fold 2 | Epoch 85/100 | Train Loss: 0.4747 | Val Loss: 0.5321 | Train Acc: 0.9599 | Val Acc: 0.9510 | Train Dice: 0.7558 | Val Dice: 0.7433
# Fold 2 | Epoch 86/100 | Train Loss: 0.4763 | Val Loss: 0.5427 | Train Acc: 0.9591 | Val Acc: 0.9521 | Train Dice: 0.7576 | Val Dice: 0.7322
# Fold 2 | Epoch 87/100 | Train Loss: 0.4673 | Val Loss: 0.5432 | Train Acc: 0.9598 | Val Acc: 0.9516 | Train Dice: 0.7603 | Val Dice: 0.7318
# Fold 2 | Epoch 88/100 | Train Loss: 0.4685 | Val Loss: 0.5390 | Train Acc: 0.9601 | Val Acc: 0.9520 | Train Dice: 0.7604 | Val Dice: 0.7349
# Fold 2 | Epoch 89/100 | Train Loss: 0.4589 | Val Loss: 0.5460 | Train Acc: 0.9608 | Val Acc: 0.9518 | Train Dice: 0.7646 | Val Dice: 0.7296
# Fold 2 | Epoch 90/100 | Train Loss: 0.4639 | Val Loss: 0.5474 | Train Acc: 0.9604 | Val Acc: 0.9518 | Train Dice: 0.7640 | Val Dice: 0.7281
# Fold 2 | Epoch 91/100 | Train Loss: 0.4626 | Val Loss: 0.5304 | Train Acc: 0.9608 | Val Acc: 0.9513 | Train Dice: 0.7626 | Val Dice: 0.7432
# Fold 2 | Epoch 92/100 | Train Loss: 0.4582 | Val Loss: 0.5351 | Train Acc: 0.9608 | Val Acc: 0.9513 | Train Dice: 0.7660 | Val Dice: 0.7396
# Fold 2 | Epoch 93/100 | Train Loss: 0.4580 | Val Loss: 0.5376 | Train Acc: 0.9612 | Val Acc: 0.9520 | Train Dice: 0.7657 | Val Dice: 0.7364
# Fold 2 | Epoch 94/100 | Train Loss: 0.4567 | Val Loss: 0.5352 | Train Acc: 0.9609 | Val Acc: 0.9516 | Train Dice: 0.7667 | Val Dice: 0.7396
# Fold 2 | Epoch 95/100 | Train Loss: 0.4580 | Val Loss: 0.5259 | Train Acc: 0.9610 | Val Acc: 0.9521 | Train Dice: 0.7692 | Val Dice: 0.7448
# Fold 2 | Epoch 96/100 | Train Loss: 0.4567 | Val Loss: 0.5509 | Train Acc: 0.9608 | Val Acc: 0.9518 | Train Dice: 0.7666 | Val Dice: 0.7240
# Fold 2 | Epoch 97/100 | Train Loss: 0.4595 | Val Loss: 0.5410 | Train Acc: 0.9606 | Val Acc: 0.9524 | Train Dice: 0.7648 | Val Dice: 0.7314
# Fold 2 | Epoch 98/100 | Train Loss: 0.4597 | Val Loss: 0.5278 | Train Acc: 0.9605 | Val Acc: 0.9529 | Train Dice: 0.7642 | Val Dice: 0.7426
# Fold 2 | Epoch 99/100 | Train Loss: 0.4594 | Val Loss: 0.5307 | Train Acc: 0.9610 | Val Acc: 0.9505 | Train Dice: 0.7679 | Val Dice: 0.7454
# Fold 2 | Epoch 100/100 | Train Loss: 0.4539 | Val Loss: 0.5457 | Train Acc: 0.9610 | Val Acc: 0.9520 | Train Dice: 0.7683 | Val Dice: 0.7286
#
# ===== FOLD 3 ====
# Fold 3 | Epoch 1/100 | Train Loss: 1.2664 | Val Loss: 1.2458 | Train Acc: 0.0883 | Val Acc: 0.0839 | Train Dice: 0.1607 | Val Dice: 0.1545
# Fold 3 | Epoch 2/100 | Train Loss: 1.2360 | Val Loss: 1.1891 | Train Acc: 0.8025 | Val Acc: 0.9162 | Train Dice: 0.1171 | Val Dice: 0.0000
# Fold 3 | Epoch 3/100 | Train Loss: 1.1475 | Val Loss: 1.3340 | Train Acc: 0.9118 | Val Acc: 0.9163 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 3 | Epoch 4/100 | Train Loss: 1.0975 | Val Loss: 1.2928 | Train Acc: 0.9138 | Val Acc: 0.9163 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 3 | Epoch 5/100 | Train Loss: 1.0716 | Val Loss: 1.2660 | Train Acc: 0.9150 | Val Acc: 0.9163 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 3 | Epoch 6/100 | Train Loss: 1.0546 | Val Loss: 1.2261 | Train Acc: 0.9147 | Val Acc: 0.9163 | Train Dice: 0.0230 | Val Dice: 0.0000
# Fold 3 | Epoch 7/100 | Train Loss: 1.0379 | Val Loss: 1.1156 | Train Acc: 0.9213 | Val Acc: 0.9163 | Train Dice: 0.2325 | Val Dice: 0.0000
# Fold 3 | Epoch 8/100 | Train Loss: 1.0216 | Val Loss: 1.0404 | Train Acc: 0.9225 | Val Acc: 0.9186 | Train Dice: 0.3522 | Val Dice: 0.0580
# Fold 3 | Epoch 9/100 | Train Loss: 1.0017 | Val Loss: 1.0139 | Train Acc: 0.9225 | Val Acc: 0.9219 | Train Dice: 0.4118 | Val Dice: 0.1425
# Fold 3 | Epoch 10/100 | Train Loss: 0.9765 | Val Loss: 0.9635 | Train Acc: 0.9230 | Val Acc: 0.9289 | Train Dice: 0.4412 | Val Dice: 0.3115
# Fold 3 | Epoch 11/100 | Train Loss: 0.9630 | Val Loss: 0.9346 | Train Acc: 0.9204 | Val Acc: 0.9313 | Train Dice: 0.4495 | Val Dice: 0.3731
# Fold 3 | Epoch 12/100 | Train Loss: 0.9190 | Val Loss: 0.8807 | Train Acc: 0.9230 | Val Acc: 0.9359 | Train Dice: 0.4864 | Val Dice: 0.5014
# Fold 3 | Epoch 13/100 | Train Loss: 0.8813 | Val Loss: 0.8324 | Train Acc: 0.9262 | Val Acc: 0.9375 | Train Dice: 0.5275 | Val Dice: 0.5445
# Fold 3 | Epoch 14/100 | Train Loss: 0.8450 | Val Loss: 0.7766 | Train Acc: 0.9234 | Val Acc: 0.9383 | Train Dice: 0.5467 | Val Dice: 0.5974
# Fold 3 | Epoch 15/100 | Train Loss: 0.8027 | Val Loss: 0.7319 | Train Acc: 0.9267 | Val Acc: 0.9407 | Train Dice: 0.5584 | Val Dice: 0.6062
# Fold 3 | Epoch 16/100 | Train Loss: 0.7668 | Val Loss: 0.6909 | Train Acc: 0.9263 | Val Acc: 0.9416 | Train Dice: 0.5806 | Val Dice: 0.6281
# Fold 3 | Epoch 17/100 | Train Loss: 0.7447 | Val Loss: 0.6639 | Train Acc: 0.9300 | Val Acc: 0.9421 | Train Dice: 0.5943 | Val Dice: 0.6528
# Fold 3 | Epoch 18/100 | Train Loss: 0.7055 | Val Loss: 0.6582 | Train Acc: 0.9332 | Val Acc: 0.9477 | Train Dice: 0.6268 | Val Dice: 0.6383
# Fold 3 | Epoch 19/100 | Train Loss: 0.6901 | Val Loss: 0.6555 | Train Acc: 0.9359 | Val Acc: 0.9485 | Train Dice: 0.6296 | Val Dice: 0.6324
# Fold 3 | Epoch 20/100 | Train Loss: 0.6866 | Val Loss: 0.6140 | Train Acc: 0.9373 | Val Acc: 0.9473 | Train Dice: 0.6305 | Val Dice: 0.6795
# Fold 3 | Epoch 21/100 | Train Loss: 0.6634 | Val Loss: 0.6069 | Train Acc: 0.9428 | Val Acc: 0.9479 | Train Dice: 0.6466 | Val Dice: 0.6885
# Fold 3 | Epoch 22/100 | Train Loss: 0.6494 | Val Loss: 0.6161 | Train Acc: 0.9408 | Val Acc: 0.9510 | Train Dice: 0.6596 | Val Dice: 0.6613
# Fold 3 | Epoch 23/100 | Train Loss: 0.6483 | Val Loss: 0.5873 | Train Acc: 0.9413 | Val Acc: 0.9514 | Train Dice: 0.6549 | Val Dice: 0.6887
# Fold 3 | Epoch 24/100 | Train Loss: 0.6313 | Val Loss: 0.5798 | Train Acc: 0.9453 | Val Acc: 0.9487 | Train Dice: 0.6605 | Val Dice: 0.6985
# Fold 3 | Epoch 25/100 | Train Loss: 0.6317 | Val Loss: 0.5864 | Train Acc: 0.9437 | Val Acc: 0.9456 | Train Dice: 0.6641 | Val Dice: 0.6946
# Fold 3 | Epoch 26/100 | Train Loss: 0.6233 | Val Loss: 0.5686 | Train Acc: 0.9431 | Val Acc: 0.9520 | Train Dice: 0.6730 | Val Dice: 0.7001
# Fold 3 | Epoch 27/100 | Train Loss: 0.6080 | Val Loss: 0.5576 | Train Acc: 0.9461 | Val Acc: 0.9526 | Train Dice: 0.6803 | Val Dice: 0.7099
# Fold 3 | Epoch 28/100 | Train Loss: 0.6013 | Val Loss: 0.5557 | Train Acc: 0.9457 | Val Acc: 0.9524 | Train Dice: 0.6845 | Val Dice: 0.7140
# Fold 3 | Epoch 29/100 | Train Loss: 0.5847 | Val Loss: 0.5797 | Train Acc: 0.9476 | Val Acc: 0.9532 | Train Dice: 0.6956 | Val Dice: 0.6783
# Fold 3 | Epoch 30/100 | Train Loss: 0.5871 | Val Loss: 0.5428 | Train Acc: 0.9474 | Val Acc: 0.9534 | Train Dice: 0.6905 | Val Dice: 0.7167
# Fold 3 | Epoch 31/100 | Train Loss: 0.5855 | Val Loss: 0.5397 | Train Acc: 0.9492 | Val Acc: 0.9531 | Train Dice: 0.6917 | Val Dice: 0.7215
# Fold 3 | Epoch 32/100 | Train Loss: 0.5790 | Val Loss: 0.5362 | Train Acc: 0.9487 | Val Acc: 0.9550 | Train Dice: 0.6967 | Val Dice: 0.7202
# Fold 3 | Epoch 33/100 | Train Loss: 0.5656 | Val Loss: 0.5471 | Train Acc: 0.9498 | Val Acc: 0.9555 | Train Dice: 0.7065 | Val Dice: 0.7071
# Fold 3 | Epoch 34/100 | Train Loss: 0.5624 | Val Loss: 0.5304 | Train Acc: 0.9510 | Val Acc: 0.9548 | Train Dice: 0.7070 | Val Dice: 0.7223
# Fold 3 | Epoch 35/100 | Train Loss: 0.5734 | Val Loss: 0.5338 | Train Acc: 0.9494 | Val Acc: 0.9514 | Train Dice: 0.7019 | Val Dice: 0.7212
# Fold 3 | Epoch 36/100 | Train Loss: 0.5602 | Val Loss: 0.5236 | Train Acc: 0.9500 | Val Acc: 0.9555 | Train Dice: 0.7089 | Val Dice: 0.7258
# Fold 3 | Epoch 37/100 | Train Loss: 0.5498 | Val Loss: 0.5252 | Train Acc: 0.9514 | Val Acc: 0.9556 | Train Dice: 0.7176 | Val Dice: 0.7243
# Fold 3 | Epoch 38/100 | Train Loss: 0.5472 | Val Loss: 0.5422 | Train Acc: 0.9521 | Val Acc: 0.9492 | Train Dice: 0.7175 | Val Dice: 0.7185
# Fold 3 | Epoch 39/100 | Train Loss: 0.5731 | Val Loss: 0.5188 | Train Acc: 0.9482 | Val Acc: 0.9545 | Train Dice: 0.6982 | Val Dice: 0.7279
# Fold 3 | Epoch 40/100 | Train Loss: 0.5555 | Val Loss: 0.5201 | Train Acc: 0.9481 | Val Acc: 0.9576 | Train Dice: 0.7131 | Val Dice: 0.7260
# Fold 3 | Epoch 41/100 | Train Loss: 0.5580 | Val Loss: 0.5629 | Train Acc: 0.9513 | Val Acc: 0.9462 | Train Dice: 0.7093 | Val Dice: 0.7131
# Fold 3 | Epoch 42/100 | Train Loss: 0.5541 | Val Loss: 0.5276 | Train Acc: 0.9502 | Val Acc: 0.9571 | Train Dice: 0.7145 | Val Dice: 0.7198
# Fold 3 | Epoch 43/100 | Train Loss: 0.5509 | Val Loss: 0.5159 | Train Acc: 0.9504 | Val Acc: 0.9537 | Train Dice: 0.7128 | Val Dice: 0.7323
# Fold 3 | Epoch 44/100 | Train Loss: 0.5433 | Val Loss: 0.5207 | Train Acc: 0.9520 | Val Acc: 0.9583 | Train Dice: 0.7179 | Val Dice: 0.7230
# Fold 3 | Epoch 45/100 | Train Loss: 0.5328 | Val Loss: 0.5105 | Train Acc: 0.9527 | Val Acc: 0.9551 | Train Dice: 0.7262 | Val Dice: 0.7346
# Fold 3 | Epoch 46/100 | Train Loss: 0.5286 | Val Loss: 0.5097 | Train Acc: 0.9540 | Val Acc: 0.9580 | Train Dice: 0.7259 | Val Dice: 0.7316
# Fold 3 | Epoch 47/100 | Train Loss: 0.5279 | Val Loss: 0.5103 | Train Acc: 0.9539 | Val Acc: 0.9560 | Train Dice: 0.7267 | Val Dice: 0.7332
# Fold 3 | Epoch 48/100 | Train Loss: 0.5372 | Val Loss: 0.5086 | Train Acc: 0.9528 | Val Acc: 0.9561 | Train Dice: 0.7220 | Val Dice: 0.7343
# Fold 3 | Epoch 49/100 | Train Loss: 0.5231 | Val Loss: 0.5058 | Train Acc: 0.9533 | Val Acc: 0.9578 | Train Dice: 0.7317 | Val Dice: 0.7334
# Fold 3 | Epoch 50/100 | Train Loss: 0.5348 | Val Loss: 0.5072 | Train Acc: 0.9533 | Val Acc: 0.9551 | Train Dice: 0.7270 | Val Dice: 0.7347
# Fold 3 | Epoch 51/100 | Train Loss: 0.5290 | Val Loss: 0.5208 | Train Acc: 0.9520 | Val Acc: 0.9580 | Train Dice: 0.7275 | Val Dice: 0.7199
# Fold 3 | Epoch 52/100 | Train Loss: 0.5293 | Val Loss: 0.5030 | Train Acc: 0.9526 | Val Acc: 0.9561 | Train Dice: 0.7279 | Val Dice: 0.7373
# Fold 3 | Epoch 53/100 | Train Loss: 0.5150 | Val Loss: 0.4912 | Train Acc: 0.9558 | Val Acc: 0.9583 | Train Dice: 0.7332 | Val Dice: 0.7433
# Fold 3 | Epoch 54/100 | Train Loss: 0.5133 | Val Loss: 0.5061 | Train Acc: 0.9544 | Val Acc: 0.9584 | Train Dice: 0.7356 | Val Dice: 0.7304
# Fold 3 | Epoch 55/100 | Train Loss: 0.5116 | Val Loss: 0.5018 | Train Acc: 0.9557 | Val Acc: 0.9577 | Train Dice: 0.7350 | Val Dice: 0.7365
# Fold 3 | Epoch 56/100 | Train Loss: 0.5085 | Val Loss: 0.4930 | Train Acc: 0.9550 | Val Acc: 0.9590 | Train Dice: 0.7386 | Val Dice: 0.7407
# Fold 3 | Epoch 57/100 | Train Loss: 0.5085 | Val Loss: 0.4983 | Train Acc: 0.9554 | Val Acc: 0.9570 | Train Dice: 0.7385 | Val Dice: 0.7385
# Fold 3 | Epoch 58/100 | Train Loss: 0.5047 | Val Loss: 0.4963 | Train Acc: 0.9565 | Val Acc: 0.9571 | Train Dice: 0.7392 | Val Dice: 0.7401
# Fold 3 | Epoch 59/100 | Train Loss: 0.5132 | Val Loss: 0.4900 | Train Acc: 0.9551 | Val Acc: 0.9572 | Train Dice: 0.7374 | Val Dice: 0.7447
# Fold 3 | Epoch 60/100 | Train Loss: 0.5030 | Val Loss: 0.5079 | Train Acc: 0.9551 | Val Acc: 0.9592 | Train Dice: 0.7407 | Val Dice: 0.7283
# Fold 3 | Epoch 61/100 | Train Loss: 0.5060 | Val Loss: 0.4901 | Train Acc: 0.9556 | Val Acc: 0.9577 | Train Dice: 0.7401 | Val Dice: 0.7436
# Fold 3 | Epoch 62/100 | Train Loss: 0.5016 | Val Loss: 0.4899 | Train Acc: 0.9570 | Val Acc: 0.9579 | Train Dice: 0.7419 | Val Dice: 0.7431
# Fold 3 | Epoch 63/100 | Train Loss: 0.5016 | Val Loss: 0.4961 | Train Acc: 0.9560 | Val Acc: 0.9590 | Train Dice: 0.7414 | Val Dice: 0.7371
# Fold 3 | Epoch 64/100 | Train Loss: 0.5015 | Val Loss: 0.4839 | Train Acc: 0.9569 | Val Acc: 0.9583 | Train Dice: 0.7415 | Val Dice: 0.7478
# Fold 3 | Epoch 65/100 | Train Loss: 0.5026 | Val Loss: 0.4934 | Train Acc: 0.9563 | Val Acc: 0.9564 | Train Dice: 0.7417 | Val Dice: 0.7430
# Fold 3 | Epoch 66/100 | Train Loss: 0.5104 | Val Loss: 0.5067 | Train Acc: 0.9547 | Val Acc: 0.9592 | Train Dice: 0.7372 | Val Dice: 0.7281
# Fold 3 | Epoch 67/100 | Train Loss: 0.5029 | Val Loss: 0.4854 | Train Acc: 0.9555 | Val Acc: 0.9587 | Train Dice: 0.7417 | Val Dice: 0.7460
# Fold 3 | Epoch 68/100 | Train Loss: 0.4994 | Val Loss: 0.4891 | Train Acc: 0.9574 | Val Acc: 0.9579 | Train Dice: 0.7400 | Val Dice: 0.7454
# Fold 3 | Epoch 69/100 | Train Loss: 0.4917 | Val Loss: 0.5011 | Train Acc: 0.9564 | Val Acc: 0.9594 | Train Dice: 0.7482 | Val Dice: 0.7329
# Fold 3 | Epoch 70/100 | Train Loss: 0.4949 | Val Loss: 0.4878 | Train Acc: 0.9574 | Val Acc: 0.9578 | Train Dice: 0.7449 | Val Dice: 0.7441
# Fold 3 | Epoch 71/100 | Train Loss: 0.4890 | Val Loss: 0.4789 | Train Acc: 0.9578 | Val Acc: 0.9589 | Train Dice: 0.7485 | Val Dice: 0.7488
# Fold 3 | Epoch 72/100 | Train Loss: 0.4931 | Val Loss: 0.4836 | Train Acc: 0.9564 | Val Acc: 0.9587 | Train Dice: 0.7464 | Val Dice: 0.7468
# Fold 3 | Epoch 73/100 | Train Loss: 0.4890 | Val Loss: 0.4843 | Train Acc: 0.9570 | Val Acc: 0.9588 | Train Dice: 0.7509 | Val Dice: 0.7447
# Fold 3 | Epoch 74/100 | Train Loss: 0.5000 | Val Loss: 0.4881 | Train Acc: 0.9562 | Val Acc: 0.9576 | Train Dice: 0.7472 | Val Dice: 0.7442
# Fold 3 | Epoch 75/100 | Train Loss: 0.4907 | Val Loss: 0.4882 | Train Acc: 0.9569 | Val Acc: 0.9586 | Train Dice: 0.7500 | Val Dice: 0.7424
# Fold 3 | Epoch 76/100 | Train Loss: 0.4827 | Val Loss: 0.4819 | Train Acc: 0.9579 | Val Acc: 0.9587 | Train Dice: 0.7534 | Val Dice: 0.7476
# Fold 3 | Epoch 77/100 | Train Loss: 0.4827 | Val Loss: 0.5022 | Train Acc: 0.9584 | Val Acc: 0.9585 | Train Dice: 0.7532 | Val Dice: 0.7319
# Fold 3 | Epoch 78/100 | Train Loss: 0.4856 | Val Loss: 0.4861 | Train Acc: 0.9571 | Val Acc: 0.9593 | Train Dice: 0.7537 | Val Dice: 0.7432
# Fold 3 | Epoch 79/100 | Train Loss: 0.4785 | Val Loss: 0.4813 | Train Acc: 0.9582 | Val Acc: 0.9598 | Train Dice: 0.7572 | Val Dice: 0.7460
# Fold 3 | Epoch 80/100 | Train Loss: 0.4795 | Val Loss: 0.4839 | Train Acc: 0.9585 | Val Acc: 0.9576 | Train Dice: 0.7555 | Val Dice: 0.7475
# Fold 3 | Epoch 81/100 | Train Loss: 0.4761 | Val Loss: 0.4849 | Train Acc: 0.9587 | Val Acc: 0.9590 | Train Dice: 0.7574 | Val Dice: 0.7452
# Fold 3 | Epoch 82/100 | Train Loss: 0.4780 | Val Loss: 0.4821 | Train Acc: 0.9588 | Val Acc: 0.9581 | Train Dice: 0.7561 | Val Dice: 0.7488
# Fold 3 | Epoch 83/100 | Train Loss: 0.4845 | Val Loss: 0.4886 | Train Acc: 0.9572 | Val Acc: 0.9602 | Train Dice: 0.7538 | Val Dice: 0.7401
# Fold 3 | Epoch 84/100 | Train Loss: 0.4931 | Val Loss: 0.4885 | Train Acc: 0.9557 | Val Acc: 0.9592 | Train Dice: 0.7483 | Val Dice: 0.7424
# Fold 3 | Epoch 85/100 | Train Loss: 0.4792 | Val Loss: 0.4764 | Train Acc: 0.9592 | Val Acc: 0.9588 | Train Dice: 0.7554 | Val Dice: 0.7515
# Fold 3 | Epoch 86/100 | Train Loss: 0.4847 | Val Loss: 0.4834 | Train Acc: 0.9573 | Val Acc: 0.9588 | Train Dice: 0.7542 | Val Dice: 0.7469
# Fold 3 | Epoch 87/100 | Train Loss: 0.4780 | Val Loss: 0.4844 | Train Acc: 0.9584 | Val Acc: 0.9586 | Train Dice: 0.7557 | Val Dice: 0.7456
# Fold 3 | Epoch 88/100 | Train Loss: 0.4833 | Val Loss: 0.4841 | Train Acc: 0.9576 | Val Acc: 0.9607 | Train Dice: 0.7548 | Val Dice: 0.7404
# Fold 3 | Epoch 89/100 | Train Loss: 0.4784 | Val Loss: 0.4883 | Train Acc: 0.9575 | Val Acc: 0.9592 | Train Dice: 0.7576 | Val Dice: 0.7416
# Fold 3 | Epoch 90/100 | Train Loss: 0.4748 | Val Loss: 0.4767 | Train Acc: 0.9592 | Val Acc: 0.9581 | Train Dice: 0.7572 | Val Dice: 0.7534
# Fold 3 | Epoch 91/100 | Train Loss: 0.4726 | Val Loss: 0.4816 | Train Acc: 0.9589 | Val Acc: 0.9603 | Train Dice: 0.7590 | Val Dice: 0.7444
# Fold 3 | Epoch 92/100 | Train Loss: 0.4711 | Val Loss: 0.4821 | Train Acc: 0.9592 | Val Acc: 0.9598 | Train Dice: 0.7593 | Val Dice: 0.7469
# Fold 3 | Epoch 93/100 | Train Loss: 0.4673 | Val Loss: 0.4755 | Train Acc: 0.9594 | Val Acc: 0.9599 | Train Dice: 0.7626 | Val Dice: 0.7523
# Fold 3 | Epoch 94/100 | Train Loss: 0.4719 | Val Loss: 0.4811 | Train Acc: 0.9595 | Val Acc: 0.9579 | Train Dice: 0.7614 | Val Dice: 0.7493
# Fold 3 | Epoch 95/100 | Train Loss: 0.4760 | Val Loss: 0.4875 | Train Acc: 0.9579 | Val Acc: 0.9599 | Train Dice: 0.7586 | Val Dice: 0.7405
# Fold 3 | Epoch 96/100 | Train Loss: 0.4651 | Val Loss: 0.4746 | Train Acc: 0.9594 | Val Acc: 0.9591 | Train Dice: 0.7649 | Val Dice: 0.7531
# Fold 3 | Epoch 97/100 | Train Loss: 0.4693 | Val Loss: 0.4781 | Train Acc: 0.9593 | Val Acc: 0.9602 | Train Dice: 0.7625 | Val Dice: 0.7480
# Fold 3 | Epoch 98/100 | Train Loss: 0.4632 | Val Loss: 0.4804 | Train Acc: 0.9598 | Val Acc: 0.9600 | Train Dice: 0.7634 | Val Dice: 0.7473
# Fold 3 | Epoch 99/100 | Train Loss: 0.4600 | Val Loss: 0.4790 | Train Acc: 0.9606 | Val Acc: 0.9604 | Train Dice: 0.7665 | Val Dice: 0.7479
# Fold 3 | Epoch 100/100 | Train Loss: 0.4626 | Val Loss: 0.4733 | Train Acc: 0.9600 | Val Acc: 0.9604 | Train Dice: 0.7650 | Val Dice: 0.7519
#
# ===== FOLD 4 ====
# Fold 4 | Epoch 1/100 | Train Loss: 1.2485 | Val Loss: 1.2317 | Train Acc: 0.9132 | Val Acc: 0.9010 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 4 | Epoch 2/100 | Train Loss: 1.2307 | Val Loss: 1.2045 | Train Acc: 0.9156 | Val Acc: 0.9010 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 4 | Epoch 3/100 | Train Loss: 1.1681 | Val Loss: 1.3112 | Train Acc: 0.9149 | Val Acc: 0.9010 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 4 | Epoch 4/100 | Train Loss: 1.1060 | Val Loss: 1.4154 | Train Acc: 0.9153 | Val Acc: 0.9010 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 4 | Epoch 5/100 | Train Loss: 1.0853 | Val Loss: 1.3177 | Train Acc: 0.9138 | Val Acc: 0.9010 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 4 | Epoch 6/100 | Train Loss: 1.0635 | Val Loss: 1.2627 | Train Acc: 0.9165 | Val Acc: 0.9010 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 4 | Epoch 7/100 | Train Loss: 1.0503 | Val Loss: 1.1068 | Train Acc: 0.9159 | Val Acc: 0.9010 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 4 | Epoch 8/100 | Train Loss: 1.0372 | Val Loss: 1.0585 | Train Acc: 0.9168 | Val Acc: 0.9010 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 4 | Epoch 9/100 | Train Loss: 1.0212 | Val Loss: 1.0466 | Train Acc: 0.9168 | Val Acc: 0.9010 | Train Dice: 0.0132 | Val Dice: 0.0000
# Fold 4 | Epoch 10/100 | Train Loss: 1.0061 | Val Loss: 1.0092 | Train Acc: 0.9207 | Val Acc: 0.9021 | Train Dice: 0.1411 | Val Dice: 0.0181
# Fold 4 | Epoch 11/100 | Train Loss: 0.9844 | Val Loss: 0.9914 | Train Acc: 0.9267 | Val Acc: 0.9061 | Train Dice: 0.3049 | Val Dice: 0.0970
# Fold 4 | Epoch 12/100 | Train Loss: 0.9589 | Val Loss: 0.9569 | Train Acc: 0.9295 | Val Acc: 0.9117 | Train Dice: 0.3988 | Val Dice: 0.2266
# Fold 4 | Epoch 13/100 | Train Loss: 0.9235 | Val Loss: 0.9165 | Train Acc: 0.9319 | Val Acc: 0.9192 | Train Dice: 0.4476 | Val Dice: 0.3785
# Fold 4 | Epoch 14/100 | Train Loss: 0.8887 | Val Loss: 0.8886 | Train Acc: 0.9343 | Val Acc: 0.9239 | Train Dice: 0.5134 | Val Dice: 0.4499
# Fold 4 | Epoch 15/100 | Train Loss: 0.8578 | Val Loss: 0.8425 | Train Acc: 0.9350 | Val Acc: 0.9310 | Train Dice: 0.5407 | Val Dice: 0.5644
# Fold 4 | Epoch 16/100 | Train Loss: 0.8363 | Val Loss: 0.8028 | Train Acc: 0.9340 | Val Acc: 0.9327 | Train Dice: 0.5725 | Val Dice: 0.6437
# Fold 4 | Epoch 17/100 | Train Loss: 0.7932 | Val Loss: 0.7570 | Train Acc: 0.9374 | Val Acc: 0.9355 | Train Dice: 0.6000 | Val Dice: 0.6451
# Fold 4 | Epoch 18/100 | Train Loss: 0.7541 | Val Loss: 0.7549 | Train Acc: 0.9364 | Val Acc: 0.9339 | Train Dice: 0.6262 | Val Dice: 0.5882
# Fold 4 | Epoch 19/100 | Train Loss: 0.7299 | Val Loss: 0.6777 | Train Acc: 0.9312 | Val Acc: 0.9385 | Train Dice: 0.6149 | Val Dice: 0.6674
# Fold 4 | Epoch 20/100 | Train Loss: 0.7033 | Val Loss: 0.6563 | Train Acc: 0.9382 | Val Acc: 0.9374 | Train Dice: 0.6226 | Val Dice: 0.6824
# Fold 4 | Epoch 21/100 | Train Loss: 0.6667 | Val Loss: 0.6405 | Train Acc: 0.9417 | Val Acc: 0.9406 | Train Dice: 0.6479 | Val Dice: 0.6799
# Fold 4 | Epoch 22/100 | Train Loss: 0.6551 | Val Loss: 0.6289 | Train Acc: 0.9404 | Val Acc: 0.9369 | Train Dice: 0.6477 | Val Dice: 0.6856
# Fold 4 | Epoch 23/100 | Train Loss: 0.6342 | Val Loss: 0.6201 | Train Acc: 0.9427 | Val Acc: 0.9430 | Train Dice: 0.6644 | Val Dice: 0.6897
# Fold 4 | Epoch 24/100 | Train Loss: 0.6297 | Val Loss: 0.6369 | Train Acc: 0.9438 | Val Acc: 0.9435 | Train Dice: 0.6659 | Val Dice: 0.6686
# Fold 4 | Epoch 25/100 | Train Loss: 0.6287 | Val Loss: 0.6488 | Train Acc: 0.9432 | Val Acc: 0.9431 | Train Dice: 0.6685 | Val Dice: 0.6572
# Fold 4 | Epoch 26/100 | Train Loss: 0.6195 | Val Loss: 0.5886 | Train Acc: 0.9437 | Val Acc: 0.9439 | Train Dice: 0.6745 | Val Dice: 0.7090
# Fold 4 | Epoch 27/100 | Train Loss: 0.6063 | Val Loss: 0.5794 | Train Acc: 0.9470 | Val Acc: 0.9449 | Train Dice: 0.6786 | Val Dice: 0.7172
# Fold 4 | Epoch 28/100 | Train Loss: 0.6087 | Val Loss: 0.5713 | Train Acc: 0.9471 | Val Acc: 0.9462 | Train Dice: 0.6780 | Val Dice: 0.7204
# Fold 4 | Epoch 29/100 | Train Loss: 0.5881 | Val Loss: 0.5762 | Train Acc: 0.9477 | Val Acc: 0.9477 | Train Dice: 0.6913 | Val Dice: 0.7117
# Fold 4 | Epoch 30/100 | Train Loss: 0.5844 | Val Loss: 0.6015 | Train Acc: 0.9480 | Val Acc: 0.9467 | Train Dice: 0.6958 | Val Dice: 0.6875
# Fold 4 | Epoch 31/100 | Train Loss: 0.5924 | Val Loss: 0.5667 | Train Acc: 0.9464 | Val Acc: 0.9461 | Train Dice: 0.6836 | Val Dice: 0.7180
# Fold 4 | Epoch 32/100 | Train Loss: 0.5891 | Val Loss: 0.5634 | Train Acc: 0.9484 | Val Acc: 0.9445 | Train Dice: 0.6862 | Val Dice: 0.7261
# Fold 4 | Epoch 33/100 | Train Loss: 0.5750 | Val Loss: 0.5665 | Train Acc: 0.9500 | Val Acc: 0.9491 | Train Dice: 0.6974 | Val Dice: 0.7166
# Fold 4 | Epoch 34/100 | Train Loss: 0.5832 | Val Loss: 0.5512 | Train Acc: 0.9479 | Val Acc: 0.9489 | Train Dice: 0.6920 | Val Dice: 0.7313
# Fold 4 | Epoch 35/100 | Train Loss: 0.5634 | Val Loss: 0.5522 | Train Acc: 0.9519 | Val Acc: 0.9491 | Train Dice: 0.7051 | Val Dice: 0.7306
# Fold 4 | Epoch 36/100 | Train Loss: 0.5572 | Val Loss: 0.5955 | Train Acc: 0.9493 | Val Acc: 0.9482 | Train Dice: 0.7115 | Val Dice: 0.6935
# Fold 4 | Epoch 37/100 | Train Loss: 0.5546 | Val Loss: 0.5394 | Train Acc: 0.9523 | Val Acc: 0.9479 | Train Dice: 0.7083 | Val Dice: 0.7383
# Fold 4 | Epoch 38/100 | Train Loss: 0.5443 | Val Loss: 0.5473 | Train Acc: 0.9524 | Val Acc: 0.9505 | Train Dice: 0.7157 | Val Dice: 0.7279
# ...
# Fold 9 | Epoch 88/100 | Train Loss: 0.4778 | Val Loss: 0.4861 | Train Acc: 0.9577 | Val Acc: 0.9588 | Train Dice: 0.7580 | Val Dice: 0.7424
# Fold 9 | Epoch 89/100 | Train Loss: 0.4755 | Val Loss: 0.4925 | Train Acc: 0.9593 | Val Acc: 0.9575 | Train Dice: 0.7581 | Val Dice: 0.7399
# Fold 9 | Epoch 90/100 | Train Loss: 0.4669 | Val Loss: 0.4889 | Train Acc: 0.9588 | Val Acc: 0.9611 | Train Dice: 0.7632 | Val Dice: 0.7370
# Fold 9 | Epoch 91/100 | Train Loss: 0.4670 | Val Loss: 0.4930 | Train Acc: 0.9599 | Val Acc: 0.9576 | Train Dice: 0.7646 | Val Dice: 0.7394
# Fold 9 | Epoch 92/100 | Train Loss: 0.4702 | Val Loss: 0.4903 | Train Acc: 0.9590 | Val Acc: 0.9587 | Train Dice: 0.7609 | Val Dice: 0.7399
# Fold 9 | Epoch 93/100 | Train Loss: 0.4610 | Val Loss: 0.4892 | Train Acc: 0.9598 | Val Acc: 0.9613 | Train Dice: 0.7677 | Val Dice: 0.7360
# Fold 9 | Epoch 94/100 | Train Loss: 0.4621 | Val Loss: 0.4876 | Train Acc: 0.9597 | Val Acc: 0.9583 | Train Dice: 0.7640 | Val Dice: 0.7411
# Fold 9 | Epoch 95/100 | Train Loss: 0.4683 | Val Loss: 0.4837 | Train Acc: 0.9596 | Val Acc: 0.9590 | Train Dice: 0.7612 | Val Dice: 0.7443
# Fold 9 | Epoch 96/100 | Train Loss: 0.4608 | Val Loss: 0.4852 | Train Acc: 0.9593 | Val Acc: 0.9617 | Train Dice: 0.7674 | Val Dice: 0.7387
# Fold 9 | Epoch 97/100 | Train Loss: 0.4760 | Val Loss: 0.4817 | Train Acc: 0.9580 | Val Acc: 0.9592 | Train Dice: 0.7586 | Val Dice: 0.7450
# Fold 9 | Epoch 98/100 | Train Loss: 0.4644 | Val Loss: 0.4845 | Train Acc: 0.9602 | Val Acc: 0.9587 | Train Dice: 0.7622 | Val Dice: 0.7431
# Fold 9 | Epoch 99/100 | Train Loss: 0.4593 | Val Loss: 0.4906 | Train Acc: 0.9593 | Val Acc: 0.9616 | Train Dice: 0.7675 | Val Dice: 0.7346
# Fold 9 | Epoch 100/100 | Train Loss: 0.4637 | Val Loss: 0.4809 | Train Acc: 0.9597 | Val Acc: 0.9594 | Train Dice: 0.7645 | Val Dice: 0.7458
#
# ===== FOLD 10 ====
# Fold 10 | Epoch 1/100 | Train Loss: 1.2654 | Val Loss: 1.2648 | Train Acc: 0.0904 | Val Acc: 0.2809 | Train Dice: 0.1602 | Val Dice: 0.1955
# Fold 10 | Epoch 2/100 | Train Loss: 1.2379 | Val Loss: 1.2092 | Train Acc: 0.7430 | Val Acc: 0.9122 | Train Dice: 0.1622 | Val Dice: 0.0000
# Fold 10 | Epoch 3/100 | Train Loss: 1.1564 | Val Loss: 1.3184 | Train Acc: 0.9140 | Val Acc: 0.9126 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 10 | Epoch 4/100 | Train Loss: 1.1059 | Val Loss: 1.2020 | Train Acc: 0.9154 | Val Acc: 0.9126 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 10 | Epoch 5/100 | Train Loss: 1.0792 | Val Loss: 1.1550 | Train Acc: 0.9137 | Val Acc: 0.9126 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 10 | Epoch 6/100 | Train Loss: 1.0601 | Val Loss: 1.0903 | Train Acc: 0.9149 | Val Acc: 0.9126 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 10 | Epoch 7/100 | Train Loss: 1.0443 | Val Loss: 1.0547 | Train Acc: 0.9156 | Val Acc: 0.9126 | Train Dice: 0.0393 | Val Dice: 0.0000
# Fold 10 | Epoch 8/100 | Train Loss: 1.0322 | Val Loss: 1.0440 | Train Acc: 0.9233 | Val Acc: 0.9160 | Train Dice: 0.2577 | Val Dice: 0.0845
# Fold 10 | Epoch 9/100 | Train Loss: 1.0157 | Val Loss: 1.0251 | Train Acc: 0.9247 | Val Acc: 0.9243 | Train Dice: 0.3602 | Val Dice: 0.3039
# Fold 10 | Epoch 10/100 | Train Loss: 0.9978 | Val Loss: 0.9957 | Train Acc: 0.9269 | Val Acc: 0.9266 | Train Dice: 0.4267 | Val Dice: 0.3740
# Fold 10 | Epoch 11/100 | Train Loss: 0.9780 | Val Loss: 0.9651 | Train Acc: 0.9259 | Val Acc: 0.9287 | Train Dice: 0.4386 | Val Dice: 0.4314
# Fold 10 | Epoch 12/100 | Train Loss: 0.9404 | Val Loss: 0.9305 | Train Acc: 0.9278 | Val Acc: 0.9301 | Train Dice: 0.4823 | Val Dice: 0.4695
# Fold 10 | Epoch 13/100 | Train Loss: 0.9057 | Val Loss: 0.8941 | Train Acc: 0.9301 | Val Acc: 0.9319 | Train Dice: 0.4975 | Val Dice: 0.5401
# Fold 10 | Epoch 14/100 | Train Loss: 0.8724 | Val Loss: 0.8685 | Train Acc: 0.9315 | Val Acc: 0.9312 | Train Dice: 0.5402 | Val Dice: 0.5854
# Fold 10 | Epoch 15/100 | Train Loss: 0.8455 | Val Loss: 0.8317 | Train Acc: 0.9315 | Val Acc: 0.9332 | Train Dice: 0.5618 | Val Dice: 0.5936
# Fold 10 | Epoch 16/100 | Train Loss: 0.8242 | Val Loss: 0.8002 | Train Acc: 0.9315 | Val Acc: 0.9344 | Train Dice: 0.5768 | Val Dice: 0.6185
# Fold 10 | Epoch 17/100 | Train Loss: 0.7810 | Val Loss: 0.7680 | Train Acc: 0.9341 | Val Acc: 0.9382 | Train Dice: 0.6072 | Val Dice: 0.6255
# Fold 10 | Epoch 18/100 | Train Loss: 0.7477 | Val Loss: 0.7374 | Train Acc: 0.9387 | Val Acc: 0.9376 | Train Dice: 0.6191 | Val Dice: 0.6407
# Fold 10 | Epoch 19/100 | Train Loss: 0.7119 | Val Loss: 0.7101 | Train Acc: 0.9380 | Val Acc: 0.9383 | Train Dice: 0.6365 | Val Dice: 0.6465
# Fold 10 | Epoch 20/100 | Train Loss: 0.6859 | Val Loss: 0.6825 | Train Acc: 0.9404 | Val Acc: 0.9380 | Train Dice: 0.6442 | Val Dice: 0.6541
# Fold 10 | Epoch 21/100 | Train Loss: 0.6679 | Val Loss: 0.6929 | Train Acc: 0.9409 | Val Acc: 0.9305 | Train Dice: 0.6515 | Val Dice: 0.6477
# Fold 10 | Epoch 22/100 | Train Loss: 0.6741 | Val Loss: 0.6493 | Train Acc: 0.9371 | Val Acc: 0.9422 | Train Dice: 0.6422 | Val Dice: 0.6642
# Fold 10 | Epoch 23/100 | Train Loss: 0.6446 | Val Loss: 0.6339 | Train Acc: 0.9398 | Val Acc: 0.9440 | Train Dice: 0.6640 | Val Dice: 0.6709
# Fold 10 | Epoch 24/100 | Train Loss: 0.6345 | Val Loss: 0.6343 | Train Acc: 0.9434 | Val Acc: 0.9405 | Train Dice: 0.6636 | Val Dice: 0.6738
# Fold 10 | Epoch 25/100 | Train Loss: 0.6128 | Val Loss: 0.6248 | Train Acc: 0.9446 | Val Acc: 0.9461 | Train Dice: 0.6785 | Val Dice: 0.6729
# Fold 10 | Epoch 26/100 | Train Loss: 0.6059 | Val Loss: 0.6099 | Train Acc: 0.9450 | Val Acc: 0.9446 | Train Dice: 0.6842 | Val Dice: 0.6838
# Fold 10 | Epoch 27/100 | Train Loss: 0.5944 | Val Loss: 0.6034 | Train Acc: 0.9477 | Val Acc: 0.9439 | Train Dice: 0.6872 | Val Dice: 0.6883
# Fold 10 | Epoch 28/100 | Train Loss: 0.5961 | Val Loss: 0.6019 | Train Acc: 0.9461 | Val Acc: 0.9437 | Train Dice: 0.6860 | Val Dice: 0.6889
# Fold 10 | Epoch 29/100 | Train Loss: 0.5834 | Val Loss: 0.5920 | Train Acc: 0.9474 | Val Acc: 0.9473 | Train Dice: 0.6940 | Val Dice: 0.6962
# Fold 10 | Epoch 30/100 | Train Loss: 0.5676 | Val Loss: 0.5894 | Train Acc: 0.9500 | Val Acc: 0.9505 | Train Dice: 0.7046 | Val Dice: 0.6906
# Fold 10 | Epoch 31/100 | Train Loss: 0.5801 | Val Loss: 0.5770 | Train Acc: 0.9479 | Val Acc: 0.9468 | Train Dice: 0.6970 | Val Dice: 0.7042
# Fold 10 | Epoch 32/100 | Train Loss: 0.5605 | Val Loss: 0.5724 | Train Acc: 0.9505 | Val Acc: 0.9487 | Train Dice: 0.7074 | Val Dice: 0.7105
# Fold 10 | Epoch 33/100 | Train Loss: 0.5568 | Val Loss: 0.5666 | Train Acc: 0.9508 | Val Acc: 0.9507 | Train Dice: 0.7090 | Val Dice: 0.7118
# Fold 10 | Epoch 34/100 | Train Loss: 0.5480 | Val Loss: 0.5761 | Train Acc: 0.9518 | Val Acc: 0.9459 | Train Dice: 0.7140 | Val Dice: 0.7092
# Fold 10 | Epoch 35/100 | Train Loss: 0.5444 | Val Loss: 0.5582 | Train Acc: 0.9520 | Val Acc: 0.9516 | Train Dice: 0.7155 | Val Dice: 0.7135
# Fold 10 | Epoch 36/100 | Train Loss: 0.5438 | Val Loss: 0.5532 | Train Acc: 0.9516 | Val Acc: 0.9515 | Train Dice: 0.7170 | Val Dice: 0.7174
# Fold 10 | Epoch 37/100 | Train Loss: 0.5384 | Val Loss: 0.5506 | Train Acc: 0.9523 | Val Acc: 0.9509 | Train Dice: 0.7225 | Val Dice: 0.7209
# Fold 10 | Epoch 38/100 | Train Loss: 0.5334 | Val Loss: 0.5566 | Train Acc: 0.9535 | Val Acc: 0.9536 | Train Dice: 0.7239 | Val Dice: 0.7110
# Fold 10 | Epoch 39/100 | Train Loss: 0.5311 | Val Loss: 0.5560 | Train Acc: 0.9530 | Val Acc: 0.9472 | Train Dice: 0.7270 | Val Dice: 0.7195
# Fold 10 | Epoch 40/100 | Train Loss: 0.5351 | Val Loss: 0.5554 | Train Acc: 0.9529 | Val Acc: 0.9468 | Train Dice: 0.7214 | Val Dice: 0.7199
# Fold 10 | Epoch 41/100 | Train Loss: 0.5530 | Val Loss: 0.5550 | Train Acc: 0.9494 | Val Acc: 0.9540 | Train Dice: 0.7125 | Val Dice: 0.7104
# Fold 10 | Epoch 42/100 | Train Loss: 0.5366 | Val Loss: 0.5552 | Train Acc: 0.9521 | Val Acc: 0.9472 | Train Dice: 0.7213 | Val Dice: 0.7218
# Fold 10 | Epoch 43/100 | Train Loss: 0.5308 | Val Loss: 0.5279 | Train Acc: 0.9540 | Val Acc: 0.9536 | Train Dice: 0.7228 | Val Dice: 0.7355
# Fold 10 | Epoch 44/100 | Train Loss: 0.5209 | Val Loss: 0.5295 | Train Acc: 0.9537 | Val Acc: 0.9553 | Train Dice: 0.7295 | Val Dice: 0.7306
# Fold 10 | Epoch 45/100 | Train Loss: 0.5185 | Val Loss: 0.5353 | Train Acc: 0.9552 | Val Acc: 0.9520 | Train Dice: 0.7336 | Val Dice: 0.7309
# Fold 10 | Epoch 46/100 | Train Loss: 0.5100 | Val Loss: 0.5234 | Train Acc: 0.9558 | Val Acc: 0.9541 | Train Dice: 0.7355 | Val Dice: 0.7352
# Fold 10 | Epoch 47/100 | Train Loss: 0.5147 | Val Loss: 0.5250 | Train Acc: 0.9543 | Val Acc: 0.9537 | Train Dice: 0.7315 | Val Dice: 0.7348
# Fold 10 | Epoch 48/100 | Train Loss: 0.5108 | Val Loss: 0.5370 | Train Acc: 0.9550 | Val Acc: 0.9551 | Train Dice: 0.7340 | Val Dice: 0.7230
# Fold 10 | Epoch 49/100 | Train Loss: 0.5166 | Val Loss: 0.5172 | Train Acc: 0.9534 | Val Acc: 0.9548 | Train Dice: 0.7338 | Val Dice: 0.7389
# Fold 10 | Epoch 50/100 | Train Loss: 0.5165 | Val Loss: 0.5194 | Train Acc: 0.9552 | Val Acc: 0.9534 | Train Dice: 0.7312 | Val Dice: 0.7400
# Fold 10 | Epoch 51/100 | Train Loss: 0.5021 | Val Loss: 0.5268 | Train Acc: 0.9561 | Val Acc: 0.9560 | Train Dice: 0.7437 | Val Dice: 0.7296
# Fold 10 | Epoch 52/100 | Train Loss: 0.5129 | Val Loss: 0.5156 | Train Acc: 0.9548 | Val Acc: 0.9559 | Train Dice: 0.7330 | Val Dice: 0.7403
# Fold 10 | Epoch 53/100 | Train Loss: 0.4957 | Val Loss: 0.5233 | Train Acc: 0.9578 | Val Acc: 0.9562 | Train Dice: 0.7428 | Val Dice: 0.7319
# Fold 10 | Epoch 54/100 | Train Loss: 0.4978 | Val Loss: 0.5211 | Train Acc: 0.9564 | Val Acc: 0.9543 | Train Dice: 0.7441 | Val Dice: 0.7367
# Fold 10 | Epoch 55/100 | Train Loss: 0.4947 | Val Loss: 0.5283 | Train Acc: 0.9582 | Val Acc: 0.9504 | Train Dice: 0.7450 | Val Dice: 0.7358
# Fold 10 | Epoch 56/100 | Train Loss: 0.4969 | Val Loss: 0.5109 | Train Acc: 0.9570 | Val Acc: 0.9558 | Train Dice: 0.7421 | Val Dice: 0.7422
# Fold 10 | Epoch 57/100 | Train Loss: 0.5040 | Val Loss: 0.5161 | Train Acc: 0.9552 | Val Acc: 0.9558 | Train Dice: 0.7421 | Val Dice: 0.7373
# Fold 10 | Epoch 58/100 | Train Loss: 0.4928 | Val Loss: 0.5144 | Train Acc: 0.9576 | Val Acc: 0.9543 | Train Dice: 0.7482 | Val Dice: 0.7418
# Fold 10 | Epoch 59/100 | Train Loss: 0.5068 | Val Loss: 0.5112 | Train Acc: 0.9549 | Val Acc: 0.9545 | Train Dice: 0.7381 | Val Dice: 0.7420
# Fold 10 | Epoch 60/100 | Train Loss: 0.4952 | Val Loss: 0.5124 | Train Acc: 0.9552 | Val Acc: 0.9563 | Train Dice: 0.7456 | Val Dice: 0.7389
# Fold 10 | Epoch 61/100 | Train Loss: 0.4868 | Val Loss: 0.5187 | Train Acc: 0.9590 | Val Acc: 0.9524 | Train Dice: 0.7495 | Val Dice: 0.7416
# Fold 10 | Epoch 62/100 | Train Loss: 0.4946 | Val Loss: 0.5058 | Train Acc: 0.9566 | Val Acc: 0.9558 | Train Dice: 0.7476 | Val Dice: 0.7442
# Fold 10 | Epoch 63/100 | Train Loss: 0.4893 | Val Loss: 0.5026 | Train Acc: 0.9566 | Val Acc: 0.9561 | Train Dice: 0.7489 | Val Dice: 0.7456
# Fold 10 | Epoch 64/100 | Train Loss: 0.4873 | Val Loss: 0.5105 | Train Acc: 0.9576 | Val Acc: 0.9549 | Train Dice: 0.7480 | Val Dice: 0.7410
# Fold 10 | Epoch 65/100 | Train Loss: 0.4870 | Val Loss: 0.5050 | Train Acc: 0.9578 | Val Acc: 0.9546 | Train Dice: 0.7520 | Val Dice: 0.7448
# Fold 10 | Epoch 66/100 | Train Loss: 0.4804 | Val Loss: 0.5003 | Train Acc: 0.9582 | Val Acc: 0.9567 | Train Dice: 0.7548 | Val Dice: 0.7456
# Fold 10 | Epoch 67/100 | Train Loss: 0.4819 | Val Loss: 0.5068 | Train Acc: 0.9579 | Val Acc: 0.9551 | Train Dice: 0.7530 | Val Dice: 0.7426
# Fold 10 | Epoch 68/100 | Train Loss: 0.4827 | Val Loss: 0.5049 | Train Acc: 0.9579 | Val Acc: 0.9545 | Train Dice: 0.7534 | Val Dice: 0.7458
# Fold 10 | Epoch 69/100 | Train Loss: 0.4775 | Val Loss: 0.5025 | Train Acc: 0.9588 | Val Acc: 0.9558 | Train Dice: 0.7574 | Val Dice: 0.7453
# Fold 10 | Epoch 70/100 | Train Loss: 0.4775 | Val Loss: 0.5139 | Train Acc: 0.9578 | Val Acc: 0.9565 | Train Dice: 0.7538 | Val Dice: 0.7347
# Fold 10 | Epoch 71/100 | Train Loss: 0.4771 | Val Loss: 0.5029 | Train Acc: 0.9587 | Val Acc: 0.9546 | Train Dice: 0.7531 | Val Dice: 0.7478
# Fold 10 | Epoch 72/100 | Train Loss: 0.4899 | Val Loss: 0.5024 | Train Acc: 0.9575 | Val Acc: 0.9552 | Train Dice: 0.7481 | Val Dice: 0.7483
# Fold 10 | Epoch 73/100 | Train Loss: 0.4721 | Val Loss: 0.5129 | Train Acc: 0.9587 | Val Acc: 0.9569 | Train Dice: 0.7577 | Val Dice: 0.7343
# Fold 10 | Epoch 74/100 | Train Loss: 0.4762 | Val Loss: 0.5144 | Train Acc: 0.9594 | Val Acc: 0.9519 | Train Dice: 0.7544 | Val Dice: 0.7417
# Fold 10 | Epoch 75/100 | Train Loss: 0.4756 | Val Loss: 0.5019 | Train Acc: 0.9593 | Val Acc: 0.9571 | Train Dice: 0.7572 | Val Dice: 0.7435
# Fold 10 | Epoch 76/100 | Train Loss: 0.4750 | Val Loss: 0.5003 | Train Acc: 0.9583 | Val Acc: 0.9563 | Train Dice: 0.7572 | Val Dice: 0.7454
# Fold 10 | Epoch 77/100 | Train Loss: 0.4821 | Val Loss: 0.4985 | Train Acc: 0.9583 | Val Acc: 0.9554 | Train Dice: 0.7556 | Val Dice: 0.7488
# Fold 10 | Epoch 78/100 | Train Loss: 0.4662 | Val Loss: 0.5063 | Train Acc: 0.9594 | Val Acc: 0.9561 | Train Dice: 0.7616 | Val Dice: 0.7400
# Fold 10 | Epoch 79/100 | Train Loss: 0.4705 | Val Loss: 0.5024 | Train Acc: 0.9588 | Val Acc: 0.9546 | Train Dice: 0.7577 | Val Dice: 0.7454
# Fold 10 | Epoch 80/100 | Train Loss: 0.4653 | Val Loss: 0.4946 | Train Acc: 0.9598 | Val Acc: 0.9565 | Train Dice: 0.7647 | Val Dice: 0.7493
# Fold 10 | Epoch 81/100 | Train Loss: 0.4643 | Val Loss: 0.4988 | Train Acc: 0.9598 | Val Acc: 0.9567 | Train Dice: 0.7652 | Val Dice: 0.7450
# Fold 10 | Epoch 82/100 | Train Loss: 0.4616 | Val Loss: 0.4978 | Train Acc: 0.9601 | Val Acc: 0.9565 | Train Dice: 0.7651 | Val Dice: 0.7449
# Fold 10 | Epoch 83/100 | Train Loss: 0.4629 | Val Loss: 0.5002 | Train Acc: 0.9601 | Val Acc: 0.9543 | Train Dice: 0.7636 | Val Dice: 0.7486
# Fold 10 | Epoch 84/100 | Train Loss: 0.4672 | Val Loss: 0.4948 | Train Acc: 0.9596 | Val Acc: 0.9576 | Train Dice: 0.7625 | Val Dice: 0.7474
# Fold 10 | Epoch 85/100 | Train Loss: 0.4613 | Val Loss: 0.4928 | Train Acc: 0.9602 | Val Acc: 0.9582 | Train Dice: 0.7638 | Val Dice: 0.7484
# Fold 10 | Epoch 86/100 | Train Loss: 0.4618 | Val Loss: 0.5050 | Train Acc: 0.9611 | Val Acc: 0.9537 | Train Dice: 0.7630 | Val Dice: 0.7442
# Fold 10 | Epoch 87/100 | Train Loss: 0.4589 | Val Loss: 0.4912 | Train Acc: 0.9605 | Val Acc: 0.9573 | Train Dice: 0.7655 | Val Dice: 0.7501
# Fold 10 | Epoch 88/100 | Train Loss: 0.4612 | Val Loss: 0.4920 | Train Acc: 0.9601 | Val Acc: 0.9570 | Train Dice: 0.7659 | Val Dice: 0.7496
# Fold 10 | Epoch 89/100 | Train Loss: 0.4551 | Val Loss: 0.5014 | Train Acc: 0.9608 | Val Acc: 0.9563 | Train Dice: 0.7678 | Val Dice: 0.7429
# Fold 10 | Epoch 90/100 | Train Loss: 0.4537 | Val Loss: 0.4953 | Train Acc: 0.9611 | Val Acc: 0.9553 | Train Dice: 0.7681 | Val Dice: 0.7496
# Fold 10 | Epoch 91/100 | Train Loss: 0.4547 | Val Loss: 0.4999 | Train Acc: 0.9613 | Val Acc: 0.9573 | Train Dice: 0.7702 | Val Dice: 0.7417
# Fold 10 | Epoch 92/100 | Train Loss: 0.4615 | Val Loss: 0.5011 | Train Acc: 0.9597 | Val Acc: 0.9540 | Train Dice: 0.7683 | Val Dice: 0.7469
# Fold 10 | Epoch 93/100 | Train Loss: 0.4535 | Val Loss: 0.4892 | Train Acc: 0.9617 | Val Acc: 0.9567 | Train Dice: 0.7683 | Val Dice: 0.7528
# Fold 10 | Epoch 94/100 | Train Loss: 0.4495 | Val Loss: 0.4942 | Train Acc: 0.9617 | Val Acc: 0.9573 | Train Dice: 0.7735 | Val Dice: 0.7464
# Fold 10 | Epoch 95/100 | Train Loss: 0.4495 | Val Loss: 0.4863 | Train Acc: 0.9613 | Val Acc: 0.9576 | Train Dice: 0.7717 | Val Dice: 0.7524
# Fold 10 | Epoch 96/100 | Train Loss: 0.4504 | Val Loss: 0.5133 | Train Acc: 0.9613 | Val Acc: 0.9512 | Train Dice: 0.7739 | Val Dice: 0.7428
# Fold 10 | Epoch 97/100 | Train Loss: 0.4520 | Val Loss: 0.4904 | Train Acc: 0.9610 | Val Acc: 0.9573 | Train Dice: 0.7688 | Val Dice: 0.7499
# Fold 10 | Epoch 98/100 | Train Loss: 0.4590 | Val Loss: 0.4965 | Train Acc: 0.9601 | Val Acc: 0.9580 | Train Dice: 0.7678 | Val Dice: 0.7438
# Fold 10 | Epoch 99/100 | Train Loss: 0.4486 | Val Loss: 0.4968 | Train Acc: 0.9618 | Val Acc: 0.9547 | Train Dice: 0.7727 | Val Dice: 0.7501
# Fold 10 | Epoch 100/100 | Train Loss: 0.4545 | Val Loss: 0.5054 | Train Acc: 0.9609 | Val Acc: 0.9528 | Train Dice: 0.7697 | Val Dice: 0.7460

# %%
# === FINAL EVALUATION ===
final_metrics = evaluate_test(model, val_loader, device)


fold_results.append({
    "metrics": final_metrics,
    "history": history
})

# %%
save_path_bobot = os.path.join(
    save_dir,
    f"DRIVE_model_bobot_resASPP_Unet_paper_aug_fold{fold+1}.pth"
)

torch.save({
    'model_state_dict': model.state_dict(),
    'metrics': final_metrics,
    'history': history
}, save_path_bobot)

print(f"✅ Model + history fold {fold+1} disimpan di:")
print(save_path_bobot)
# Out:
# ✅ Model + history fold 10 disimpan di:
# /content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_bobot_resASPP_Unet_paper_aug_fold10.pth

# %%
model = ResASPP_UNet()
path = "/content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_bobot_resASPP_Unet_paper_aug_fold10.pth"
checkpoint = torch.load(path, map_location=device)

model.load_state_dict(checkpoint['model_state_dict'])

model.to(device)
model.eval()

# optional
print(checkpoint['metrics'])
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# {'loss': 0.5054463744163513, 'Accuracy': 0.9528484344464248, 'Sensitivity': 0.792373343793413, 'Specificity': 0.9682135952746367, 'Dice': 0.7459710836410522, 'IoU': 0.5949124097824097}

# %%
import matplotlib.pyplot as plt

def plot_history(history):
    plt.figure(figsize=(18, 5))


    # Plot Loss
    plt.subplot(1,3,1)
    plt.plot(history['train_loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Val Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Plot Accuracy
    plt.subplot(1,3,2)
    plt.plot(history['train_acc'], label='Train Accuracy')
    plt.plot(history['val_acc'], label='Val Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Dice Score
    plt.subplot(1, 3, 3)
    plt.plot(history['train_dice'], label='Train Dice', color='blue')
    plt.plot(history['val_dice'], label='Val Dice', color='orange')
    plt.title('Dice Score per Epoch')
    plt.xlabel('Epoch')
    plt.ylabel('Dice')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# %%
# === Tampilkan model summary ===
from torchinfo import summary # Import summary
print("Model Summary:")
summary(
    model,
    input_size=(1, 1, 512, 512),  # (batch, channels, H, W) - Adjusted for single channel green image and common size for DRIVE
    col_names=["input_size", "output_size", "num_params", "kernel_size", "mult_adds"],
    col_width=20,
    row_settings=["var_names"]
)
# Out:
# Model Summary:
# =================================================================================================================================================
# Layer (type (var_name))                       Input Shape          Output Shape         Param #              Kernel Shape         Mult-Adds
# =================================================================================================================================================
# ResASPP_UNet (ResASPP_UNet)                   [1, 1, 512, 512]     [1, 1, 512, 512]     --                   --                   --
# ├─DeepLabEncoder (encoder)                    [1, 1, 512, 512]     [1, 256, 128, 128]   --                   --                   --
# │    └─Sequential (initial)                   [1, 1, 512, 512]     [1, 64, 128, 128]    --                   --                   --
# │    │    └─Conv2d (0)                        [1, 1, 512, 512]     [1, 64, 256, 256]    3,136                [7, 7]               205,520,896
# │    │    └─BatchNorm2d (1)                   [1, 64, 256, 256]    [1, 64, 256, 256]    128                  --                   128
# │    │    └─ReLU (2)                          [1, 64, 256, 256]    [1, 64, 256, 256]    --                   --                   --
# │    │    └─MaxPool2d (3)                     [1, 64, 256, 256]    [1, 64, 128, 128]    --                   3                    --
# │    └─Sequential (layer1)                    [1, 64, 128, 128]    [1, 256, 128, 128]   --                   --                   --
# │    │    └─Bottleneck (0)                    [1, 64, 128, 128]    [1, 256, 128, 128]   75,008               --                   1,207,960,832
# │    │    └─Bottleneck (1)                    [1, 256, 128, 128]   [1, 256, 128, 128]   70,400               --                   1,140,851,456
# │    │    └─Bottleneck (2)                    [1, 256, 128, 128]   [1, 256, 128, 128]   70,400               --                   1,140,851,456
# │    └─Sequential (layer2)                    [1, 256, 128, 128]   [1, 512, 64, 64]     --                   --                   --
# │    │    └─Bottleneck (0)                    [1, 256, 128, 128]   [1, 512, 64, 64]     379,392              --                   1,946,159,616
# │    │    └─Bottleneck (1)                    [1, 512, 64, 64]     [1, 512, 64, 64]     280,064              --                   1,140,852,224
# │    │    └─Bottleneck (2)                    [1, 512, 64, 64]     [1, 512, 64, 64]     280,064              --                   1,140,852,224
# │    │    └─Bottleneck (3)                    [1, 512, 64, 64]     [1, 512, 64, 64]     280,064              --                   1,140,852,224
# │    └─Sequential (layer3)                    [1, 512, 64, 64]     [1, 1024, 32, 32]    --                   --                   --
# │    │    └─Bottleneck (0)                    [1, 512, 64, 64]     [1, 1024, 32, 32]    1,512,448            --                   1,946,162,176
# │    │    └─Bottleneck (1)                    [1, 1024, 32, 32]    [1, 1024, 32, 32]    1,117,184            --                   1,140,853,760
# │    │    └─Bottleneck (2)                    [1, 1024, 32, 32]    [1, 1024, 32, 32]    1,117,184            --                   1,140,853,760
# │    │    └─Bottleneck (3)                    [1, 1024, 32, 32]    [1, 1024, 32, 32]    1,117,184            --                   1,140,853,760
# │    │    └─Bottleneck (4)                    [1, 1024, 32, 32]    [1, 1024, 32, 32]    1,117,184            --                   1,140,853,760
# │    │    └─Bottleneck (5)                    [1, 1024, 32, 32]    [1, 1024, 32, 32]    1,117,184            --                   1,140,853,760
# │    └─Sequential (layer4)                    [1, 1024, 32, 32]    [1, 2048, 16, 16]    --                   --                   --
# │    │    └─Bottleneck (0)                    [1, 1024, 32, 32]    [1, 2048, 16, 16]    6,039,552            --                   1,946,167,296
# │    │    └─Bottleneck (1)                    [1, 2048, 16, 16]    [1, 2048, 16, 16]    4,462,592            --                   1,140,856,832
# │    │    └─Bottleneck (2)                    [1, 2048, 16, 16]    [1, 2048, 16, 16]    4,462,592            --                   1,140,856,832
# ├─ASPP (aspp)                                 [1, 2048, 16, 16]    [1, 256, 16, 16]     --                   --                   --
# │    └─Conv2d (atrous1)                       [1, 2048, 16, 16]    [1, 256, 16, 16]     524,544              [1, 1]               134,283,264
# │    └─Conv2d (atrous6)                       [1, 2048, 16, 16]    [1, 256, 16, 16]     4,718,848            [3, 3]               1,208,025,088
# │    └─Conv2d (atrous12)                      [1, 2048, 16, 16]    [1, 256, 16, 16]     4,718,848            [3, 3]               1,208,025,088
# │    └─Conv2d (atrous18)                      [1, 2048, 16, 16]    [1, 256, 16, 16]     4,718,848            [3, 3]               1,208,025,088
# │    └─Sequential (global_pool)               [1, 2048, 16, 16]    [1, 256, 1, 1]       --                   --                   --
# │    │    └─AdaptiveAvgPool2d (0)             [1, 2048, 16, 16]    [1, 2048, 1, 1]      --                   --                   --
# │    │    └─Conv2d (1)                        [1, 2048, 1, 1]      [1, 256, 1, 1]       524,544              [1, 1]               524,544
# │    │    └─ReLU (2)                          [1, 256, 1, 1]       [1, 256, 1, 1]       --                   --                   --
# │    └─Conv2d (conv_out)                      [1, 1280, 16, 16]    [1, 256, 16, 16]     327,936              [1, 1]               83,951,616
# ├─UNetDecoder (decoder)                       [1, 256, 16, 16]     [1, 1, 512, 512]     --                   --                   --
# │    └─Sequential (up1)                       [1, 2304, 32, 32]    [1, 256, 32, 32]     --                   --                   --
# │    │    └─Conv2d (0)                        [1, 2304, 32, 32]    [1, 256, 32, 32]     5,308,672            [3, 3]               5,436,080,128
# │    │    └─ReLU (1)                          [1, 256, 32, 32]     [1, 256, 32, 32]     --                   --                   --
# │    │    └─Conv2d (2)                        [1, 256, 32, 32]     [1, 256, 32, 32]     590,080              [3, 3]               604,241,920
# │    │    └─ReLU (3)                          [1, 256, 32, 32]     [1, 256, 32, 32]     --                   --                   --
# │    └─Sequential (up2)                       [1, 1280, 64, 64]    [1, 128, 64, 64]     --                   --                   --
# │    │    └─Conv2d (0)                        [1, 1280, 64, 64]    [1, 128, 64, 64]     1,474,688            [3, 3]               6,040,322,048
# │    │    └─ReLU (1)                          [1, 128, 64, 64]     [1, 128, 64, 64]     --                   --                   --
# │    │    └─Conv2d (2)                        [1, 128, 64, 64]     [1, 128, 64, 64]     147,584              [3, 3]               604,504,064
# │    │    └─ReLU (3)                          [1, 128, 64, 64]     [1, 128, 64, 64]     --                   --                   --
# │    └─Sequential (up3)                       [1, 640, 128, 128]   [1, 64, 128, 128]    --                   --                   --
# │    │    └─Conv2d (0)                        [1, 640, 128, 128]   [1, 64, 128, 128]    368,704              [3, 3]               6,040,846,336
# │    │    └─ReLU (1)                          [1, 64, 128, 128]    [1, 64, 128, 128]    --                   --                   --
# │    │    └─Conv2d (2)                        [1, 64, 128, 128]    [1, 64, 128, 128]    36,928               [3, 3]               605,028,352
# │    │    └─ReLU (3)                          [1, 64, 128, 128]    [1, 64, 128, 128]    --                   --                   --
# │    └─Sequential (up4)                       [1, 320, 256, 256]   [1, 32, 256, 256]    --                   --                   --
# │    │    └─Conv2d (0)                        [1, 320, 256, 256]   [1, 32, 256, 256]    92,192               [3, 3]               6,041,894,912
# │    │    └─ReLU (1)                          [1, 32, 256, 256]    [1, 32, 256, 256]    --                   --                   --
# │    │    └─Conv2d (2)                        [1, 32, 256, 256]    [1, 32, 256, 256]    9,248                [3, 3]               606,076,928
# │    │    └─ReLU (3)                          [1, 32, 256, 256]    [1, 32, 256, 256]    --                   --                   --
# │    └─Conv2d (final)                         [1, 32, 512, 512]    [1, 1, 512, 512]     33                   [1, 1]               8,650,752
# =================================================================================================================================================
# Total params: 47,063,457
# Trainable params: 47,063,457
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 50.77
# =================================================================================================================================================
# Input size (MB): 1.05
# Forward/backward pass size (MB): 996.67
# Params size (MB): 188.25
# Estimated Total Size (MB): 1185.98
# =================================================================================================================================================

# %%
save_path = '/content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_ab_resASPP_Unet_paper_aug.pth'
torch.save(model, save_path)

print(f"Model disimpan di: {save_path}")
# Out:
# Model disimpan di: /content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_ab_resASPP_Unet_paper_aug.pth

# %%
save_path_bobot = "/content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_bobot_resASPP_Unet_paper_aug.pth"
torch.save(model.state_dict(), save_path_bobot)
print("Saved to:", save_path_bobot)
# Out:
# Saved to: /content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_bobot_resASPP_Unet_paper_aug.pth

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Pastikan cell definisi class ResASPP_UNet sudah dijalankan sebelumnya
with torch.serialization.safe_globals([ResASPP_UNet]):
    model = torch.load("/content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_ab_resASPP_Unet_paper_aug.pth",
                       map_location=device, weights_only=False)

model.eval()
print("✅ Model berhasil dimuat tanpa file .py terpisah.")
# Out:
# ✅ Model berhasil dimuat tanpa file .py terpisah.

# %%
# Make sure the cell defining plot_history is run before this cell.
plot_history(history)

# %%
#Visualisasi Prediksi
def visualize_prediction(model, dataset, index=0, device='cuda'): # Add device as an argument with default 'cuda'
    model.eval()
    image, true_mask = dataset[index]
    image_input = image.unsqueeze(0).to(device)

    with torch.no_grad():
        pred_mask = model(image_input)
        pred_mask = (pred_mask.squeeze().cpu().numpy() > 0.5).astype(float)

    image_np = image.permute(1, 2, 0).numpy()
    true_mask_np = true_mask.squeeze().numpy()

    plt.figure(figsize=(12, 4))

    plt.subplot(1, 3, 1)
    plt.imshow(image_np)
    plt.title("Input Image")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(true_mask_np, cmap='gray')
    plt.title("Ground Truth Mask")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask, cmap='gray')
    plt.title("Predicted Mask")
    plt.axis("off")

    plt.tight_layout()
    plt.show()

# %%
visualize_prediction(model, val_dataset, index=0)

# %%
print(len(test_dataset.image_paths))
print(len(test_dataset.mask_paths))
# Out:
# 20
# 20

# %%
visualize_prediction(model, test_dataset, index=0)

# %%
def visualize_prediction(model, dataset, index=0):
    import torch
    import matplotlib.pyplot as plt

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()

    img, mask = dataset[index]  # img: (C,H,W)

    img_tensor = img.unsqueeze(0).to(device)  # pindah ke GPU

    with torch.no_grad():
        pred = model(img_tensor)

    pred = pred.squeeze().cpu().numpy()  # balik ke CPU untuk numpy
    img_np = img.permute(1,2,0).cpu().numpy()
    mask_np = mask.squeeze().cpu().numpy()

    plt.figure(figsize=(12,4))

    plt.subplot(1,3,1)
    plt.title("Input Image")
    plt.imshow(img_np)

    plt.subplot(1,3,2)
    plt.title("Ground Truth")
    plt.imshow(mask_np, cmap='gray')

    plt.subplot(1,3,3)
    plt.title("Prediction")
    plt.imshow(pred > 0.5, cmap='gray')

    plt.show()

# %%
visualize_prediction(model, val_dataset, index=0)

# %%
import numpy as np

# Process fold_results to get a consistent list of metric dictionaries for averaging
processed_metrics = []
for fold_res in fold_results:
    if isinstance(fold_res, dict) and "metrics" in fold_res and isinstance(fold_res["metrics"], dict):
        processed_metrics.append(fold_res["metrics"])
    elif isinstance(fold_res, dict) and "loss" in fold_res: # Assuming 'loss' is a key present in direct metric dicts
        processed_metrics.append(fold_res)


print("\n=== CROSS VALIDATION RESULT ===")
if not processed_metrics:
    print("No valid metric dictionaries found in fold_results to average.")
else:
    # Use the keys from the first processed metric dictionary for averaging
    # This assumes all metric dictionaries have the same set of keys
    avg_results = {
        k: np.mean([res[k] for res in processed_metrics])
        for k in processed_metrics[0]
    }

    for k, v in avg_results.items():
        print(f"{k}: {v:.4f}")
# Out:
# === CROSS VALIDATION RESULT ===
# loss: 0.5196
# Accuracy: 0.9526
# Sensitivity: 0.7590
# Specificity: 0.9711
# Dice: 0.7363
# IoU: 0.5829
