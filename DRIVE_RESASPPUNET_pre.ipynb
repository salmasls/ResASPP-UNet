# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install albumentations opencv-python
# Out:
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (2.0.8)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.13.0.92)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.12/dist-packages (from albumentations) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from albumentations) (1.16.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from albumentations) (6.0.3)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations) (2.12.3)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations) (4.13.0.92)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (4.6.0)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (6.5.16)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.4.2)

# %%
import os
import glob
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

# %%
def preprocess_green_clahe(image):
    green = image[:, :, 1]

    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    enhanced = clahe.apply(green)

    # jadi 1 channel
    enhanced = np.expand_dims(enhanced, axis=-1)
    return enhanced

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2

train_transform = A.Compose([
    A.Resize(512, 512),
    A.HorizontalFlip(p=0.7),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.7),
    A.RandomBrightnessContrast(p=0.7),
    A.Normalize(mean=(0.5,), std=(0.5,)),  # untuk 1 channel
    ToTensorV2()
])

test_transform = A.Compose([
    A.Resize(512, 512),
    A.Normalize(mean=(0.5,), std=(0.5,)),
    ToTensorV2()
])

# %%
import cv2
import numpy as np
from torch.utils.data import Dataset
from PIL import Image

class DRIVEDataset(Dataset):
    def __init__(self, image_paths, mask_paths, transform=None):
        self.image_paths = image_paths
        self.mask_paths = mask_paths
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        # === LOAD RGB ASLI ===
        image_rgb = cv2.imread(self.image_paths[idx])
        image_rgb = cv2.cvtColor(image_rgb, cv2.COLOR_BGR2RGB)

        # === COPY untuk model ===
        image = preprocess_green_clahe(image_rgb)

        mask = Image.open(self.mask_paths[idx]).convert("L")
        mask = np.array(mask)
        mask = (mask > 0).astype(np.float32)

        if self.transform:
            augmented = self.transform(image=image, mask=mask)
            image = augmented['image']
            mask  = augmented['mask']

        if mask.ndim == 2:
            mask = mask.unsqueeze(0)

        #  RETURN TAMBAHAN RGB
        return image, mask, image_rgb

# %%
# Direktori input dan output
img_dir = "/content/drive/MyDrive/Colab Notebooks/DRIVE/training/images"
mask_dir = "/content/drive/MyDrive/Colab Notebooks/DRIVE/training/1st_manual"


from glob import glob
import os

train_imgs = sorted(glob(os.path.join(img_dir, "*.tif")))
train_masks = sorted(glob(os.path.join(mask_dir, "*.gif")))

test_imgs = sorted(glob("/content/drive/MyDrive/Colab Notebooks/DRIVE/test/images/*.tif"))
test_masks = sorted(glob("/content/drive/MyDrive/Colab Notebooks/DRIVE/test/mask/*.gif"))

# %%
print("Train images:", len(train_imgs))
print("Train masks:", len(train_masks))
print("Test images:", len(test_imgs))
print("Test masks:", len(test_masks))
# Out:
# Train images: 20
# Train masks: 20
# Test images: 20
# Test masks: 0

# %%
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader

kf = KFold(n_splits=10, shuffle=True, random_state=42)

for fold, (train_idx, val_idx) in enumerate(kf.split(train_imgs)):

    train_fold_imgs = [train_imgs[i] for i in train_idx]
    train_fold_masks = [train_masks[i] for i in train_idx]

    val_fold_imgs = [train_imgs[i] for i in val_idx]
    val_fold_masks = [train_masks[i] for i in val_idx]

    train_dataset = DRIVEDataset(
        train_fold_imgs,
        train_fold_masks,
        transform=train_transform   # AUGMENTASI DI SINI
    )

    val_dataset = DRIVEDataset(
        val_fold_imgs,
        val_fold_masks,
        transform=test_transform    # TANPA AUGMENTASI
    )

    train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=4)
    val_loader   = DataLoader(val_dataset, batch_size=4, shuffle=False)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()

# %%
test_dataset = DRIVEDataset(test_imgs, test_masks, transform=test_transform)
test_loader  = DataLoader(test_dataset, batch_size=4, shuffle=False)

# %%
print(len(train_fold_imgs), len(val_fold_imgs))
# Out:
# 18 2

# %%
import matplotlib.pyplot as plt

# ambil 1 sample dari train_dataset (yang sudah diaugmentasi)
image, mask, image_rgb = train_dataset[0]

# ubah tensor → numpy
image = image.permute(1, 2, 0).cpu().numpy()
mask = mask.squeeze().cpu().numpy()

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(image, cmap='gray' if image.shape[2]==1 else None)
plt.title("Augmented Image")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(mask, cmap='gray')
plt.title("Mask")
plt.axis('off')

plt.show()

# %%
# === HITUNG JUMLAH DATA TRAINING & VALIDATION ===
print("========================================")
# Define all_files by combining training and test image paths
all_files = train_imgs + test_imgs
print("Jumlah total data:", len(all_files))
print("Jumlah data training :", len(train_dataset))
print("Jumlah data validation :", len(val_dataset))
print("Jumlah data test :", len(test_dataset))
print("========================================")
# Out:
# ========================================
# Jumlah total data: 40
# Jumlah data training : 18
# Jumlah data validation : 2
# Jumlah data test : 20
# ========================================

# %%
# === LOAD IMAGE ===
img = cv2.imread("/content/drive/MyDrive/Colab Notebooks/DRIVE/training/images/21_training.tif")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# === PREPROCESSING ===
preprocessed = preprocess_green_clahe(img)

if preprocessed.ndim == 2:
    preprocessed = preprocessed[..., None]

# === LOAD MASK ===
mask = cv2.imread("/content/drive/MyDrive/Colab Notebooks/DRIVE/training/1st_manual/21_manual1.gif", cv2.IMREAD_GRAYSCALE)
mask = (mask > 0).astype("float32")
mask = mask[..., None]

# === AUGMENTATION ===
augmented = train_transform(image=preprocessed, mask=mask)

aug_img = augmented["image"]
aug_mask = augmented["mask"]

# === CONVERT UNTUK VISUALISASI ===
aug_img_np = aug_img.permute(1, 2, 0).cpu().numpy()
aug_mask_np = aug_mask.squeeze().cpu().numpy()

# === PLOT ===
plt.figure(figsize=(18, 6))

plt.subplot(1, 4, 1)
plt.imshow(img)
plt.title("Original")
plt.axis("off")

plt.subplot(1, 4, 2)
plt.imshow(preprocessed.squeeze(), cmap='gray')
plt.title("Preprocessing (Green + CLAHE)")
plt.axis("off")

plt.subplot(1, 4, 3)
plt.imshow(aug_img_np.squeeze(), cmap='gray')
plt.title("Augmented Image")
plt.axis("off")

plt.subplot(1, 4, 4)
plt.imshow(aug_mask_np, cmap='gray')
plt.title("Augmented Mask")
plt.axis("off")

plt.show()

# %%
batch = next(iter(train_loader))
imgs, masks, imgs_rgb = batch

img = imgs[0]
mask = masks[0]

img_np = img.permute(1, 2, 0).cpu().numpy()
mask_np = mask.squeeze().cpu().numpy()

# undo normalize
mean = 0.5
std = 0.5
img_np = (img_np * std) + mean
img_np = np.clip(img_np, 0, 1)

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
if img_np.shape[2] == 1:
    plt.imshow(img_np.squeeze(), cmap='gray')
else:
    plt.imshow(img_np)
plt.title("Sample Image (DataLoader)")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(mask_np, cmap="gray")
plt.title("Mask")
plt.axis("off")

plt.show()

# %%
image, mask, image_rgb = train_dataset[0]
print(image.shape)
# Out:
# torch.Size([1, 512, 512])

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models

# === DeepLabV3 Encoder: ResNet Backbone ===
class DeepLabEncoder(nn.Module):
    def __init__(self):
        super().__init__()
        resnet = models.resnet50(pretrained=True)
        resnet.conv1 = nn.Conv2d(
            1, 64, kernel_size=7, stride=2, padding=3, bias=False
        )
        self.initial = nn.Sequential(
            resnet.conv1,
            resnet.bn1,
            resnet.relu,
            resnet.maxpool
        )

        self.layer1 = resnet.layer1  # 256  # CHANGED (comment)
        self.layer2 = resnet.layer2  # 512  # CHANGED (comment)
        self.layer3 = resnet.layer3  # 1024 # CHANGED (comment)
        self.layer4 = resnet.layer4  # 2048 # CHANGED (comment)

    def forward(self, x):
        x0 = self.initial(x)
        x1 = self.layer1(x0)  # 256
        x2 = self.layer2(x1)  # 512
        x3 = self.layer3(x2)  # 1024
        x4 = self.layer4(x3)  # 2048
        return x1, x2, x3, x4


# === ASPP Module ===
class ASPP(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.atrous1 = nn.Conv2d(in_channels, out_channels, 1, padding=0, dilation=1)
        self.atrous6 = nn.Conv2d(in_channels, out_channels, 3, padding=6, dilation=6)
        self.atrous12 = nn.Conv2d(in_channels, out_channels, 3, padding=12, dilation=12)
        self.atrous18 = nn.Conv2d(in_channels, out_channels, 3, padding=18, dilation=18)
        self.global_pool = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(in_channels, out_channels, 1),
            nn.ReLU()
        )
        self.conv_out = nn.Conv2d(out_channels * 5, out_channels, 1)

    def forward(self, x):
        size = x.shape[2:]
        f1 = self.atrous1(x)
        f2 = self.atrous6(x)
        f3 = self.atrous12(x)
        f4 = self.atrous18(x)
        f5 = self.global_pool(x)
        f5 = F.interpolate(f5, size=size, mode='bilinear', align_corners=False)
        x = torch.cat([f1, f2, f3, f4, f5], dim=1)
        return self.conv_out(x)


class UNetDecoder(nn.Module):
    def __init__(self):
        super().__init__()

        # Correct skip channels for ResNet50
        # bridge (ASPP) out_channels = 256
        # x4 = 2048, x3 = 1024, x2 = 512, x1 = 256
        self.up1 = self.block(256, 2048, 256)  # bridge + x4
        self.up2 = self.block(256, 1024, 128)  # up1 + x3
        self.up3 = self.block(128, 512, 64)    # up2 + x2
        self.up4 = self.block(64, 256, 32)     # up3 + x1

        self.final = nn.Conv2d(32, 1, 1)

    def block(self, in_channels, skip_channels, out_channels):
        return nn.Sequential(
            nn.Conv2d(in_channels + skip_channels, out_channels, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, 3, padding=1),
            nn.ReLU(inplace=True),
        )

    def forward(self, x, skips):
        x1, x2, x3, x4 = skips

        # === UP 1 === (bridge + x4)
        x = F.interpolate(x, scale_factor=2, mode='bilinear', align_corners=False)
        if x4.shape[2:] != x.shape[2:]:
            x4 = F.interpolate(x4, size=x.shape[2:], mode='bilinear', align_corners=False)
        x = self.up1(torch.cat([x, x4], dim=1))

        # === UP 2 === (up1 + x3)
        x = F.interpolate(x, scale_factor=2, mode='bilinear', align_corners=False)
        if x3.shape[2:] != x.shape[2:]:
            x3 = F.interpolate(x3, size=x.shape[2:], mode='bilinear', align_corners=False)
        x = self.up2(torch.cat([x, x3], dim=1))

        # === UP 3 === (up2 + x2)
        x = F.interpolate(x, scale_factor=2, mode='bilinear', align_corners=False)
        if x2.shape[2:] != x.shape[2:]:
            x2 = F.interpolate(x2, size=x.shape[2:], mode='bilinear', align_corners=False)
        x = self.up3(torch.cat([x, x2], dim=1))

        # === UP 4 === (up3 + x1)
        x = F.interpolate(x, scale_factor=2, mode='bilinear', align_corners=False)
        if x1.shape[2:] != x.shape[2:]:
            x1 = F.interpolate(x1, size=x.shape[2:], mode='bilinear', align_corners=False)
        x = self.up4(torch.cat([x, x1], dim=1))

        x = F.interpolate(x, size=(512, 512), mode='bilinear', align_corners=False)

        return self.final(x)


# === Hybrid Model ===
class ResASPP_UNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = DeepLabEncoder()
        self.aspp = ASPP(2048, 256)
        self.decoder = UNetDecoder()

    def forward(self, x):
        x1, x2, x3, x4 = self.encoder(x)
        bridge = self.aspp(x4)
        out = self.decoder(bridge, [x1, x2, x3, x4])  # CHANGED
        return out

# %%
import torch.nn as nn
import torch.nn.functional as F

class DiceLoss(nn.Module):
    def __init__(self, smooth=1e-6):
        super().__init__()
        self.smooth = smooth

    def forward(self, pred, target):
        pred = torch.sigmoid(pred)
        intersection = (pred * target).sum(dim=(2,3))
        union = pred.sum(dim=(2,3)) + target.sum(dim=(2,3))
        dice = (2 * intersection + self.smooth) / (union + self.smooth)
        return 1 - dice.mean()


class BoundaryLoss(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, pred, target):
        pred = torch.sigmoid(pred)

        sobel_x = torch.tensor([[1,0,-1],[2,0,-2],[1,0,-1]],
                               dtype=torch.float32).to(pred.device).view(1,1,3,3)
        sobel_y = sobel_x.permute(0,1,3,2)

        pred_edge = F.conv2d(pred, sobel_x, padding=1) + F.conv2d(pred, sobel_y, padding=1)
        target_edge = F.conv2d(target, sobel_x, padding=1) + F.conv2d(target, sobel_y, padding=1)

        return F.l1_loss(pred_edge, target_edge)


class TopologyLoss(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, pred, target):
        pred = torch.sigmoid(pred)
        return F.binary_cross_entropy(pred, target)


class HybridLoss(nn.Module):
    def __init__(self, w_dice=1.0, w_boundary=0.5, w_topo=0.3):
        super().__init__()
        self.dice = DiceLoss()
        self.boundary = BoundaryLoss()
        self.topo = TopologyLoss()

        self.w_dice = w_dice
        self.w_boundary = w_boundary
        self.w_topo = w_topo

    def forward(self, pred, target):
        return (
            self.w_dice * self.dice(pred, target) +
            self.w_boundary * self.boundary(pred, target) +
            self.w_topo * self.topo(pred, target)
        )

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import time # Import the time module


def dice_score(preds, targets, threshold=0.5):
    preds = (preds > threshold).float()
    intersection = (preds * targets).sum()
    return (2. * intersection) / (preds.sum() + targets.sum() + 1e-8)

def accuracy_score(preds, targets, threshold=0.5):
    preds = (preds > threshold).float()
    correct = (preds == targets).float().sum()
    total = torch.numel(targets)
    return correct / total

def train_model(model, train_loader, val_loader, epochs=30, lr=1e-4, device='cuda'):
    model.to(device)
    criterion = HybridLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)

    history = {
        "train_loss": [],
        "val_loss": [],
        "train_acc": [],
        "val_acc": [],
        "train_dice": [],
        "val_dice": []
    }

    start_time = time.time()

    for epoch in range(epochs):
        model.train()
        running_loss = 0
        running_acc = 0
        running_dice = 0

        for images, masks in train_loader:
            images, masks = images.to(device), masks.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, masks)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            running_acc  += accuracy_score(outputs, masks).item()
            running_dice += dice_score(outputs, masks).item()

        train_loss = running_loss / len(train_loader)
        train_acc  = running_acc  / len(train_loader)
        train_dice = running_dice / len(train_loader)

        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['train_dice'].append(train_dice)


        # ==========================
        # VALIDATION
        # ==========================
        model.eval()
        val_loss = 0
        total_dice = 0
        total_acc = 0

        with torch.no_grad():
            for images, masks in val_loader:
                images, masks = images.to(device), masks.to(device)
                outputs = model(images)

                loss = criterion(outputs, masks)
                val_loss += loss.item()

                total_dice += dice_score(outputs, masks).item()
                total_acc  += accuracy_score(outputs, masks).item()

        val_loss /= len(val_loader)
        val_dice = total_dice / len(val_loader)
        val_acc  = total_acc  / len(val_loader)

        history['val_loss'].append(val_loss)
        history['val_dice'].append(val_dice)
        history['val_acc'].append(val_acc)

        print(f"Epoch {epoch+1}/{epochs} | "
              f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | "
              f"Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f} | "
              f"Train Dice: {train_dice:.4f} | Val Dice: {val_dice:.4f}")


    end_time = time.time() # Record the end time
    total_training_time = end_time - start_time
    print(f"\nTotal Training Time: {total_training_time:.2f} seconds")

    return model, history

# %%
import matplotlib.pyplot as plt

def plot_history(history):
    plt.figure(figsize=(18, 5))


    # Plot Loss
    plt.subplot(1,3,1)
    plt.plot(history['train_loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Val Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Plot Accuracy
    plt.subplot(1,3,2)
    plt.plot(history['train_acc'], label='Train Accuracy')
    plt.plot(history['val_acc'], label='Val Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Dice Score
    plt.subplot(1, 3, 3)
    plt.plot(history['train_dice'], label='Train Dice', color='blue')
    plt.plot(history['val_dice'], label='Val Dice', color='orange')
    plt.title('Dice Score per Epoch')
    plt.xlabel('Epoch')
    plt.ylabel('Dice')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# %%
pip install torchinfo
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.12/dist-packages (1.8.0)

# %%
def evaluate_test(model, loader, device):
    model.eval()

    total_loss = 0
    # total_dice = 0 # These are not explicitly used in the return, removed for clarity
    # total_acc  = 0 # These are not explicitly used in the return, removed for clarity

    criterion = HybridLoss()


    TP, TN, FP, FN = 0, 0, 0, 0
    dice_total, iou_total, n = 0, 0, 0

    with torch.no_grad():
        for images, masks, _ in loader:
            images, masks = images.to(device), masks.to(device)

            outputs = model(images)
            preds = (torch.sigmoid(outputs) > 0.5).float()

            loss = criterion(outputs, masks) # Calculate loss
            total_loss += loss.item() # Accumulate loss

            TP += ((preds == 1) & (masks == 1)).sum().item()
            TN += ((preds == 0) & (masks == 0)).sum().item()
            FP += ((preds == 1) & (masks == 0)).sum().item()
            FN += ((preds == 0) & (masks == 1)).sum().item()

            intersection = (preds * masks).sum(dim=(2,3))
            union = preds.sum(dim=(2,3)) + masks.sum(dim=(2,3))

            dice = (2 * intersection + 1e-6) / (union + 1e-6)
            iou = (intersection + 1e-6) / (union - intersection + 1e-6)

            dice_total += dice.mean().item()
            iou_total += iou.mean().item()
            n += 1

    return {
        "loss": total_loss / n, # Added loss to the return dictionary
        "Accuracy": (TP + TN) / (TP + TN + FP + FN + 1e-6),
        "Sensitivity": TP / (TP + FN + 1e-6),
        "Specificity": TN / (TN + FP + 1e-6),
        "Dice": dice_total / n,
        "IoU": iou_total / n
    }

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

fold_results = []

import os

# Folder penyimpanan
save_dir = "/content/drive/MyDrive/Colab Notebooks/DRIVE/"
os.makedirs(save_dir, exist_ok=True)

for fold, (train_idx, val_idx) in enumerate(kf.split(train_imgs)):
    print(f"\n===== FOLD {fold+1} ====")

    train_fold_imgs = [train_imgs[i] for i in train_idx]
    train_fold_masks = [train_masks[i] for i in train_idx]

    val_fold_imgs = [train_imgs[i] for i in val_idx]
    val_fold_masks = [train_masks[i] for i in val_idx]

    # Dataset
    train_dataset = DRIVEDataset(train_fold_imgs, train_fold_masks, transform=train_transform)
    val_dataset   = DRIVEDataset(val_fold_imgs, val_fold_masks, transform=test_transform)

    train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=4)
    val_loader   = DataLoader(val_dataset, batch_size=4, shuffle=False, num_workers=4)

    model = ResASPP_UNet().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
    criterion = HybridLoss()

    num_epochs = 100

    history = {
        "train_loss": [],
        "val_loss": [],
        "train_dice": [],
        "val_dice": [],
        "train_acc": [],
        "val_acc": []
    }

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0
        running_dice = 0
        running_acc  = 0

        for images, masks, _ in train_loader:
            images, masks = images.to(device), masks.to(device)

            outputs = model(images)
            preds = torch.sigmoid(outputs)

            loss = criterion(outputs, masks)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            running_dice += dice_score(preds, masks).item()
            running_acc  += accuracy_score(preds, masks).item()

        # === TRAIN METRICS ===
        train_loss = running_loss / len(train_loader)
        train_dice = running_dice / len(train_loader)
        train_acc  = running_acc  / len(train_loader)

        # === VALIDATION ===
        val_metrics = evaluate_test(model, val_loader, device)

        # === SIMPAN HISTORY ===
        history["train_loss"].append(train_loss)
        history["train_dice"].append(train_dice)
        history["train_acc"].append(train_acc)

        history["val_loss"].append(val_metrics["loss"])
        history["val_dice"].append(val_metrics["Dice"])
        history["val_acc"].append(val_metrics["Accuracy"])

        # === PRINT (SEPERTI train_model) ===
        print(f"Fold {fold+1} | Epoch {epoch+1}/{num_epochs} | "
              f"Train Loss: {train_loss:.4f} | Val Loss: {val_metrics['loss']:.4f} | "
              f"Train Acc: {train_acc:.4f} | Val Acc: {val_metrics['Accuracy']:.4f} | "
              f"Train Dice: {train_dice:.4f} | Val Dice: {val_metrics['Dice']:.4f}")
# Out:
# ===== FOLD 1 ====
# Fold 1 | Epoch 1/100 | Train Loss: 1.2310 | Val Loss: 1.2229 | Train Acc: 0.9130 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 2/100 | Train Loss: 1.2044 | Val Loss: 1.1717 | Train Acc: 0.9128 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 3/100 | Train Loss: 1.1262 | Val Loss: 1.2160 | Train Acc: 0.9125 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 4/100 | Train Loss: 1.0980 | Val Loss: 1.1240 | Train Acc: 0.9133 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 5/100 | Train Loss: 1.0724 | Val Loss: 1.1150 | Train Acc: 0.9140 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 6/100 | Train Loss: 1.0578 | Val Loss: 1.1639 | Train Acc: 0.9126 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 7/100 | Train Loss: 1.0413 | Val Loss: 1.0624 | Train Acc: 0.9126 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 8/100 | Train Loss: 1.0362 | Val Loss: 1.0619 | Train Acc: 0.9107 | Val Acc: 0.9194 | Train Dice: 0.0070 | Val Dice: 0.0000
# Fold 1 | Epoch 9/100 | Train Loss: 1.0097 | Val Loss: 1.0788 | Train Acc: 0.9186 | Val Acc: 0.9194 | Train Dice: 0.1177 | Val Dice: 0.0000
# Fold 1 | Epoch 10/100 | Train Loss: 0.9951 | Val Loss: 1.0071 | Train Acc: 0.9223 | Val Acc: 0.9208 | Train Dice: 0.2839 | Val Dice: 0.0402
# Fold 1 | Epoch 11/100 | Train Loss: 0.9632 | Val Loss: 0.9694 | Train Acc: 0.9260 | Val Acc: 0.9251 | Train Dice: 0.3809 | Val Dice: 0.1553
# Fold 1 | Epoch 12/100 | Train Loss: 0.9261 | Val Loss: 0.9229 | Train Acc: 0.9294 | Val Acc: 0.9321 | Train Dice: 0.4683 | Val Dice: 0.3343
# Fold 1 | Epoch 13/100 | Train Loss: 0.8836 | Val Loss: 0.8691 | Train Acc: 0.9270 | Val Acc: 0.9361 | Train Dice: 0.5287 | Val Dice: 0.5152
# Fold 1 | Epoch 14/100 | Train Loss: 0.8311 | Val Loss: 0.8045 | Train Acc: 0.9266 | Val Acc: 0.9343 | Train Dice: 0.5449 | Val Dice: 0.5688
# Fold 1 | Epoch 15/100 | Train Loss: 0.7758 | Val Loss: 0.7754 | Train Acc: 0.9257 | Val Acc: 0.9260 | Train Dice: 0.5739 | Val Dice: 0.5645
# Fold 1 | Epoch 16/100 | Train Loss: 0.7458 | Val Loss: 0.7129 | Train Acc: 0.9269 | Val Acc: 0.9337 | Train Dice: 0.5878 | Val Dice: 0.5987
# Fold 1 | Epoch 17/100 | Train Loss: 0.7174 | Val Loss: 0.6838 | Train Acc: 0.9323 | Val Acc: 0.9417 | Train Dice: 0.6051 | Val Dice: 0.6146
# Fold 1 | Epoch 18/100 | Train Loss: 0.6834 | Val Loss: 0.6616 | Train Acc: 0.9366 | Val Acc: 0.9433 | Train Dice: 0.6339 | Val Dice: 0.6252
# Fold 1 | Epoch 19/100 | Train Loss: 0.6785 | Val Loss: 0.6506 | Train Acc: 0.9384 | Val Acc: 0.9388 | Train Dice: 0.6334 | Val Dice: 0.6465
# Fold 1 | Epoch 20/100 | Train Loss: 0.6531 | Val Loss: 0.6278 | Train Acc: 0.9388 | Val Acc: 0.9467 | Train Dice: 0.6527 | Val Dice: 0.6527
# Fold 1 | Epoch 21/100 | Train Loss: 0.6479 | Val Loss: 0.6296 | Train Acc: 0.9423 | Val Acc: 0.9478 | Train Dice: 0.6571 | Val Dice: 0.6417
# Fold 1 | Epoch 22/100 | Train Loss: 0.6304 | Val Loss: 0.6127 | Train Acc: 0.9424 | Val Acc: 0.9491 | Train Dice: 0.6673 | Val Dice: 0.6595
# Fold 1 | Epoch 23/100 | Train Loss: 0.6261 | Val Loss: 0.6044 | Train Acc: 0.9439 | Val Acc: 0.9443 | Train Dice: 0.6691 | Val Dice: 0.6718
# Fold 1 | Epoch 24/100 | Train Loss: 0.6193 | Val Loss: 0.5902 | Train Acc: 0.9446 | Val Acc: 0.9483 | Train Dice: 0.6712 | Val Dice: 0.6762
# Fold 1 | Epoch 25/100 | Train Loss: 0.6041 | Val Loss: 0.5977 | Train Acc: 0.9446 | Val Acc: 0.9517 | Train Dice: 0.6848 | Val Dice: 0.6632
# Fold 1 | Epoch 26/100 | Train Loss: 0.6053 | Val Loss: 0.5788 | Train Acc: 0.9446 | Val Acc: 0.9488 | Train Dice: 0.6826 | Val Dice: 0.6868
# Fold 1 | Epoch 27/100 | Train Loss: 0.5943 | Val Loss: 0.5732 | Train Acc: 0.9477 | Val Acc: 0.9506 | Train Dice: 0.6905 | Val Dice: 0.6905
# Fold 1 | Epoch 28/100 | Train Loss: 0.5861 | Val Loss: 0.5717 | Train Acc: 0.9476 | Val Acc: 0.9495 | Train Dice: 0.6911 | Val Dice: 0.6879
# Fold 1 | Epoch 29/100 | Train Loss: 0.5788 | Val Loss: 0.5682 | Train Acc: 0.9477 | Val Acc: 0.9510 | Train Dice: 0.6952 | Val Dice: 0.6880
# Fold 1 | Epoch 30/100 | Train Loss: 0.5750 | Val Loss: 0.5669 | Train Acc: 0.9485 | Val Acc: 0.9483 | Train Dice: 0.7003 | Val Dice: 0.6930
# Fold 1 | Epoch 31/100 | Train Loss: 0.5606 | Val Loss: 0.5565 | Train Acc: 0.9507 | Val Acc: 0.9533 | Train Dice: 0.7071 | Val Dice: 0.6948
# Fold 1 | Epoch 32/100 | Train Loss: 0.5624 | Val Loss: 0.5609 | Train Acc: 0.9500 | Val Acc: 0.9491 | Train Dice: 0.7074 | Val Dice: 0.6955
# Fold 1 | Epoch 33/100 | Train Loss: 0.5566 | Val Loss: 0.5484 | Train Acc: 0.9503 | Val Acc: 0.9529 | Train Dice: 0.7132 | Val Dice: 0.7014
# Fold 1 | Epoch 34/100 | Train Loss: 0.5509 | Val Loss: 0.5406 | Train Acc: 0.9504 | Val Acc: 0.9545 | Train Dice: 0.7149 | Val Dice: 0.7052
# Fold 1 | Epoch 35/100 | Train Loss: 0.5483 | Val Loss: 0.5488 | Train Acc: 0.9514 | Val Acc: 0.9554 | Train Dice: 0.7144 | Val Dice: 0.6937
# Fold 1 | Epoch 36/100 | Train Loss: 0.5437 | Val Loss: 0.5352 | Train Acc: 0.9518 | Val Acc: 0.9550 | Train Dice: 0.7178 | Val Dice: 0.7073
# Fold 1 | Epoch 37/100 | Train Loss: 0.5481 | Val Loss: 0.5349 | Train Acc: 0.9511 | Val Acc: 0.9514 | Train Dice: 0.7159 | Val Dice: 0.7141
# Fold 1 | Epoch 38/100 | Train Loss: 0.5388 | Val Loss: 0.5373 | Train Acc: 0.9525 | Val Acc: 0.9513 | Train Dice: 0.7217 | Val Dice: 0.7119
# Fold 1 | Epoch 39/100 | Train Loss: 0.5316 | Val Loss: 0.5319 | Train Acc: 0.9537 | Val Acc: 0.9520 | Train Dice: 0.7219 | Val Dice: 0.7149
# Fold 1 | Epoch 40/100 | Train Loss: 0.5264 | Val Loss: 0.5221 | Train Acc: 0.9539 | Val Acc: 0.9551 | Train Dice: 0.7278 | Val Dice: 0.7186
# Fold 1 | Epoch 41/100 | Train Loss: 0.5255 | Val Loss: 0.5230 | Train Acc: 0.9533 | Val Acc: 0.9558 | Train Dice: 0.7298 | Val Dice: 0.7151
# Fold 1 | Epoch 42/100 | Train Loss: 0.5249 | Val Loss: 0.5223 | Train Acc: 0.9537 | Val Acc: 0.9550 | Train Dice: 0.7303 | Val Dice: 0.7166
# Fold 1 | Epoch 43/100 | Train Loss: 0.5210 | Val Loss: 0.5298 | Train Acc: 0.9539 | Val Acc: 0.9522 | Train Dice: 0.7311 | Val Dice: 0.7168
# Fold 1 | Epoch 44/100 | Train Loss: 0.5227 | Val Loss: 0.5502 | Train Acc: 0.9540 | Val Acc: 0.9468 | Train Dice: 0.7280 | Val Dice: 0.7101
# Fold 1 | Epoch 45/100 | Train Loss: 0.5366 | Val Loss: 0.5176 | Train Acc: 0.9517 | Val Acc: 0.9558 | Train Dice: 0.7217 | Val Dice: 0.7213
# Fold 1 | Epoch 46/100 | Train Loss: 0.5359 | Val Loss: 0.5255 | Train Acc: 0.9510 | Val Acc: 0.9540 | Train Dice: 0.7266 | Val Dice: 0.7190
# Fold 1 | Epoch 47/100 | Train Loss: 0.5158 | Val Loss: 0.5112 | Train Acc: 0.9551 | Val Acc: 0.9544 | Train Dice: 0.7321 | Val Dice: 0.7287
# Fold 1 | Epoch 48/100 | Train Loss: 0.5111 | Val Loss: 0.5138 | Train Acc: 0.9546 | Val Acc: 0.9546 | Train Dice: 0.7376 | Val Dice: 0.7255
# Fold 1 | Epoch 49/100 | Train Loss: 0.5082 | Val Loss: 0.5202 | Train Acc: 0.9554 | Val Acc: 0.9567 | Train Dice: 0.7372 | Val Dice: 0.7141
# Fold 1 | Epoch 50/100 | Train Loss: 0.5088 | Val Loss: 0.5067 | Train Acc: 0.9546 | Val Acc: 0.9556 | Train Dice: 0.7387 | Val Dice: 0.7283
# Fold 1 | Epoch 51/100 | Train Loss: 0.5022 | Val Loss: 0.5043 | Train Acc: 0.9568 | Val Acc: 0.9558 | Train Dice: 0.7389 | Val Dice: 0.7307
# Fold 1 | Epoch 52/100 | Train Loss: 0.5010 | Val Loss: 0.5133 | Train Acc: 0.9558 | Val Acc: 0.9576 | Train Dice: 0.7424 | Val Dice: 0.7167
# Fold 1 | Epoch 53/100 | Train Loss: 0.5105 | Val Loss: 0.5063 | Train Acc: 0.9547 | Val Acc: 0.9568 | Train Dice: 0.7358 | Val Dice: 0.7264
# Fold 1 | Epoch 54/100 | Train Loss: 0.4992 | Val Loss: 0.5131 | Train Acc: 0.9569 | Val Acc: 0.9529 | Train Dice: 0.7424 | Val Dice: 0.7306
# Fold 1 | Epoch 55/100 | Train Loss: 0.5083 | Val Loss: 0.4941 | Train Acc: 0.9556 | Val Acc: 0.9567 | Train Dice: 0.7359 | Val Dice: 0.7380
# Fold 1 | Epoch 56/100 | Train Loss: 0.5033 | Val Loss: 0.5013 | Train Acc: 0.9548 | Val Acc: 0.9581 | Train Dice: 0.7424 | Val Dice: 0.7271
# Fold 1 | Epoch 57/100 | Train Loss: 0.5087 | Val Loss: 0.5289 | Train Acc: 0.9549 | Val Acc: 0.9508 | Train Dice: 0.7373 | Val Dice: 0.7209
# Fold 1 | Epoch 58/100 | Train Loss: 0.4947 | Val Loss: 0.5034 | Train Acc: 0.9573 | Val Acc: 0.9559 | Train Dice: 0.7435 | Val Dice: 0.7313
# Fold 1 | Epoch 59/100 | Train Loss: 0.4975 | Val Loss: 0.4899 | Train Acc: 0.9561 | Val Acc: 0.9573 | Train Dice: 0.7478 | Val Dice: 0.7392
# Fold 1 | Epoch 60/100 | Train Loss: 0.4927 | Val Loss: 0.4949 | Train Acc: 0.9563 | Val Acc: 0.9579 | Train Dice: 0.7481 | Val Dice: 0.7308
# Fold 1 | Epoch 61/100 | Train Loss: 0.4927 | Val Loss: 0.5060 | Train Acc: 0.9566 | Val Acc: 0.9550 | Train Dice: 0.7477 | Val Dice: 0.7294
# Fold 1 | Epoch 62/100 | Train Loss: 0.4848 | Val Loss: 0.5136 | Train Acc: 0.9581 | Val Acc: 0.9532 | Train Dice: 0.7523 | Val Dice: 0.7280
# Fold 1 | Epoch 63/100 | Train Loss: 0.4803 | Val Loss: 0.4931 | Train Acc: 0.9577 | Val Acc: 0.9581 | Train Dice: 0.7527 | Val Dice: 0.7318
# Fold 1 | Epoch 64/100 | Train Loss: 0.4848 | Val Loss: 0.4942 | Train Acc: 0.9574 | Val Acc: 0.9581 | Train Dice: 0.7519 | Val Dice: 0.7315
# Fold 1 | Epoch 65/100 | Train Loss: 0.4889 | Val Loss: 0.5057 | Train Acc: 0.9576 | Val Acc: 0.9536 | Train Dice: 0.7498 | Val Dice: 0.7337
# Fold 1 | Epoch 66/100 | Train Loss: 0.4800 | Val Loss: 0.4909 | Train Acc: 0.9581 | Val Acc: 0.9583 | Train Dice: 0.7522 | Val Dice: 0.7339
# Fold 1 | Epoch 67/100 | Train Loss: 0.4877 | Val Loss: 0.4854 | Train Acc: 0.9572 | Val Acc: 0.9573 | Train Dice: 0.7509 | Val Dice: 0.7420
# Fold 1 | Epoch 68/100 | Train Loss: 0.4885 | Val Loss: 0.4951 | Train Acc: 0.9563 | Val Acc: 0.9587 | Train Dice: 0.7523 | Val Dice: 0.7295
# Fold 1 | Epoch 69/100 | Train Loss: 0.4908 | Val Loss: 0.4981 | Train Acc: 0.9573 | Val Acc: 0.9555 | Train Dice: 0.7478 | Val Dice: 0.7378
# Fold 1 | Epoch 70/100 | Train Loss: 0.4835 | Val Loss: 0.4921 | Train Acc: 0.9583 | Val Acc: 0.9567 | Train Dice: 0.7510 | Val Dice: 0.7371
# Fold 1 | Epoch 71/100 | Train Loss: 0.4754 | Val Loss: 0.5000 | Train Acc: 0.9586 | Val Acc: 0.9573 | Train Dice: 0.7581 | Val Dice: 0.7291
# Fold 1 | Epoch 72/100 | Train Loss: 0.4786 | Val Loss: 0.5009 | Train Acc: 0.9581 | Val Acc: 0.9551 | Train Dice: 0.7580 | Val Dice: 0.7341
# Fold 1 | Epoch 73/100 | Train Loss: 0.4751 | Val Loss: 0.4897 | Train Acc: 0.9584 | Val Acc: 0.9581 | Train Dice: 0.7581 | Val Dice: 0.7357
# Fold 1 | Epoch 74/100 | Train Loss: 0.4772 | Val Loss: 0.4867 | Train Acc: 0.9584 | Val Acc: 0.9574 | Train Dice: 0.7596 | Val Dice: 0.7400
# Fold 1 | Epoch 75/100 | Train Loss: 0.4744 | Val Loss: 0.4932 | Train Acc: 0.9587 | Val Acc: 0.9581 | Train Dice: 0.7596 | Val Dice: 0.7330
# Fold 1 | Epoch 76/100 | Train Loss: 0.4771 | Val Loss: 0.4974 | Train Acc: 0.9584 | Val Acc: 0.9557 | Train Dice: 0.7586 | Val Dice: 0.7352
# Fold 1 | Epoch 77/100 | Train Loss: 0.4708 | Val Loss: 0.4929 | Train Acc: 0.9593 | Val Acc: 0.9560 | Train Dice: 0.7571 | Val Dice: 0.7390
# Fold 1 | Epoch 78/100 | Train Loss: 0.4673 | Val Loss: 0.4961 | Train Acc: 0.9599 | Val Acc: 0.9551 | Train Dice: 0.7634 | Val Dice: 0.7377
# Fold 1 | Epoch 79/100 | Train Loss: 0.4699 | Val Loss: 0.4886 | Train Acc: 0.9589 | Val Acc: 0.9572 | Train Dice: 0.7608 | Val Dice: 0.7400
# Fold 1 | Epoch 80/100 | Train Loss: 0.4670 | Val Loss: 0.4984 | Train Acc: 0.9591 | Val Acc: 0.9582 | Train Dice: 0.7626 | Val Dice: 0.7281
# Fold 1 | Epoch 81/100 | Train Loss: 0.4640 | Val Loss: 0.5069 | Train Acc: 0.9602 | Val Acc: 0.9526 | Train Dice: 0.7636 | Val Dice: 0.7324
# Fold 1 | Epoch 82/100 | Train Loss: 0.4621 | Val Loss: 0.4925 | Train Acc: 0.9607 | Val Acc: 0.9551 | Train Dice: 0.7627 | Val Dice: 0.7388
# Fold 1 | Epoch 83/100 | Train Loss: 0.4667 | Val Loss: 0.4891 | Train Acc: 0.9592 | Val Acc: 0.9590 | Train Dice: 0.7624 | Val Dice: 0.7331
# Fold 1 | Epoch 84/100 | Train Loss: 0.4664 | Val Loss: 0.4805 | Train Acc: 0.9594 | Val Acc: 0.9582 | Train Dice: 0.7649 | Val Dice: 0.7428
# Fold 1 | Epoch 85/100 | Train Loss: 0.4721 | Val Loss: 0.4929 | Train Acc: 0.9589 | Val Acc: 0.9559 | Train Dice: 0.7581 | Val Dice: 0.7384
# Fold 1 | Epoch 86/100 | Train Loss: 0.4627 | Val Loss: 0.4819 | Train Acc: 0.9602 | Val Acc: 0.9587 | Train Dice: 0.7645 | Val Dice: 0.7415
# Fold 1 | Epoch 87/100 | Train Loss: 0.4672 | Val Loss: 0.4830 | Train Acc: 0.9592 | Val Acc: 0.9579 | Train Dice: 0.7636 | Val Dice: 0.7417
# Fold 1 | Epoch 88/100 | Train Loss: 0.4572 | Val Loss: 0.4985 | Train Acc: 0.9607 | Val Acc: 0.9546 | Train Dice: 0.7706 | Val Dice: 0.7373
# Fold 1 | Epoch 89/100 | Train Loss: 0.4618 | Val Loss: 0.4923 | Train Acc: 0.9600 | Val Acc: 0.9574 | Train Dice: 0.7655 | Val Dice: 0.7362
# Fold 1 | Epoch 90/100 | Train Loss: 0.4537 | Val Loss: 0.4797 | Train Acc: 0.9608 | Val Acc: 0.9597 | Train Dice: 0.7712 | Val Dice: 0.7418
# Fold 1 | Epoch 91/100 | Train Loss: 0.4540 | Val Loss: 0.4928 | Train Acc: 0.9613 | Val Acc: 0.9559 | Train Dice: 0.7690 | Val Dice: 0.7401
# Fold 1 | Epoch 92/100 | Train Loss: 0.4585 | Val Loss: 0.4953 | Train Acc: 0.9608 | Val Acc: 0.9552 | Train Dice: 0.7674 | Val Dice: 0.7387
# Fold 1 | Epoch 93/100 | Train Loss: 0.4561 | Val Loss: 0.4840 | Train Acc: 0.9607 | Val Acc: 0.9579 | Train Dice: 0.7706 | Val Dice: 0.7421
# Fold 1 | Epoch 94/100 | Train Loss: 0.4658 | Val Loss: 0.4794 | Train Acc: 0.9594 | Val Acc: 0.9585 | Train Dice: 0.7637 | Val Dice: 0.7424
# Fold 1 | Epoch 95/100 | Train Loss: 0.4530 | Val Loss: 0.4802 | Train Acc: 0.9608 | Val Acc: 0.9581 | Train Dice: 0.7714 | Val Dice: 0.7439
# Fold 1 | Epoch 96/100 | Train Loss: 0.4526 | Val Loss: 0.4976 | Train Acc: 0.9611 | Val Acc: 0.9553 | Train Dice: 0.7725 | Val Dice: 0.7359
# Fold 1 | Epoch 97/100 | Train Loss: 0.4501 | Val Loss: 0.4871 | Train Acc: 0.9617 | Val Acc: 0.9564 | Train Dice: 0.7716 | Val Dice: 0.7427
# Fold 1 | Epoch 98/100 | Train Loss: 0.4518 | Val Loss: 0.4902 | Train Acc: 0.9609 | Val Acc: 0.9578 | Train Dice: 0.7707 | Val Dice: 0.7373
# Fold 1 | Epoch 99/100 | Train Loss: 0.4519 | Val Loss: 0.4888 | Train Acc: 0.9603 | Val Acc: 0.9592 | Train Dice: 0.7729 | Val Dice: 0.7324
# Fold 1 | Epoch 100/100 | Train Loss: 0.4573 | Val Loss: 0.4760 | Train Acc: 0.9606 | Val Acc: 0.9582 | Train Dice: 0.7680 | Val Dice: 0.7478
#
# ===== FOLD 2 ====
# Fold 2 | Epoch 1/100 | Train Loss: 1.2552 | Val Loss: 1.2609 | Train Acc: 0.3155 | Val Acc: 0.8925 | Train Dice: 0.1942 | Val Dice: 0.0000
# Fold 2 | Epoch 2/100 | Train Loss: 1.2398 | Val Loss: 1.2307 | Train Acc: 0.9149 | Val Acc: 0.9005 | Train Dice: 0.0222 | Val Dice: 0.0000
# Fold 2 | Epoch 3/100 | Train Loss: 1.1691 | Val Loss: 1.3381 | Train Acc: 0.9137 | Val Acc: 0.9005 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 2 | Epoch 4/100 | Train Loss: 1.1001 | Val Loss: 1.3313 | Train Acc: 0.9162 | Val Acc: 0.9005 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 2 | Epoch 5/100 | Train Loss: 1.0664 | Val Loss: 1.2429 | Train Acc: 0.9160 | Val Acc: 0.9005 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 2 | Epoch 6/100 | Train Loss: 1.0446 | Val Loss: 1.1414 | Train Acc: 0.9172 | Val Acc: 0.9005 | Train Dice: 0.0391 | Val Dice: 0.0000
# Fold 2 | Epoch 7/100 | Train Loss: 1.0249 | Val Loss: 1.0924 | Train Acc: 0.9244 | Val Acc: 0.9012 | Train Dice: 0.2738 | Val Dice: 0.0129
# Fold 2 | Epoch 8/100 | Train Loss: 1.0087 | Val Loss: 1.0544 | Train Acc: 0.9265 | Val Acc: 0.9111 | Train Dice: 0.3883 | Val Dice: 0.2233
# Fold 2 | Epoch 9/100 | Train Loss: 0.9918 | Val Loss: 1.0227 | Train Acc: 0.9246 | Val Acc: 0.9182 | Train Dice: 0.4254 | Val Dice: 0.3847
# Fold 2 | Epoch 10/100 | Train Loss: 0.9671 | Val Loss: 0.9902 | Train Acc: 0.9236 | Val Acc: 0.9220 | Train Dice: 0.4267 | Val Dice: 0.4923
# Fold 2 | Epoch 11/100 | Train Loss: 0.9231 | Val Loss: 0.9520 | Train Acc: 0.9255 | Val Acc: 0.9200 | Train Dice: 0.4975 | Val Dice: 0.4833
# Fold 2 | Epoch 12/100 | Train Loss: 0.8859 | Val Loss: 0.8994 | Train Acc: 0.9252 | Val Acc: 0.9193 | Train Dice: 0.5087 | Val Dice: 0.5247
# Fold 2 | Epoch 13/100 | Train Loss: 0.8347 | Val Loss: 0.8476 | Train Acc: 0.9250 | Val Acc: 0.9120 | Train Dice: 0.5268 | Val Dice: 0.5635
# Fold 2 | Epoch 14/100 | Train Loss: 0.8059 | Val Loss: 0.8375 | Train Acc: 0.9244 | Val Acc: 0.9017 | Train Dice: 0.5427 | Val Dice: 0.5745
# Fold 2 | Epoch 15/100 | Train Loss: 0.7857 | Val Loss: 0.7931 | Train Acc: 0.9268 | Val Acc: 0.9171 | Train Dice: 0.5573 | Val Dice: 0.5843
# Fold 2 | Epoch 16/100 | Train Loss: 0.7452 | Val Loss: 0.7736 | Train Acc: 0.9289 | Val Acc: 0.9279 | Train Dice: 0.5879 | Val Dice: 0.5837
# Fold 2 | Epoch 17/100 | Train Loss: 0.7168 | Val Loss: 0.7514 | Train Acc: 0.9371 | Val Acc: 0.9298 | Train Dice: 0.6101 | Val Dice: 0.6048
# Fold 2 | Epoch 18/100 | Train Loss: 0.6991 | Val Loss: 0.7196 | Train Acc: 0.9367 | Val Acc: 0.9279 | Train Dice: 0.6162 | Val Dice: 0.6318
# Fold 2 | Epoch 19/100 | Train Loss: 0.6805 | Val Loss: 0.7096 | Train Acc: 0.9405 | Val Acc: 0.9253 | Train Dice: 0.6347 | Val Dice: 0.6444
# Fold 2 | Epoch 20/100 | Train Loss: 0.6623 | Val Loss: 0.6921 | Train Acc: 0.9418 | Val Acc: 0.9301 | Train Dice: 0.6448 | Val Dice: 0.6519
# Fold 2 | Epoch 21/100 | Train Loss: 0.6506 | Val Loss: 0.6791 | Train Acc: 0.9416 | Val Acc: 0.9353 | Train Dice: 0.6509 | Val Dice: 0.6562
# Fold 2 | Epoch 22/100 | Train Loss: 0.6370 | Val Loss: 0.6649 | Train Acc: 0.9433 | Val Acc: 0.9322 | Train Dice: 0.6611 | Val Dice: 0.6682
# Fold 2 | Epoch 23/100 | Train Loss: 0.6365 | Val Loss: 0.6606 | Train Acc: 0.9436 | Val Acc: 0.9326 | Train Dice: 0.6568 | Val Dice: 0.6725
# Fold 2 | Epoch 24/100 | Train Loss: 0.6215 | Val Loss: 0.6509 | Train Acc: 0.9436 | Val Acc: 0.9392 | Train Dice: 0.6689 | Val Dice: 0.6689
# Fold 2 | Epoch 25/100 | Train Loss: 0.6064 | Val Loss: 0.6378 | Train Acc: 0.9461 | Val Acc: 0.9393 | Train Dice: 0.6792 | Val Dice: 0.6807
# Fold 2 | Epoch 26/100 | Train Loss: 0.5958 | Val Loss: 0.6308 | Train Acc: 0.9470 | Val Acc: 0.9394 | Train Dice: 0.6848 | Val Dice: 0.6854
# Fold 2 | Epoch 27/100 | Train Loss: 0.5942 | Val Loss: 0.6448 | Train Acc: 0.9474 | Val Acc: 0.9417 | Train Dice: 0.6871 | Val Dice: 0.6695
# Fold 2 | Epoch 28/100 | Train Loss: 0.5885 | Val Loss: 0.6217 | Train Acc: 0.9478 | Val Acc: 0.9391 | Train Dice: 0.6912 | Val Dice: 0.6933
# Fold 2 | Epoch 29/100 | Train Loss: 0.5842 | Val Loss: 0.6228 | Train Acc: 0.9487 | Val Acc: 0.9375 | Train Dice: 0.6928 | Val Dice: 0.6947
# Fold 2 | Epoch 30/100 | Train Loss: 0.5806 | Val Loss: 0.6171 | Train Acc: 0.9480 | Val Acc: 0.9426 | Train Dice: 0.6943 | Val Dice: 0.6917
# Fold 2 | Epoch 31/100 | Train Loss: 0.5707 | Val Loss: 0.6077 | Train Acc: 0.9499 | Val Acc: 0.9424 | Train Dice: 0.6995 | Val Dice: 0.6986
# Fold 2 | Epoch 32/100 | Train Loss: 0.5630 | Val Loss: 0.6110 | Train Acc: 0.9506 | Val Acc: 0.9400 | Train Dice: 0.7027 | Val Dice: 0.6995
# Fold 2 | Epoch 33/100 | Train Loss: 0.5593 | Val Loss: 0.6005 | Train Acc: 0.9504 | Val Acc: 0.9423 | Train Dice: 0.7040 | Val Dice: 0.7038
# Fold 2 | Epoch 34/100 | Train Loss: 0.5565 | Val Loss: 0.5932 | Train Acc: 0.9511 | Val Acc: 0.9444 | Train Dice: 0.7068 | Val Dice: 0.7072
# Fold 2 | Epoch 35/100 | Train Loss: 0.5500 | Val Loss: 0.5924 | Train Acc: 0.9514 | Val Acc: 0.9462 | Train Dice: 0.7122 | Val Dice: 0.7050
# Fold 2 | Epoch 36/100 | Train Loss: 0.5410 | Val Loss: 0.6068 | Train Acc: 0.9525 | Val Acc: 0.9451 | Train Dice: 0.7160 | Val Dice: 0.6935
# Fold 2 | Epoch 37/100 | Train Loss: 0.5435 | Val Loss: 0.5933 | Train Acc: 0.9525 | Val Acc: 0.9449 | Train Dice: 0.7128 | Val Dice: 0.7056
# Fold 2 | Epoch 38/100 | Train Loss: 0.5365 | Val Loss: 0.5868 | Train Acc: 0.9539 | Val Acc: 0.9430 | Train Dice: 0.7164 | Val Dice: 0.7130
# Fold 2 | Epoch 39/100 | Train Loss: 0.5333 | Val Loss: 0.5902 | Train Acc: 0.9539 | Val Acc: 0.9449 | Train Dice: 0.7192 | Val Dice: 0.7083
# Fold 2 | Epoch 40/100 | Train Loss: 0.5263 | Val Loss: 0.5892 | Train Acc: 0.9539 | Val Acc: 0.9466 | Train Dice: 0.7252 | Val Dice: 0.7065
# Fold 2 | Epoch 41/100 | Train Loss: 0.5313 | Val Loss: 0.5832 | Train Acc: 0.9542 | Val Acc: 0.9420 | Train Dice: 0.7232 | Val Dice: 0.7167
# Fold 2 | Epoch 42/100 | Train Loss: 0.5250 | Val Loss: 0.5853 | Train Acc: 0.9538 | Val Acc: 0.9470 | Train Dice: 0.7260 | Val Dice: 0.7077
# Fold 2 | Epoch 43/100 | Train Loss: 0.5232 | Val Loss: 0.5714 | Train Acc: 0.9542 | Val Acc: 0.9475 | Train Dice: 0.7274 | Val Dice: 0.7189
# Fold 2 | Epoch 44/100 | Train Loss: 0.5206 | Val Loss: 0.5733 | Train Acc: 0.9552 | Val Acc: 0.9451 | Train Dice: 0.7293 | Val Dice: 0.7189
# Fold 2 | Epoch 45/100 | Train Loss: 0.5140 | Val Loss: 0.5822 | Train Acc: 0.9551 | Val Acc: 0.9472 | Train Dice: 0.7326 | Val Dice: 0.7101
# Fold 2 | Epoch 46/100 | Train Loss: 0.5204 | Val Loss: 0.5767 | Train Acc: 0.9544 | Val Acc: 0.9481 | Train Dice: 0.7278 | Val Dice: 0.7124
# Fold 2 | Epoch 47/100 | Train Loss: 0.5126 | Val Loss: 0.5693 | Train Acc: 0.9564 | Val Acc: 0.9451 | Train Dice: 0.7329 | Val Dice: 0.7217
# Fold 2 | Epoch 48/100 | Train Loss: 0.5166 | Val Loss: 0.5709 | Train Acc: 0.9545 | Val Acc: 0.9474 | Train Dice: 0.7306 | Val Dice: 0.7180
# Fold 2 | Epoch 49/100 | Train Loss: 0.5111 | Val Loss: 0.6005 | Train Acc: 0.9549 | Val Acc: 0.9473 | Train Dice: 0.7366 | Val Dice: 0.6916
# Fold 2 | Epoch 50/100 | Train Loss: 0.5145 | Val Loss: 0.5688 | Train Acc: 0.9551 | Val Acc: 0.9460 | Train Dice: 0.7318 | Val Dice: 0.7212
# Fold 2 | Epoch 51/100 | Train Loss: 0.5039 | Val Loss: 0.5663 | Train Acc: 0.9571 | Val Acc: 0.9462 | Train Dice: 0.7334 | Val Dice: 0.7218
# Fold 2 | Epoch 52/100 | Train Loss: 0.5080 | Val Loss: 0.5721 | Train Acc: 0.9556 | Val Acc: 0.9479 | Train Dice: 0.7366 | Val Dice: 0.7160
# Fold 2 | Epoch 53/100 | Train Loss: 0.5002 | Val Loss: 0.5908 | Train Acc: 0.9562 | Val Acc: 0.9477 | Train Dice: 0.7390 | Val Dice: 0.6984
# Fold 2 | Epoch 54/100 | Train Loss: 0.5017 | Val Loss: 0.5619 | Train Acc: 0.9567 | Val Acc: 0.9455 | Train Dice: 0.7395 | Val Dice: 0.7274
# Fold 2 | Epoch 55/100 | Train Loss: 0.5054 | Val Loss: 0.5645 | Train Acc: 0.9561 | Val Acc: 0.9485 | Train Dice: 0.7353 | Val Dice: 0.7203
# Fold 2 | Epoch 56/100 | Train Loss: 0.5006 | Val Loss: 0.5786 | Train Acc: 0.9554 | Val Acc: 0.9488 | Train Dice: 0.7402 | Val Dice: 0.7064
# Fold 2 | Epoch 57/100 | Train Loss: 0.5080 | Val Loss: 0.5622 | Train Acc: 0.9564 | Val Acc: 0.9450 | Train Dice: 0.7374 | Val Dice: 0.7291
# Fold 2 | Epoch 58/100 | Train Loss: 0.5003 | Val Loss: 0.6051 | Train Acc: 0.9551 | Val Acc: 0.9475 | Train Dice: 0.7406 | Val Dice: 0.6826
# Fold 2 | Epoch 59/100 | Train Loss: 0.5125 | Val Loss: 0.5674 | Train Acc: 0.9557 | Val Acc: 0.9434 | Train Dice: 0.7306 | Val Dice: 0.7248
# Fold 2 | Epoch 60/100 | Train Loss: 0.5031 | Val Loss: 0.5702 | Train Acc: 0.9564 | Val Acc: 0.9494 | Train Dice: 0.7400 | Val Dice: 0.7129
# Fold 2 | Epoch 61/100 | Train Loss: 0.4990 | Val Loss: 0.5587 | Train Acc: 0.9566 | Val Acc: 0.9468 | Train Dice: 0.7421 | Val Dice: 0.7280
# Fold 2 | Epoch 62/100 | Train Loss: 0.4933 | Val Loss: 0.5532 | Train Acc: 0.9579 | Val Acc: 0.9496 | Train Dice: 0.7443 | Val Dice: 0.7273
# Fold 2 | Epoch 63/100 | Train Loss: 0.4925 | Val Loss: 0.5465 | Train Acc: 0.9574 | Val Acc: 0.9489 | Train Dice: 0.7463 | Val Dice: 0.7343
# Fold 2 | Epoch 64/100 | Train Loss: 0.4845 | Val Loss: 0.5507 | Train Acc: 0.9583 | Val Acc: 0.9500 | Train Dice: 0.7481 | Val Dice: 0.7277
# Fold 2 | Epoch 65/100 | Train Loss: 0.4930 | Val Loss: 0.5450 | Train Acc: 0.9567 | Val Acc: 0.9494 | Train Dice: 0.7441 | Val Dice: 0.7331
# Fold 2 | Epoch 66/100 | Train Loss: 0.4831 | Val Loss: 0.5529 | Train Acc: 0.9586 | Val Acc: 0.9476 | Train Dice: 0.7503 | Val Dice: 0.7311
# Fold 2 | Epoch 67/100 | Train Loss: 0.4871 | Val Loss: 0.5608 | Train Acc: 0.9573 | Val Acc: 0.9498 | Train Dice: 0.7495 | Val Dice: 0.7182
# Fold 2 | Epoch 68/100 | Train Loss: 0.4792 | Val Loss: 0.5639 | Train Acc: 0.9580 | Val Acc: 0.9496 | Train Dice: 0.7534 | Val Dice: 0.7157
# Fold 2 | Epoch 69/100 | Train Loss: 0.4783 | Val Loss: 0.5506 | Train Acc: 0.9590 | Val Acc: 0.9485 | Train Dice: 0.7540 | Val Dice: 0.7311
# Fold 2 | Epoch 70/100 | Train Loss: 0.4812 | Val Loss: 0.5528 | Train Acc: 0.9587 | Val Acc: 0.9494 | Train Dice: 0.7522 | Val Dice: 0.7275
# Fold 2 | Epoch 71/100 | Train Loss: 0.4853 | Val Loss: 0.5584 | Train Acc: 0.9574 | Val Acc: 0.9500 | Train Dice: 0.7482 | Val Dice: 0.7188
# Fold 2 | Epoch 72/100 | Train Loss: 0.4722 | Val Loss: 0.5465 | Train Acc: 0.9592 | Val Acc: 0.9497 | Train Dice: 0.7570 | Val Dice: 0.7321
# Fold 2 | Epoch 73/100 | Train Loss: 0.4763 | Val Loss: 0.5438 | Train Acc: 0.9594 | Val Acc: 0.9488 | Train Dice: 0.7537 | Val Dice: 0.7362
# Fold 2 | Epoch 74/100 | Train Loss: 0.4765 | Val Loss: 0.5444 | Train Acc: 0.9589 | Val Acc: 0.9497 | Train Dice: 0.7537 | Val Dice: 0.7316
# Fold 2 | Epoch 75/100 | Train Loss: 0.4750 | Val Loss: 0.5590 | Train Acc: 0.9587 | Val Acc: 0.9499 | Train Dice: 0.7549 | Val Dice: 0.7194
# Fold 2 | Epoch 76/100 | Train Loss: 0.4690 | Val Loss: 0.5546 | Train Acc: 0.9598 | Val Acc: 0.9503 | Train Dice: 0.7562 | Val Dice: 0.7219
# Fold 2 | Epoch 77/100 | Train Loss: 0.4807 | Val Loss: 0.5505 | Train Acc: 0.9584 | Val Acc: 0.9477 | Train Dice: 0.7519 | Val Dice: 0.7334
# Fold 2 | Epoch 78/100 | Train Loss: 0.4705 | Val Loss: 0.5401 | Train Acc: 0.9597 | Val Acc: 0.9496 | Train Dice: 0.7565 | Val Dice: 0.7354
# Fold 2 | Epoch 79/100 | Train Loss: 0.4676 | Val Loss: 0.5559 | Train Acc: 0.9591 | Val Acc: 0.9501 | Train Dice: 0.7591 | Val Dice: 0.7194
# Fold 2 | Epoch 80/100 | Train Loss: 0.4743 | Val Loss: 0.5428 | Train Acc: 0.9588 | Val Acc: 0.9486 | Train Dice: 0.7556 | Val Dice: 0.7355
# Fold 2 | Epoch 81/100 | Train Loss: 0.4687 | Val Loss: 0.5405 | Train Acc: 0.9602 | Val Acc: 0.9494 | Train Dice: 0.7584 | Val Dice: 0.7363
# Fold 2 | Epoch 82/100 | Train Loss: 0.4705 | Val Loss: 0.5417 | Train Acc: 0.9589 | Val Acc: 0.9509 | Train Dice: 0.7586 | Val Dice: 0.7306
# Fold 2 | Epoch 83/100 | Train Loss: 0.4676 | Val Loss: 0.5439 | Train Acc: 0.9596 | Val Acc: 0.9493 | Train Dice: 0.7593 | Val Dice: 0.7335
# Fold 2 | Epoch 84/100 | Train Loss: 0.4585 | Val Loss: 0.5431 | Train Acc: 0.9609 | Val Acc: 0.9495 | Train Dice: 0.7629 | Val Dice: 0.7336
# Fold 2 | Epoch 85/100 | Train Loss: 0.4595 | Val Loss: 0.5519 | Train Acc: 0.9604 | Val Acc: 0.9499 | Train Dice: 0.7638 | Val Dice: 0.7253
# Fold 2 | Epoch 86/100 | Train Loss: 0.4594 | Val Loss: 0.5425 | Train Acc: 0.9613 | Val Acc: 0.9501 | Train Dice: 0.7617 | Val Dice: 0.7342
# Fold 2 | Epoch 87/100 | Train Loss: 0.4645 | Val Loss: 0.5356 | Train Acc: 0.9605 | Val Acc: 0.9499 | Train Dice: 0.7606 | Val Dice: 0.7394
# Fold 2 | Epoch 88/100 | Train Loss: 0.4612 | Val Loss: 0.5435 | Train Acc: 0.9609 | Val Acc: 0.9506 | Train Dice: 0.7625 | Val Dice: 0.7318
# Fold 2 | Epoch 89/100 | Train Loss: 0.4529 | Val Loss: 0.5511 | Train Acc: 0.9608 | Val Acc: 0.9506 | Train Dice: 0.7682 | Val Dice: 0.7244
# Fold 2 | Epoch 90/100 | Train Loss: 0.4616 | Val Loss: 0.5365 | Train Acc: 0.9604 | Val Acc: 0.9504 | Train Dice: 0.7640 | Val Dice: 0.7375
# Fold 2 | Epoch 91/100 | Train Loss: 0.4567 | Val Loss: 0.5564 | Train Acc: 0.9609 | Val Acc: 0.9497 | Train Dice: 0.7655 | Val Dice: 0.7220
# Fold 2 | Epoch 92/100 | Train Loss: 0.4564 | Val Loss: 0.5311 | Train Acc: 0.9608 | Val Acc: 0.9507 | Train Dice: 0.7663 | Val Dice: 0.7415
# Fold 2 | Epoch 93/100 | Train Loss: 0.4521 | Val Loss: 0.5382 | Train Acc: 0.9618 | Val Acc: 0.9493 | Train Dice: 0.7670 | Val Dice: 0.7396
# Fold 2 | Epoch 94/100 | Train Loss: 0.4574 | Val Loss: 0.5329 | Train Acc: 0.9609 | Val Acc: 0.9499 | Train Dice: 0.7657 | Val Dice: 0.7414
# Fold 2 | Epoch 95/100 | Train Loss: 0.4573 | Val Loss: 0.5509 | Train Acc: 0.9603 | Val Acc: 0.9509 | Train Dice: 0.7654 | Val Dice: 0.7230
# Fold 2 | Epoch 96/100 | Train Loss: 0.4529 | Val Loss: 0.5387 | Train Acc: 0.9613 | Val Acc: 0.9507 | Train Dice: 0.7697 | Val Dice: 0.7368
# Fold 2 | Epoch 97/100 | Train Loss: 0.4511 | Val Loss: 0.5340 | Train Acc: 0.9616 | Val Acc: 0.9507 | Train Dice: 0.7701 | Val Dice: 0.7381
# Fold 2 | Epoch 98/100 | Train Loss: 0.4504 | Val Loss: 0.5536 | Train Acc: 0.9610 | Val Acc: 0.9506 | Train Dice: 0.7698 | Val Dice: 0.7177
# Fold 2 | Epoch 99/100 | Train Loss: 0.4516 | Val Loss: 0.5311 | Train Acc: 0.9614 | Val Acc: 0.9515 | Train Dice: 0.7675 | Val Dice: 0.7376
# Fold 2 | Epoch 100/100 | Train Loss: 0.4471 | Val Loss: 0.5336 | Train Acc: 0.9621 | Val Acc: 0.9494 | Train Dice: 0.7686 | Val Dice: 0.7418
#
# ===== FOLD 3 ====
# Fold 3 | Epoch 1/100 | Train Loss: 1.2376 | Val Loss: 1.2194 | Train Acc: 0.9147 | Val Acc: 0.9163 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 3 | Epoch 2/100 | Train Loss: 1.2047 | Val Loss: 1.1672 | Train Acc: 0.9139 | Val Acc: 0.9163 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 3 | Epoch 3/100 | Train Loss: 1.1207 | Val Loss: 1.2774 | Train Acc: 0.9127 | Val Acc: 0.9163 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 3 | Epoch 4/100 | Train Loss: 1.0807 | Val Loss: 1.1726 | Train Acc: 0.9141 | Val Acc: 0.9163 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 3 | Epoch 5/100 | Train Loss: 1.0641 | Val Loss: 1.1859 | Train Acc: 0.9134 | Val Acc: 0.9163 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 3 | Epoch 6/100 | Train Loss: 1.0416 | Val Loss: 1.1925 | Train Acc: 0.9138 | Val Acc: 0.9163 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 3 | Epoch 7/100 | Train Loss: 1.0190 | Val Loss: 1.1583 | Train Acc: 0.9140 | Val Acc: 0.9163 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 3 | Epoch 8/100 | Train Loss: 0.9997 | Val Loss: 1.0332 | Train Acc: 0.9140 | Val Acc: 0.9163 | Train Dice: 0.0184 | Val Dice: 0.0000
# Fold 3 | Epoch 9/100 | Train Loss: 0.9712 | Val Loss: 0.9891 | Train Acc: 0.9216 | Val Acc: 0.9180 | Train Dice: 0.1632 | Val Dice: 0.0402
# Fold 3 | Epoch 10/100 | Train Loss: 0.9416 | Val Loss: 0.9326 | Train Acc: 0.9290 | Val Acc: 0.9258 | Train Dice: 0.3874 | Val Dice: 0.2320
# Fold 3 | Epoch 11/100 | Train Loss: 0.9088 | Val Loss: 0.8873 | Train Acc: 0.9338 | Val Acc: 0.9344 | Train Dice: 0.5007 | Val Dice: 0.4374
# Fold 3 | Epoch 12/100 | Train Loss: 0.8770 | Val Loss: 0.8491 | Train Acc: 0.9348 | Val Acc: 0.9366 | Train Dice: 0.5355 | Val Dice: 0.5024
# Fold 3 | Epoch 13/100 | Train Loss: 0.8351 | Val Loss: 0.7974 | Train Acc: 0.9363 | Val Acc: 0.9405 | Train Dice: 0.5796 | Val Dice: 0.5941
# Fold 3 | Epoch 14/100 | Train Loss: 0.7958 | Val Loss: 0.7517 | Train Acc: 0.9374 | Val Acc: 0.9425 | Train Dice: 0.6067 | Val Dice: 0.6124
# Fold 3 | Epoch 15/100 | Train Loss: 0.7555 | Val Loss: 0.6973 | Train Acc: 0.9364 | Val Acc: 0.9433 | Train Dice: 0.6156 | Val Dice: 0.6418
# Fold 3 | Epoch 16/100 | Train Loss: 0.7172 | Val Loss: 0.7071 | Train Acc: 0.9355 | Val Acc: 0.9269 | Train Dice: 0.6228 | Val Dice: 0.6384
# Fold 3 | Epoch 17/100 | Train Loss: 0.7322 | Val Loss: 0.6598 | Train Acc: 0.9294 | Val Acc: 0.9416 | Train Dice: 0.6066 | Val Dice: 0.6551
# Fold 3 | Epoch 18/100 | Train Loss: 0.6922 | Val Loss: 0.6270 | Train Acc: 0.9305 | Val Acc: 0.9482 | Train Dice: 0.6346 | Val Dice: 0.6763
# Fold 3 | Epoch 19/100 | Train Loss: 0.6701 | Val Loss: 0.6381 | Train Acc: 0.9435 | Val Acc: 0.9391 | Train Dice: 0.6419 | Val Dice: 0.6730
# Fold 3 | Epoch 20/100 | Train Loss: 0.6615 | Val Loss: 0.6126 | Train Acc: 0.9365 | Val Acc: 0.9482 | Train Dice: 0.6545 | Val Dice: 0.6816
# Fold 3 | Epoch 21/100 | Train Loss: 0.6465 | Val Loss: 0.5997 | Train Acc: 0.9436 | Val Acc: 0.9480 | Train Dice: 0.6595 | Val Dice: 0.6905
# Fold 3 | Epoch 22/100 | Train Loss: 0.6314 | Val Loss: 0.5916 | Train Acc: 0.9440 | Val Acc: 0.9512 | Train Dice: 0.6743 | Val Dice: 0.6918
# Fold 3 | Epoch 23/100 | Train Loss: 0.6169 | Val Loss: 0.5822 | Train Acc: 0.9441 | Val Acc: 0.9507 | Train Dice: 0.6805 | Val Dice: 0.6952
# Fold 3 | Epoch 24/100 | Train Loss: 0.6118 | Val Loss: 0.5799 | Train Acc: 0.9459 | Val Acc: 0.9486 | Train Dice: 0.6760 | Val Dice: 0.6990
# Fold 3 | Epoch 25/100 | Train Loss: 0.6039 | Val Loss: 0.5669 | Train Acc: 0.9462 | Val Acc: 0.9511 | Train Dice: 0.6853 | Val Dice: 0.7028
# Fold 3 | Epoch 26/100 | Train Loss: 0.5959 | Val Loss: 0.5673 | Train Acc: 0.9458 | Val Acc: 0.9523 | Train Dice: 0.6905 | Val Dice: 0.7006
# Fold 3 | Epoch 27/100 | Train Loss: 0.5889 | Val Loss: 0.5652 | Train Acc: 0.9476 | Val Acc: 0.9511 | Train Dice: 0.6918 | Val Dice: 0.7005
# Fold 3 | Epoch 28/100 | Train Loss: 0.5793 | Val Loss: 0.5570 | Train Acc: 0.9495 | Val Acc: 0.9510 | Train Dice: 0.6961 | Val Dice: 0.7071
# Fold 3 | Epoch 29/100 | Train Loss: 0.5754 | Val Loss: 0.5560 | Train Acc: 0.9483 | Val Acc: 0.9545 | Train Dice: 0.6996 | Val Dice: 0.7043
# Fold 3 | Epoch 30/100 | Train Loss: 0.5778 | Val Loss: 0.5470 | Train Acc: 0.9476 | Val Acc: 0.9535 | Train Dice: 0.7017 | Val Dice: 0.7106
# Fold 3 | Epoch 31/100 | Train Loss: 0.5675 | Val Loss: 0.5511 | Train Acc: 0.9508 | Val Acc: 0.9508 | Train Dice: 0.7060 | Val Dice: 0.7141
# Fold 3 | Epoch 32/100 | Train Loss: 0.5645 | Val Loss: 0.5476 | Train Acc: 0.9498 | Val Acc: 0.9536 | Train Dice: 0.7078 | Val Dice: 0.7103
# Fold 3 | Epoch 33/100 | Train Loss: 0.5568 | Val Loss: 0.5542 | Train Acc: 0.9498 | Val Acc: 0.9551 | Train Dice: 0.7104 | Val Dice: 0.7009
# Fold 3 | Epoch 34/100 | Train Loss: 0.5611 | Val Loss: 0.5387 | Train Acc: 0.9500 | Val Acc: 0.9522 | Train Dice: 0.7067 | Val Dice: 0.7181
# Fold 3 | Epoch 35/100 | Train Loss: 0.5628 | Val Loss: 0.5365 | Train Acc: 0.9500 | Val Acc: 0.9545 | Train Dice: 0.7044 | Val Dice: 0.7166
# Fold 3 | Epoch 36/100 | Train Loss: 0.5563 | Val Loss: 0.5319 | Train Acc: 0.9500 | Val Acc: 0.9550 | Train Dice: 0.7142 | Val Dice: 0.7214
# Fold 3 | Epoch 37/100 | Train Loss: 0.5369 | Val Loss: 0.5294 | Train Acc: 0.9528 | Val Acc: 0.9558 | Train Dice: 0.7242 | Val Dice: 0.7213
# Fold 3 | Epoch 38/100 | Train Loss: 0.5452 | Val Loss: 0.5394 | Train Acc: 0.9512 | Val Acc: 0.9559 | Train Dice: 0.7150 | Val Dice: 0.7095
# Fold 3 | Epoch 39/100 | Train Loss: 0.5384 | Val Loss: 0.5258 | Train Acc: 0.9528 | Val Acc: 0.9553 | Train Dice: 0.7208 | Val Dice: 0.7245
# Fold 3 | Epoch 40/100 | Train Loss: 0.5319 | Val Loss: 0.5256 | Train Acc: 0.9537 | Val Acc: 0.9529 | Train Dice: 0.7278 | Val Dice: 0.7259
# Fold 3 | Epoch 41/100 | Train Loss: 0.5281 | Val Loss: 0.5248 | Train Acc: 0.9534 | Val Acc: 0.9562 | Train Dice: 0.7274 | Val Dice: 0.7234
# Fold 3 | Epoch 42/100 | Train Loss: 0.5291 | Val Loss: 0.5211 | Train Acc: 0.9531 | Val Acc: 0.9545 | Train Dice: 0.7292 | Val Dice: 0.7261
# Fold 3 | Epoch 43/100 | Train Loss: 0.5255 | Val Loss: 0.5244 | Train Acc: 0.9535 | Val Acc: 0.9544 | Train Dice: 0.7302 | Val Dice: 0.7255
# Fold 3 | Epoch 44/100 | Train Loss: 0.5199 | Val Loss: 0.5200 | Train Acc: 0.9541 | Val Acc: 0.9559 | Train Dice: 0.7345 | Val Dice: 0.7250
# Fold 3 | Epoch 45/100 | Train Loss: 0.5175 | Val Loss: 0.5173 | Train Acc: 0.9545 | Val Acc: 0.9566 | Train Dice: 0.7331 | Val Dice: 0.7275
# Fold 3 | Epoch 46/100 | Train Loss: 0.5194 | Val Loss: 0.5211 | Train Acc: 0.9543 | Val Acc: 0.9547 | Train Dice: 0.7342 | Val Dice: 0.7254
# Fold 3 | Epoch 47/100 | Train Loss: 0.5152 | Val Loss: 0.5262 | Train Acc: 0.9556 | Val Acc: 0.9513 | Train Dice: 0.7349 | Val Dice: 0.7259
# Fold 3 | Epoch 48/100 | Train Loss: 0.5278 | Val Loss: 0.5136 | Train Acc: 0.9535 | Val Acc: 0.9539 | Train Dice: 0.7263 | Val Dice: 0.7311
# Fold 3 | Epoch 49/100 | Train Loss: 0.5208 | Val Loss: 0.5372 | Train Acc: 0.9520 | Val Acc: 0.9568 | Train Dice: 0.7350 | Val Dice: 0.7083
# Fold 3 | Epoch 50/100 | Train Loss: 0.5252 | Val Loss: 0.5214 | Train Acc: 0.9542 | Val Acc: 0.9530 | Train Dice: 0.7281 | Val Dice: 0.7281
# Fold 3 | Epoch 51/100 | Train Loss: 0.5182 | Val Loss: 0.5161 | Train Acc: 0.9552 | Val Acc: 0.9552 | Train Dice: 0.7322 | Val Dice: 0.7292
# Fold 3 | Epoch 52/100 | Train Loss: 0.5184 | Val Loss: 0.5230 | Train Acc: 0.9534 | Val Acc: 0.9576 | Train Dice: 0.7386 | Val Dice: 0.7186
# Fold 3 | Epoch 53/100 | Train Loss: 0.5068 | Val Loss: 0.5091 | Train Acc: 0.9567 | Val Acc: 0.9551 | Train Dice: 0.7384 | Val Dice: 0.7337
# Fold 3 | Epoch 54/100 | Train Loss: 0.5050 | Val Loss: 0.5103 | Train Acc: 0.9561 | Val Acc: 0.9566 | Train Dice: 0.7412 | Val Dice: 0.7312
# Fold 3 | Epoch 55/100 | Train Loss: 0.5029 | Val Loss: 0.5134 | Train Acc: 0.9557 | Val Acc: 0.9569 | Train Dice: 0.7456 | Val Dice: 0.7277
# Fold 3 | Epoch 56/100 | Train Loss: 0.5031 | Val Loss: 0.5181 | Train Acc: 0.9563 | Val Acc: 0.9566 | Train Dice: 0.7433 | Val Dice: 0.7241
# Fold 3 | Epoch 57/100 | Train Loss: 0.5033 | Val Loss: 0.5040 | Train Acc: 0.9554 | Val Acc: 0.9564 | Train Dice: 0.7446 | Val Dice: 0.7361
# Fold 3 | Epoch 58/100 | Train Loss: 0.4992 | Val Loss: 0.5052 | Train Acc: 0.9564 | Val Acc: 0.9566 | Train Dice: 0.7452 | Val Dice: 0.7340
# Fold 3 | Epoch 59/100 | Train Loss: 0.5057 | Val Loss: 0.5149 | Train Acc: 0.9556 | Val Acc: 0.9542 | Train Dice: 0.7409 | Val Dice: 0.7314
# Fold 3 | Epoch 60/100 | Train Loss: 0.5008 | Val Loss: 0.5057 | Train Acc: 0.9561 | Val Acc: 0.9559 | Train Dice: 0.7418 | Val Dice: 0.7350
# Fold 3 | Epoch 61/100 | Train Loss: 0.4912 | Val Loss: 0.5286 | Train Acc: 0.9560 | Val Acc: 0.9578 | Train Dice: 0.7513 | Val Dice: 0.7131
# Fold 3 | Epoch 62/100 | Train Loss: 0.4985 | Val Loss: 0.5015 | Train Acc: 0.9566 | Val Acc: 0.9558 | Train Dice: 0.7427 | Val Dice: 0.7392
# Fold 3 | Epoch 63/100 | Train Loss: 0.5024 | Val Loss: 0.5004 | Train Acc: 0.9565 | Val Acc: 0.9562 | Train Dice: 0.7431 | Val Dice: 0.7396
# Fold 3 | Epoch 64/100 | Train Loss: 0.4923 | Val Loss: 0.5119 | Train Acc: 0.9561 | Val Acc: 0.9578 | Train Dice: 0.7522 | Val Dice: 0.7267
# Fold 3 | Epoch 65/100 | Train Loss: 0.4963 | Val Loss: 0.5044 | Train Acc: 0.9561 | Val Acc: 0.9565 | Train Dice: 0.7467 | Val Dice: 0.7355
# Fold 3 | Epoch 66/100 | Train Loss: 0.4870 | Val Loss: 0.5028 | Train Acc: 0.9579 | Val Acc: 0.9567 | Train Dice: 0.7521 | Val Dice: 0.7361
# Fold 3 | Epoch 67/100 | Train Loss: 0.4909 | Val Loss: 0.5149 | Train Acc: 0.9568 | Val Acc: 0.9575 | Train Dice: 0.7495 | Val Dice: 0.7221
# Fold 3 | Epoch 68/100 | Train Loss: 0.4843 | Val Loss: 0.5004 | Train Acc: 0.9577 | Val Acc: 0.9571 | Train Dice: 0.7556 | Val Dice: 0.7368
# Fold 3 | Epoch 69/100 | Train Loss: 0.4832 | Val Loss: 0.5033 | Train Acc: 0.9583 | Val Acc: 0.9576 | Train Dice: 0.7536 | Val Dice: 0.7340
# Fold 3 | Epoch 70/100 | Train Loss: 0.4793 | Val Loss: 0.4988 | Train Acc: 0.9583 | Val Acc: 0.9564 | Train Dice: 0.7569 | Val Dice: 0.7396
# Fold 3 | Epoch 71/100 | Train Loss: 0.4836 | Val Loss: 0.5077 | Train Acc: 0.9583 | Val Acc: 0.9543 | Train Dice: 0.7538 | Val Dice: 0.7374
# Fold 3 | Epoch 72/100 | Train Loss: 0.4846 | Val Loss: 0.5173 | Train Acc: 0.9572 | Val Acc: 0.9576 | Train Dice: 0.7530 | Val Dice: 0.7222
# Fold 3 | Epoch 73/100 | Train Loss: 0.4903 | Val Loss: 0.4959 | Train Acc: 0.9559 | Val Acc: 0.9577 | Train Dice: 0.7529 | Val Dice: 0.7398
# Fold 3 | Epoch 74/100 | Train Loss: 0.4876 | Val Loss: 0.5010 | Train Acc: 0.9580 | Val Acc: 0.9549 | Train Dice: 0.7532 | Val Dice: 0.7399
# Fold 3 | Epoch 75/100 | Train Loss: 0.4812 | Val Loss: 0.5195 | Train Acc: 0.9571 | Val Acc: 0.9578 | Train Dice: 0.7563 | Val Dice: 0.7191
# Fold 3 | Epoch 76/100 | Train Loss: 0.4797 | Val Loss: 0.5015 | Train Acc: 0.9581 | Val Acc: 0.9551 | Train Dice: 0.7561 | Val Dice: 0.7386
# Fold 3 | Epoch 77/100 | Train Loss: 0.4906 | Val Loss: 0.4992 | Train Acc: 0.9581 | Val Acc: 0.9557 | Train Dice: 0.7484 | Val Dice: 0.7389
# Fold 3 | Epoch 78/100 | Train Loss: 0.4800 | Val Loss: 0.5068 | Train Acc: 0.9572 | Val Acc: 0.9579 | Train Dice: 0.7588 | Val Dice: 0.7309
# Fold 3 | Epoch 79/100 | Train Loss: 0.4796 | Val Loss: 0.5013 | Train Acc: 0.9585 | Val Acc: 0.9555 | Train Dice: 0.7596 | Val Dice: 0.7384
# Fold 3 | Epoch 80/100 | Train Loss: 0.4757 | Val Loss: 0.5040 | Train Acc: 0.9583 | Val Acc: 0.9582 | Train Dice: 0.7595 | Val Dice: 0.7333
# Fold 3 | Epoch 81/100 | Train Loss: 0.4709 | Val Loss: 0.4973 | Train Acc: 0.9590 | Val Acc: 0.9582 | Train Dice: 0.7627 | Val Dice: 0.7377
# Fold 3 | Epoch 82/100 | Train Loss: 0.4654 | Val Loss: 0.4956 | Train Acc: 0.9604 | Val Acc: 0.9578 | Train Dice: 0.7651 | Val Dice: 0.7384
# Fold 3 | Epoch 83/100 | Train Loss: 0.4634 | Val Loss: 0.5017 | Train Acc: 0.9597 | Val Acc: 0.9581 | Train Dice: 0.7656 | Val Dice: 0.7330
# Fold 3 | Epoch 84/100 | Train Loss: 0.4698 | Val Loss: 0.5071 | Train Acc: 0.9593 | Val Acc: 0.9562 | Train Dice: 0.7617 | Val Dice: 0.7334
# Fold 3 | Epoch 85/100 | Train Loss: 0.4684 | Val Loss: 0.4970 | Train Acc: 0.9598 | Val Acc: 0.9572 | Train Dice: 0.7635 | Val Dice: 0.7401
# Fold 3 | Epoch 86/100 | Train Loss: 0.4660 | Val Loss: 0.4981 | Train Acc: 0.9595 | Val Acc: 0.9591 | Train Dice: 0.7652 | Val Dice: 0.7352
# Fold 3 | Epoch 87/100 | Train Loss: 0.4593 | Val Loss: 0.5055 | Train Acc: 0.9600 | Val Acc: 0.9582 | Train Dice: 0.7671 | Val Dice: 0.7307
# Fold 3 | Epoch 88/100 | Train Loss: 0.4647 | Val Loss: 0.5014 | Train Acc: 0.9599 | Val Acc: 0.9546 | Train Dice: 0.7676 | Val Dice: 0.7402
# Fold 3 | Epoch 89/100 | Train Loss: 0.4753 | Val Loss: 0.5005 | Train Acc: 0.9586 | Val Acc: 0.9570 | Train Dice: 0.7589 | Val Dice: 0.7368
# Fold 3 | Epoch 90/100 | Train Loss: 0.4687 | Val Loss: 0.5120 | Train Acc: 0.9586 | Val Acc: 0.9585 | Train Dice: 0.7641 | Val Dice: 0.7247
# Fold 3 | Epoch 91/100 | Train Loss: 0.4682 | Val Loss: 0.4845 | Train Acc: 0.9598 | Val Acc: 0.9576 | Train Dice: 0.7633 | Val Dice: 0.7467
# Fold 3 | Epoch 92/100 | Train Loss: 0.4681 | Val Loss: 0.4949 | Train Acc: 0.9601 | Val Acc: 0.9576 | Train Dice: 0.7630 | Val Dice: 0.7394
# Fold 3 | Epoch 93/100 | Train Loss: 0.4560 | Val Loss: 0.5113 | Train Acc: 0.9597 | Val Acc: 0.9586 | Train Dice: 0.7689 | Val Dice: 0.7255
# Fold 3 | Epoch 94/100 | Train Loss: 0.4597 | Val Loss: 0.4905 | Train Acc: 0.9608 | Val Acc: 0.9569 | Train Dice: 0.7690 | Val Dice: 0.7443
# Fold 3 | Epoch 95/100 | Train Loss: 0.4588 | Val Loss: 0.4933 | Train Acc: 0.9602 | Val Acc: 0.9587 | Train Dice: 0.7683 | Val Dice: 0.7396
# Fold 3 | Epoch 96/100 | Train Loss: 0.4544 | Val Loss: 0.4987 | Train Acc: 0.9609 | Val Acc: 0.9585 | Train Dice: 0.7730 | Val Dice: 0.7360
# Fold 3 | Epoch 97/100 | Train Loss: 0.4561 | Val Loss: 0.4954 | Train Acc: 0.9611 | Val Acc: 0.9565 | Train Dice: 0.7725 | Val Dice: 0.7418
# Fold 3 | Epoch 98/100 | Train Loss: 0.4582 | Val Loss: 0.5037 | Train Acc: 0.9602 | Val Acc: 0.9589 | Train Dice: 0.7692 | Val Dice: 0.7299
# Fold 3 | Epoch 99/100 | Train Loss: 0.4588 | Val Loss: 0.5006 | Train Acc: 0.9599 | Val Acc: 0.9590 | Train Dice: 0.7677 | Val Dice: 0.7327
# Fold 3 | Epoch 100/100 | Train Loss: 0.4550 | Val Loss: 0.4922 | Train Acc: 0.9616 | Val Acc: 0.9579 | Train Dice: 0.7700 | Val Dice: 0.7420
#
# ===== FOLD 4 ====
# Fold 4 | Epoch 1/100 | Train Loss: 1.2400 | Val Loss: 1.2292 | Train Acc: 0.9153 | Val Acc: 0.9010 | Train Dice: 0.0001 | Val Dice: 0.0000
# Fold 4 | Epoch 2/100 | Train Loss: 1.2275 | Val Loss: 1.2022 | Train Acc: 0.9153 | Val Acc: 0.9010 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 4 | Epoch 3/100 | Train Loss: 1.1589 | Val Loss: 1.2414 | Train Acc: 0.9162 | Val Acc: 0.9010 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 4 | Epoch 4/100 | Train Loss: 1.1065 | Val Loss: 1.1462 | Train Acc: 0.9147 | Val Acc: 0.9010 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 4 | Epoch 5/100 | Train Loss: 1.0704 | Val Loss: 1.1247 | Train Acc: 0.9142 | Val Acc: 0.9010 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 4 | Epoch 6/100 | Train Loss: 1.0493 | Val Loss: 1.1920 | Train Acc: 0.9184 | Val Acc: 0.9010 | Train Dice: 0.0977 | Val Dice: 0.0000
# Fold 4 | Epoch 7/100 | Train Loss: 1.0291 | Val Loss: 1.0926 | Train Acc: 0.9247 | Val Acc: 0.9010 | Train Dice: 0.2796 | Val Dice: 0.0000
# Fold 4 | Epoch 8/100 | Train Loss: 1.0126 | Val Loss: 1.0233 | Train Acc: 0.9230 | Val Acc: 0.9066 | Train Dice: 0.3516 | Val Dice: 0.1119
# Fold 4 | Epoch 9/100 | Train Loss: 0.9871 | Val Loss: 1.0144 | Train Acc: 0.9200 | Val Acc: 0.9091 | Train Dice: 0.4222 | Val Dice: 0.1785
# Fold 4 | Epoch 10/100 | Train Loss: 0.9456 | Val Loss: 0.9522 | Train Acc: 0.9168 | Val Acc: 0.9165 | Train Dice: 0.4654 | Val Dice: 0.3705
# Fold 4 | Epoch 11/100 | Train Loss: 0.9173 | Val Loss: 0.8788 | Train Acc: 0.9168 | Val Acc: 0.9193 | Train Dice: 0.4597 | Val Dice: 0.5061
# Fold 4 | Epoch 12/100 | Train Loss: 0.8719 | Val Loss: 0.8313 | Train Acc: 0.9168 | Val Acc: 0.9208 | Train Dice: 0.4985 | Val Dice: 0.5356
# Fold 4 | Epoch 13/100 | Train Loss: 0.8388 | Val Loss: 0.7824 | Train Acc: 0.9201 | Val Acc: 0.9192 | Train Dice: 0.5098 | Val Dice: 0.5744
# Fold 4 | Epoch 14/100 | Train Loss: 0.7952 | Val Loss: 0.7508 | Train Acc: 0.9238 | Val Acc: 0.9233 | Train Dice: 0.5420 | Val Dice: 0.6092
# Fold 4 | Epoch 15/100 | Train Loss: 0.7677 | Val Loss: 0.7268 | Train Acc: 0.9263 | Val Acc: 0.9256 | Train Dice: 0.5648 | Val Dice: 0.6198
# Fold 4 | Epoch 16/100 | Train Loss: 0.7344 | Val Loss: 0.6992 | Train Acc: 0.9327 | Val Acc: 0.9310 | Train Dice: 0.5895 | Val Dice: 0.6424
# Fold 4 | Epoch 17/100 | Train Loss: 0.7206 | Val Loss: 0.6876 | Train Acc: 0.9339 | Val Acc: 0.9360 | Train Dice: 0.6001 | Val Dice: 0.6443
# Fold 4 | Epoch 18/100 | Train Loss: 0.7061 | Val Loss: 0.6565 | Train Acc: 0.9358 | Val Acc: 0.9382 | Train Dice: 0.6120 | Val Dice: 0.6658
# Fold 4 | Epoch 19/100 | Train Loss: 0.6831 | Val Loss: 0.6457 | Train Acc: 0.9390 | Val Acc: 0.9343 | Train Dice: 0.6277 | Val Dice: 0.6740
# Fold 4 | Epoch 20/100 | Train Loss: 0.6656 | Val Loss: 0.6321 | Train Acc: 0.9400 | Val Acc: 0.9377 | Train Dice: 0.6396 | Val Dice: 0.6828
# Fold 4 | Epoch 21/100 | Train Loss: 0.6573 | Val Loss: 0.6261 | Train Acc: 0.9421 | Val Acc: 0.9362 | Train Dice: 0.6477 | Val Dice: 0.6851
# Fold 4 | Epoch 22/100 | Train Loss: 0.6500 | Val Loss: 0.6149 | Train Acc: 0.9413 | Val Acc: 0.9396 | Train Dice: 0.6499 | Val Dice: 0.6925
# Fold 4 | Epoch 23/100 | Train Loss: 0.6371 | Val Loss: 0.6049 | Train Acc: 0.9435 | Val Acc: 0.9411 | Train Dice: 0.6574 | Val Dice: 0.6957
# Fold 4 | Epoch 24/100 | Train Loss: 0.6256 | Val Loss: 0.6081 | Train Acc: 0.9435 | Val Acc: 0.9436 | Train Dice: 0.6629 | Val Dice: 0.6885
# Fold 4 | Epoch 25/100 | Train Loss: 0.6169 | Val Loss: 0.5987 | Train Acc: 0.9450 | Val Acc: 0.9434 | Train Dice: 0.6699 | Val Dice: 0.6978
# Fold 4 | Epoch 26/100 | Train Loss: 0.6002 | Val Loss: 0.5999 | Train Acc: 0.9475 | Val Acc: 0.9448 | Train Dice: 0.6793 | Val Dice: 0.6944
# Fold 4 | Epoch 27/100 | Train Loss: 0.5922 | Val Loss: 0.6017 | Train Acc: 0.9481 | Val Acc: 0.9449 | Train Dice: 0.6828 | Val Dice: 0.6903
# Fold 4 | Epoch 28/100 | Train Loss: 0.5934 | Val Loss: 0.5850 | Train Acc: 0.9469 | Val Acc: 0.9452 | Train Dice: 0.6830 | Val Dice: 0.7034
# Fold 4 | Epoch 29/100 | Train Loss: 0.5978 | Val Loss: 0.5885 | Train Acc: 0.9480 | Val Acc: 0.9400 | Train Dice: 0.6787 | Val Dice: 0.7069
# Fold 4 | Epoch 30/100 | Train Loss: 0.6005 | Val Loss: 0.5894 | Train Acc: 0.9474 | Val Acc: 0.9458 | Train Dice: 0.6754 | Val Dice: 0.6987
# Fold 4 | Epoch 31/100 | Train Loss: 0.5907 | Val Loss: 0.5702 | Train Acc: 0.9458 | Val Acc: 0.9464 | Train Dice: 0.6895 | Val Dice: 0.7151
# Fold 4 | Epoch 32/100 | Train Loss: 0.5767 | Val Loss: 0.5649 | Train Acc: 0.9497 | Val Acc: 0.9443 | Train Dice: 0.6925 | Val Dice: 0.7201
# Fold 4 | Epoch 33/100 | Train Loss: 0.5712 | Val Loss: 0.5672 | Train Acc: 0.9502 | Val Acc: 0.9463 | Train Dice: 0.6940 | Val Dice: 0.7178
# Fold 4 | Epoch 34/100 | Train Loss: 0.5836 | Val Loss: 0.5723 | Train Acc: 0.9464 | Val Acc: 0.9469 | Train Dice: 0.6932 | Val Dice: 0.7120
# Fold 4 | Epoch 35/100 | Train Loss: 0.5729 | Val Loss: 0.5599 | Train Acc: 0.9492 | Val Acc: 0.9451 | Train Dice: 0.6969 | Val Dice: 0.7227
# Fold 4 | Epoch 36/100 | Train Loss: 0.5621 | Val Loss: 0.5558 | Train Acc: 0.9510 | Val Acc: 0.9465 | Train Dice: 0.7011 | Val Dice: 0.7233
# Fold 4 | Epoch 37/100 | Train Loss: 0.5484 | Val Loss: 0.5726 | Train Acc: 0.9513 | Val Acc: 0.9482 | Train Dice: 0.7104 | Val Dice: 0.7095
# Fold 4 | Epoch 38/100 | Train Loss: 0.5528 | Val Loss: 0.5477 | Train Acc: 0.9513 | Val Acc: 0.9481 | Train Dice: 0.7072 | Val Dice: 0.7278
# Fold 4 | Epoch 39/100 | Train Loss: 0.5469 | Val Loss: 0.5458 | Train Acc: 0.9532 | Val Acc: 0.9485 | Train Dice: 0.7097 | Val Dice: 0.7290
# Fold 4 | Epoch 40/100 | Train Loss: 0.5452 | Val Loss: 0.5542 | Train Acc: 0.9520 | Val Acc: 0.9487 | Train Dice: 0.7128 | Val Dice: 0.7227
# Fold 4 | Epoch 41/100 | Train Loss: 0.5463 | Val Loss: 0.5661 | Train Acc: 0.9519 | Val Acc: 0.9470 | Train Dice: 0.7116 | Val Dice: 0.7159
# Fold 4 | Epoch 42/100 | Train Loss: 0.5356 | Val Loss: 0.5637 | Train Acc: 0.9545 | Val Acc: 0.9485 | Train Dice: 0.7173 | Val Dice: 0.7167
# ...
# Fold 9 | Epoch 88/100 | Train Loss: 0.4549 | Val Loss: 0.5051 | Train Acc: 0.9610 | Val Acc: 0.9571 | Train Dice: 0.7702 | Val Dice: 0.7304
# Fold 9 | Epoch 89/100 | Train Loss: 0.4633 | Val Loss: 0.4968 | Train Acc: 0.9596 | Val Acc: 0.9602 | Train Dice: 0.7670 | Val Dice: 0.7316
# Fold 9 | Epoch 90/100 | Train Loss: 0.4660 | Val Loss: 0.4918 | Train Acc: 0.9591 | Val Acc: 0.9590 | Train Dice: 0.7634 | Val Dice: 0.7387
# Fold 9 | Epoch 91/100 | Train Loss: 0.4566 | Val Loss: 0.4983 | Train Acc: 0.9612 | Val Acc: 0.9569 | Train Dice: 0.7698 | Val Dice: 0.7362
# Fold 9 | Epoch 92/100 | Train Loss: 0.4603 | Val Loss: 0.4883 | Train Acc: 0.9600 | Val Acc: 0.9596 | Train Dice: 0.7677 | Val Dice: 0.7394
# Fold 9 | Epoch 93/100 | Train Loss: 0.4535 | Val Loss: 0.4950 | Train Acc: 0.9607 | Val Acc: 0.9586 | Train Dice: 0.7729 | Val Dice: 0.7349
# Fold 9 | Epoch 94/100 | Train Loss: 0.4516 | Val Loss: 0.4902 | Train Acc: 0.9614 | Val Acc: 0.9592 | Train Dice: 0.7733 | Val Dice: 0.7381
# Fold 9 | Epoch 95/100 | Train Loss: 0.4490 | Val Loss: 0.4960 | Train Acc: 0.9616 | Val Acc: 0.9577 | Train Dice: 0.7734 | Val Dice: 0.7360
# Fold 9 | Epoch 96/100 | Train Loss: 0.4581 | Val Loss: 0.5064 | Train Acc: 0.9603 | Val Acc: 0.9557 | Train Dice: 0.7709 | Val Dice: 0.7321
# Fold 9 | Epoch 97/100 | Train Loss: 0.4575 | Val Loss: 0.4979 | Train Acc: 0.9605 | Val Acc: 0.9573 | Train Dice: 0.7712 | Val Dice: 0.7369
# Fold 9 | Epoch 98/100 | Train Loss: 0.4498 | Val Loss: 0.5005 | Train Acc: 0.9610 | Val Acc: 0.9603 | Train Dice: 0.7762 | Val Dice: 0.7296
# Fold 9 | Epoch 99/100 | Train Loss: 0.4534 | Val Loss: 0.4893 | Train Acc: 0.9604 | Val Acc: 0.9592 | Train Dice: 0.7695 | Val Dice: 0.7398
# Fold 9 | Epoch 100/100 | Train Loss: 0.4528 | Val Loss: 0.4891 | Train Acc: 0.9615 | Val Acc: 0.9584 | Train Dice: 0.7699 | Val Dice: 0.7404
#
# ===== FOLD 10 ====
# Fold 10 | Epoch 1/100 | Train Loss: 1.2714 | Val Loss: 1.2778 | Train Acc: 0.0880 | Val Acc: 0.0874 | Train Dice: 0.1616 | Val Dice: 0.1607
# Fold 10 | Epoch 2/100 | Train Loss: 1.2609 | Val Loss: 1.2536 | Train Acc: 0.1492 | Val Acc: 0.8546 | Train Dice: 0.1689 | Val Dice: 0.0465
# Fold 10 | Epoch 3/100 | Train Loss: 1.1979 | Val Loss: 1.2291 | Train Acc: 0.8618 | Val Acc: 0.9126 | Train Dice: 0.0949 | Val Dice: 0.0000
# Fold 10 | Epoch 4/100 | Train Loss: 1.1153 | Val Loss: 1.2928 | Train Acc: 0.9126 | Val Acc: 0.9126 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 10 | Epoch 5/100 | Train Loss: 1.0869 | Val Loss: 1.1985 | Train Acc: 0.9136 | Val Acc: 0.9126 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 10 | Epoch 6/100 | Train Loss: 1.0624 | Val Loss: 1.1551 | Train Acc: 0.9137 | Val Acc: 0.9126 | Train Dice: 0.0077 | Val Dice: 0.0000
# Fold 10 | Epoch 7/100 | Train Loss: 1.0526 | Val Loss: 1.1313 | Train Acc: 0.9188 | Val Acc: 0.9126 | Train Dice: 0.1762 | Val Dice: 0.0000
# Fold 10 | Epoch 8/100 | Train Loss: 1.0479 | Val Loss: 1.0660 | Train Acc: 0.9166 | Val Acc: 0.9138 | Train Dice: 0.2682 | Val Dice: 0.0316
# Fold 10 | Epoch 9/100 | Train Loss: 1.0316 | Val Loss: 1.0506 | Train Acc: 0.9195 | Val Acc: 0.9198 | Train Dice: 0.3490 | Val Dice: 0.2234
# Fold 10 | Epoch 10/100 | Train Loss: 1.0297 | Val Loss: 1.0347 | Train Acc: 0.9164 | Val Acc: 0.9225 | Train Dice: 0.3761 | Val Dice: 0.3514
# Fold 10 | Epoch 11/100 | Train Loss: 1.0129 | Val Loss: 1.0234 | Train Acc: 0.9161 | Val Acc: 0.9243 | Train Dice: 0.3897 | Val Dice: 0.4610
# Fold 10 | Epoch 12/100 | Train Loss: 0.9973 | Val Loss: 0.9993 | Train Acc: 0.9189 | Val Acc: 0.9223 | Train Dice: 0.4423 | Val Dice: 0.4738
# Fold 10 | Epoch 13/100 | Train Loss: 0.9796 | Val Loss: 0.9719 | Train Acc: 0.9184 | Val Acc: 0.9217 | Train Dice: 0.4311 | Val Dice: 0.5000
# Fold 10 | Epoch 14/100 | Train Loss: 0.9470 | Val Loss: 0.9450 | Train Acc: 0.9216 | Val Acc: 0.9182 | Train Dice: 0.4670 | Val Dice: 0.5334
# Fold 10 | Epoch 15/100 | Train Loss: 0.9170 | Val Loss: 0.8954 | Train Acc: 0.9225 | Val Acc: 0.9221 | Train Dice: 0.4993 | Val Dice: 0.5457
# Fold 10 | Epoch 16/100 | Train Loss: 0.8746 | Val Loss: 0.8512 | Train Acc: 0.9250 | Val Acc: 0.9254 | Train Dice: 0.5345 | Val Dice: 0.5524
# Fold 10 | Epoch 17/100 | Train Loss: 0.8405 | Val Loss: 0.8093 | Train Acc: 0.9239 | Val Acc: 0.9237 | Train Dice: 0.5468 | Val Dice: 0.5884
# Fold 10 | Epoch 18/100 | Train Loss: 0.7948 | Val Loss: 0.7813 | Train Acc: 0.9259 | Val Acc: 0.9190 | Train Dice: 0.5736 | Val Dice: 0.6001
# Fold 10 | Epoch 19/100 | Train Loss: 0.7454 | Val Loss: 0.7361 | Train Acc: 0.9307 | Val Acc: 0.9324 | Train Dice: 0.5985 | Val Dice: 0.6103
# Fold 10 | Epoch 20/100 | Train Loss: 0.7278 | Val Loss: 0.7370 | Train Acc: 0.9311 | Val Acc: 0.9206 | Train Dice: 0.6036 | Val Dice: 0.6104
# Fold 10 | Epoch 21/100 | Train Loss: 0.6998 | Val Loss: 0.7117 | Train Acc: 0.9351 | Val Acc: 0.9282 | Train Dice: 0.6216 | Val Dice: 0.6299
# Fold 10 | Epoch 22/100 | Train Loss: 0.6763 | Val Loss: 0.6857 | Train Acc: 0.9384 | Val Acc: 0.9341 | Train Dice: 0.6373 | Val Dice: 0.6393
# Fold 10 | Epoch 23/100 | Train Loss: 0.6686 | Val Loss: 0.6785 | Train Acc: 0.9392 | Val Acc: 0.9334 | Train Dice: 0.6416 | Val Dice: 0.6466
# Fold 10 | Epoch 24/100 | Train Loss: 0.6472 | Val Loss: 0.6566 | Train Acc: 0.9415 | Val Acc: 0.9378 | Train Dice: 0.6559 | Val Dice: 0.6550
# Fold 10 | Epoch 25/100 | Train Loss: 0.6434 | Val Loss: 0.6486 | Train Acc: 0.9419 | Val Acc: 0.9381 | Train Dice: 0.6576 | Val Dice: 0.6618
# Fold 10 | Epoch 26/100 | Train Loss: 0.6324 | Val Loss: 0.6597 | Train Acc: 0.9430 | Val Acc: 0.9335 | Train Dice: 0.6638 | Val Dice: 0.6545
# Fold 10 | Epoch 27/100 | Train Loss: 0.6229 | Val Loss: 0.6406 | Train Acc: 0.9445 | Val Acc: 0.9363 | Train Dice: 0.6664 | Val Dice: 0.6671
# Fold 10 | Epoch 28/100 | Train Loss: 0.6094 | Val Loss: 0.6195 | Train Acc: 0.9444 | Val Acc: 0.9441 | Train Dice: 0.6777 | Val Dice: 0.6779
# Fold 10 | Epoch 29/100 | Train Loss: 0.6045 | Val Loss: 0.6200 | Train Acc: 0.9458 | Val Acc: 0.9405 | Train Dice: 0.6816 | Val Dice: 0.6792
# Fold 10 | Epoch 30/100 | Train Loss: 0.5944 | Val Loss: 0.6041 | Train Acc: 0.9461 | Val Acc: 0.9441 | Train Dice: 0.6892 | Val Dice: 0.6875
# Fold 10 | Epoch 31/100 | Train Loss: 0.5793 | Val Loss: 0.6009 | Train Acc: 0.9488 | Val Acc: 0.9439 | Train Dice: 0.6980 | Val Dice: 0.6881
# Fold 10 | Epoch 32/100 | Train Loss: 0.5770 | Val Loss: 0.5912 | Train Acc: 0.9485 | Val Acc: 0.9456 | Train Dice: 0.6984 | Val Dice: 0.6963
# Fold 10 | Epoch 33/100 | Train Loss: 0.5720 | Val Loss: 0.5871 | Train Acc: 0.9488 | Val Acc: 0.9488 | Train Dice: 0.6988 | Val Dice: 0.6930
# Fold 10 | Epoch 34/100 | Train Loss: 0.5690 | Val Loss: 0.5792 | Train Acc: 0.9493 | Val Acc: 0.9489 | Train Dice: 0.7018 | Val Dice: 0.7003
# Fold 10 | Epoch 35/100 | Train Loss: 0.5644 | Val Loss: 0.5771 | Train Acc: 0.9503 | Val Acc: 0.9475 | Train Dice: 0.7039 | Val Dice: 0.7044
# Fold 10 | Epoch 36/100 | Train Loss: 0.5529 | Val Loss: 0.5691 | Train Acc: 0.9523 | Val Acc: 0.9491 | Train Dice: 0.7115 | Val Dice: 0.7079
# Fold 10 | Epoch 37/100 | Train Loss: 0.5560 | Val Loss: 0.5655 | Train Acc: 0.9509 | Val Acc: 0.9493 | Train Dice: 0.7108 | Val Dice: 0.7103
# Fold 10 | Epoch 38/100 | Train Loss: 0.5560 | Val Loss: 0.5761 | Train Acc: 0.9503 | Val Acc: 0.9518 | Train Dice: 0.7117 | Val Dice: 0.6989
# Fold 10 | Epoch 39/100 | Train Loss: 0.5507 | Val Loss: 0.5659 | Train Acc: 0.9518 | Val Acc: 0.9460 | Train Dice: 0.7151 | Val Dice: 0.7103
# Fold 10 | Epoch 40/100 | Train Loss: 0.5372 | Val Loss: 0.5544 | Train Acc: 0.9528 | Val Acc: 0.9510 | Train Dice: 0.7192 | Val Dice: 0.7180
# Fold 10 | Epoch 41/100 | Train Loss: 0.5339 | Val Loss: 0.5612 | Train Acc: 0.9544 | Val Acc: 0.9470 | Train Dice: 0.7221 | Val Dice: 0.7145
# Fold 10 | Epoch 42/100 | Train Loss: 0.5440 | Val Loss: 0.5539 | Train Acc: 0.9520 | Val Acc: 0.9492 | Train Dice: 0.7157 | Val Dice: 0.7176
# Fold 10 | Epoch 43/100 | Train Loss: 0.5371 | Val Loss: 0.5471 | Train Acc: 0.9522 | Val Acc: 0.9506 | Train Dice: 0.7216 | Val Dice: 0.7213
# Fold 10 | Epoch 44/100 | Train Loss: 0.5219 | Val Loss: 0.5526 | Train Acc: 0.9539 | Val Acc: 0.9525 | Train Dice: 0.7275 | Val Dice: 0.7159
# Fold 10 | Epoch 45/100 | Train Loss: 0.5289 | Val Loss: 0.5472 | Train Acc: 0.9534 | Val Acc: 0.9499 | Train Dice: 0.7243 | Val Dice: 0.7201
# Fold 10 | Epoch 46/100 | Train Loss: 0.5278 | Val Loss: 0.5419 | Train Acc: 0.9542 | Val Acc: 0.9520 | Train Dice: 0.7279 | Val Dice: 0.7225
# Fold 10 | Epoch 47/100 | Train Loss: 0.5189 | Val Loss: 0.5388 | Train Acc: 0.9545 | Val Acc: 0.9533 | Train Dice: 0.7318 | Val Dice: 0.7236
# Fold 10 | Epoch 48/100 | Train Loss: 0.5213 | Val Loss: 0.5459 | Train Acc: 0.9540 | Val Acc: 0.9511 | Train Dice: 0.7324 | Val Dice: 0.7191
# Fold 10 | Epoch 49/100 | Train Loss: 0.5272 | Val Loss: 0.5385 | Train Acc: 0.9534 | Val Acc: 0.9528 | Train Dice: 0.7273 | Val Dice: 0.7239
# Fold 10 | Epoch 50/100 | Train Loss: 0.5170 | Val Loss: 0.5350 | Train Acc: 0.9548 | Val Acc: 0.9524 | Train Dice: 0.7338 | Val Dice: 0.7264
# Fold 10 | Epoch 51/100 | Train Loss: 0.5144 | Val Loss: 0.5316 | Train Acc: 0.9555 | Val Acc: 0.9524 | Train Dice: 0.7344 | Val Dice: 0.7284
# Fold 10 | Epoch 52/100 | Train Loss: 0.5072 | Val Loss: 0.5353 | Train Acc: 0.9556 | Val Acc: 0.9547 | Train Dice: 0.7381 | Val Dice: 0.7244
# Fold 10 | Epoch 53/100 | Train Loss: 0.5106 | Val Loss: 0.5489 | Train Acc: 0.9548 | Val Acc: 0.9545 | Train Dice: 0.7370 | Val Dice: 0.7141
# Fold 10 | Epoch 54/100 | Train Loss: 0.5177 | Val Loss: 0.5372 | Train Acc: 0.9546 | Val Acc: 0.9501 | Train Dice: 0.7324 | Val Dice: 0.7294
# Fold 10 | Epoch 55/100 | Train Loss: 0.5055 | Val Loss: 0.5387 | Train Acc: 0.9571 | Val Acc: 0.9498 | Train Dice: 0.7393 | Val Dice: 0.7287
# Fold 10 | Epoch 56/100 | Train Loss: 0.5068 | Val Loss: 0.5385 | Train Acc: 0.9548 | Val Acc: 0.9547 | Train Dice: 0.7396 | Val Dice: 0.7232
# Fold 10 | Epoch 57/100 | Train Loss: 0.5109 | Val Loss: 0.5434 | Train Acc: 0.9556 | Val Acc: 0.9476 | Train Dice: 0.7335 | Val Dice: 0.7250
# Fold 10 | Epoch 58/100 | Train Loss: 0.5072 | Val Loss: 0.5262 | Train Acc: 0.9559 | Val Acc: 0.9544 | Train Dice: 0.7374 | Val Dice: 0.7310
# Fold 10 | Epoch 59/100 | Train Loss: 0.5024 | Val Loss: 0.5259 | Train Acc: 0.9552 | Val Acc: 0.9521 | Train Dice: 0.7408 | Val Dice: 0.7326
# Fold 10 | Epoch 60/100 | Train Loss: 0.5004 | Val Loss: 0.5301 | Train Acc: 0.9577 | Val Acc: 0.9511 | Train Dice: 0.7418 | Val Dice: 0.7324
# Fold 10 | Epoch 61/100 | Train Loss: 0.4993 | Val Loss: 0.5262 | Train Acc: 0.9560 | Val Acc: 0.9540 | Train Dice: 0.7435 | Val Dice: 0.7303
# Fold 10 | Epoch 62/100 | Train Loss: 0.4976 | Val Loss: 0.5217 | Train Acc: 0.9563 | Val Acc: 0.9537 | Train Dice: 0.7430 | Val Dice: 0.7346
# Fold 10 | Epoch 63/100 | Train Loss: 0.4935 | Val Loss: 0.5309 | Train Acc: 0.9576 | Val Acc: 0.9495 | Train Dice: 0.7477 | Val Dice: 0.7303
# Fold 10 | Epoch 64/100 | Train Loss: 0.5053 | Val Loss: 0.5194 | Train Acc: 0.9556 | Val Acc: 0.9535 | Train Dice: 0.7398 | Val Dice: 0.7365
# Fold 10 | Epoch 65/100 | Train Loss: 0.4959 | Val Loss: 0.5248 | Train Acc: 0.9560 | Val Acc: 0.9548 | Train Dice: 0.7479 | Val Dice: 0.7313
# Fold 10 | Epoch 66/100 | Train Loss: 0.4889 | Val Loss: 0.5403 | Train Acc: 0.9578 | Val Acc: 0.9472 | Train Dice: 0.7493 | Val Dice: 0.7263
# Fold 10 | Epoch 67/100 | Train Loss: 0.5028 | Val Loss: 0.5122 | Train Acc: 0.9560 | Val Acc: 0.9555 | Train Dice: 0.7415 | Val Dice: 0.7384
# Fold 10 | Epoch 68/100 | Train Loss: 0.4913 | Val Loss: 0.5204 | Train Acc: 0.9564 | Val Acc: 0.9543 | Train Dice: 0.7454 | Val Dice: 0.7337
# Fold 10 | Epoch 69/100 | Train Loss: 0.4922 | Val Loss: 0.5243 | Train Acc: 0.9581 | Val Acc: 0.9507 | Train Dice: 0.7465 | Val Dice: 0.7356
# Fold 10 | Epoch 70/100 | Train Loss: 0.4884 | Val Loss: 0.5115 | Train Acc: 0.9579 | Val Acc: 0.9553 | Train Dice: 0.7491 | Val Dice: 0.7390
# Fold 10 | Epoch 71/100 | Train Loss: 0.4870 | Val Loss: 0.5173 | Train Acc: 0.9572 | Val Acc: 0.9530 | Train Dice: 0.7501 | Val Dice: 0.7359
# Fold 10 | Epoch 72/100 | Train Loss: 0.4850 | Val Loss: 0.5166 | Train Acc: 0.9578 | Val Acc: 0.9525 | Train Dice: 0.7495 | Val Dice: 0.7376
# Fold 10 | Epoch 73/100 | Train Loss: 0.4789 | Val Loss: 0.5141 | Train Acc: 0.9586 | Val Acc: 0.9538 | Train Dice: 0.7551 | Val Dice: 0.7383
# Fold 10 | Epoch 74/100 | Train Loss: 0.4783 | Val Loss: 0.5165 | Train Acc: 0.9585 | Val Acc: 0.9531 | Train Dice: 0.7545 | Val Dice: 0.7381
# Fold 10 | Epoch 75/100 | Train Loss: 0.4785 | Val Loss: 0.5080 | Train Acc: 0.9582 | Val Acc: 0.9559 | Train Dice: 0.7565 | Val Dice: 0.7408
# Fold 10 | Epoch 76/100 | Train Loss: 0.4784 | Val Loss: 0.5146 | Train Acc: 0.9580 | Val Acc: 0.9551 | Train Dice: 0.7587 | Val Dice: 0.7366
# Fold 10 | Epoch 77/100 | Train Loss: 0.4741 | Val Loss: 0.5166 | Train Acc: 0.9593 | Val Acc: 0.9524 | Train Dice: 0.7562 | Val Dice: 0.7376
# Fold 10 | Epoch 78/100 | Train Loss: 0.4742 | Val Loss: 0.5132 | Train Acc: 0.9600 | Val Acc: 0.9532 | Train Dice: 0.7556 | Val Dice: 0.7400
# Fold 10 | Epoch 79/100 | Train Loss: 0.4722 | Val Loss: 0.5090 | Train Acc: 0.9592 | Val Acc: 0.9546 | Train Dice: 0.7612 | Val Dice: 0.7402
# Fold 10 | Epoch 80/100 | Train Loss: 0.4772 | Val Loss: 0.5140 | Train Acc: 0.9581 | Val Acc: 0.9547 | Train Dice: 0.7570 | Val Dice: 0.7363
# Fold 10 | Epoch 81/100 | Train Loss: 0.4722 | Val Loss: 0.5107 | Train Acc: 0.9594 | Val Acc: 0.9538 | Train Dice: 0.7581 | Val Dice: 0.7401
# Fold 10 | Epoch 82/100 | Train Loss: 0.4685 | Val Loss: 0.5230 | Train Acc: 0.9600 | Val Acc: 0.9498 | Train Dice: 0.7597 | Val Dice: 0.7348
# Fold 10 | Epoch 83/100 | Train Loss: 0.4745 | Val Loss: 0.5125 | Train Acc: 0.9583 | Val Acc: 0.9560 | Train Dice: 0.7579 | Val Dice: 0.7369
# Fold 10 | Epoch 84/100 | Train Loss: 0.4689 | Val Loss: 0.5157 | Train Acc: 0.9589 | Val Acc: 0.9553 | Train Dice: 0.7619 | Val Dice: 0.7351
# Fold 10 | Epoch 85/100 | Train Loss: 0.4627 | Val Loss: 0.5167 | Train Acc: 0.9610 | Val Acc: 0.9519 | Train Dice: 0.7626 | Val Dice: 0.7378
# Fold 10 | Epoch 86/100 | Train Loss: 0.4680 | Val Loss: 0.5108 | Train Acc: 0.9596 | Val Acc: 0.9550 | Train Dice: 0.7610 | Val Dice: 0.7386
# Fold 10 | Epoch 87/100 | Train Loss: 0.4646 | Val Loss: 0.5050 | Train Acc: 0.9596 | Val Acc: 0.9549 | Train Dice: 0.7649 | Val Dice: 0.7429
# Fold 10 | Epoch 88/100 | Train Loss: 0.4596 | Val Loss: 0.5055 | Train Acc: 0.9609 | Val Acc: 0.9548 | Train Dice: 0.7652 | Val Dice: 0.7412
# Fold 10 | Epoch 89/100 | Train Loss: 0.4613 | Val Loss: 0.5067 | Train Acc: 0.9607 | Val Acc: 0.9544 | Train Dice: 0.7644 | Val Dice: 0.7424
# Fold 10 | Epoch 90/100 | Train Loss: 0.4579 | Val Loss: 0.5010 | Train Acc: 0.9608 | Val Acc: 0.9560 | Train Dice: 0.7671 | Val Dice: 0.7432
# Fold 10 | Epoch 91/100 | Train Loss: 0.4586 | Val Loss: 0.5079 | Train Acc: 0.9606 | Val Acc: 0.9540 | Train Dice: 0.7664 | Val Dice: 0.7401
# Fold 10 | Epoch 92/100 | Train Loss: 0.4540 | Val Loss: 0.5058 | Train Acc: 0.9613 | Val Acc: 0.9544 | Train Dice: 0.7681 | Val Dice: 0.7422
# Fold 10 | Epoch 93/100 | Train Loss: 0.4581 | Val Loss: 0.5122 | Train Acc: 0.9606 | Val Acc: 0.9567 | Train Dice: 0.7677 | Val Dice: 0.7328
# Fold 10 | Epoch 94/100 | Train Loss: 0.4654 | Val Loss: 0.5052 | Train Acc: 0.9592 | Val Acc: 0.9564 | Train Dice: 0.7617 | Val Dice: 0.7405
# Fold 10 | Epoch 95/100 | Train Loss: 0.4728 | Val Loss: 0.5132 | Train Acc: 0.9594 | Val Acc: 0.9515 | Train Dice: 0.7572 | Val Dice: 0.7418
# Fold 10 | Epoch 96/100 | Train Loss: 0.4596 | Val Loss: 0.5046 | Train Acc: 0.9604 | Val Acc: 0.9542 | Train Dice: 0.7672 | Val Dice: 0.7432
# Fold 10 | Epoch 97/100 | Train Loss: 0.4540 | Val Loss: 0.5035 | Train Acc: 0.9606 | Val Acc: 0.9567 | Train Dice: 0.7699 | Val Dice: 0.7408
# Fold 10 | Epoch 98/100 | Train Loss: 0.4614 | Val Loss: 0.5133 | Train Acc: 0.9603 | Val Acc: 0.9519 | Train Dice: 0.7637 | Val Dice: 0.7398
# Fold 10 | Epoch 99/100 | Train Loss: 0.4493 | Val Loss: 0.5037 | Train Acc: 0.9616 | Val Acc: 0.9566 | Train Dice: 0.7721 | Val Dice: 0.7410
# Fold 10 | Epoch 100/100 | Train Loss: 0.4552 | Val Loss: 0.5048 | Train Acc: 0.9607 | Val Acc: 0.9554 | Train Dice: 0.7704 | Val Dice: 0.7408

# %%
# === FINAL EVALUATION ===
final_metrics = evaluate_test(model, val_loader, device)


fold_results.append({
    "metrics": final_metrics,
    "history": history
})

# %%
save_path_bobot = os.path.join(
    save_dir,
    f"DRIVE_model_bobot_resASPP_Unet_paper_pre_fold{fold+1}.pth"
)

torch.save({
    'model_state_dict': model.state_dict(),
    'metrics': final_metrics,
    'history': history
}, save_path_bobot)

print(f" Model + history fold {fold+1} disimpan di:")
print(save_path_bobot)
# Out:
#  Model + history fold 10 disimpan di:
# /content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_bobot_resASPP_Unet_paper_pre_fold10.pth

# %%
model = ResASPP_UNet()
path = "/content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_bobot_resASPP_Unet_paper_pre_fold10.pth"
checkpoint = torch.load(path, map_location=device)

model.load_state_dict(checkpoint['model_state_dict'])

model.to(device)
model.eval()

# optional
print(checkpoint['metrics'])
# Out:
# {'loss': 0.5048386454582214, 'Accuracy': 0.955430984495248, 'Sensitivity': 0.7293999519627747, 'Specificity': 0.9770729923173058, 'Dice': 0.7407699823379517, 'IoU': 0.5884199142456055}

# %%
import matplotlib.pyplot as plt

def plot_history(history):
    plt.figure(figsize=(18, 5))


    # Plot Loss
    plt.subplot(1,3,1)
    plt.plot(history['train_loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Val Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Plot Accuracy
    plt.subplot(1,3,2)
    plt.plot(history['train_acc'], label='Train Accuracy')
    plt.plot(history['val_acc'], label='Val Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Dice Score
    plt.subplot(1, 3, 3)
    plt.plot(history['train_dice'], label='Train Dice', color='blue')
    plt.plot(history['val_dice'], label='Val Dice', color='orange')
    plt.title('Dice Score per Epoch')
    plt.xlabel('Epoch')
    plt.ylabel('Dice')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# %%
# === Tampilkan model summary ===
from torchinfo import summary # Import summary
print("Model Summary:")
summary(
    model,
    input_size=(1, 1, 512, 512),  # (batch, channels, H, W) - Adjusted for single channel green image and common size for DRIVE
    col_names=["input_size", "output_size", "num_params", "kernel_size", "mult_adds"],
    col_width=20,
    row_settings=["var_names"]
)
# Out:
# Model Summary:
# =================================================================================================================================================
# Layer (type (var_name))                       Input Shape          Output Shape         Param #              Kernel Shape         Mult-Adds
# =================================================================================================================================================
# ResASPP_UNet (ResASPP_UNet)                   [1, 1, 512, 512]     [1, 1, 512, 512]     --                   --                   --
# ├─DeepLabEncoder (encoder)                    [1, 1, 512, 512]     [1, 256, 128, 128]   --                   --                   --
# │    └─Sequential (initial)                   [1, 1, 512, 512]     [1, 64, 128, 128]    --                   --                   --
# │    │    └─Conv2d (0)                        [1, 1, 512, 512]     [1, 64, 256, 256]    3,136                [7, 7]               205,520,896
# │    │    └─BatchNorm2d (1)                   [1, 64, 256, 256]    [1, 64, 256, 256]    128                  --                   128
# │    │    └─ReLU (2)                          [1, 64, 256, 256]    [1, 64, 256, 256]    --                   --                   --
# │    │    └─MaxPool2d (3)                     [1, 64, 256, 256]    [1, 64, 128, 128]    --                   3                    --
# │    └─Sequential (layer1)                    [1, 64, 128, 128]    [1, 256, 128, 128]   --                   --                   --
# │    │    └─Bottleneck (0)                    [1, 64, 128, 128]    [1, 256, 128, 128]   75,008               --                   1,207,960,832
# │    │    └─Bottleneck (1)                    [1, 256, 128, 128]   [1, 256, 128, 128]   70,400               --                   1,140,851,456
# │    │    └─Bottleneck (2)                    [1, 256, 128, 128]   [1, 256, 128, 128]   70,400               --                   1,140,851,456
# │    └─Sequential (layer2)                    [1, 256, 128, 128]   [1, 512, 64, 64]     --                   --                   --
# │    │    └─Bottleneck (0)                    [1, 256, 128, 128]   [1, 512, 64, 64]     379,392              --                   1,946,159,616
# │    │    └─Bottleneck (1)                    [1, 512, 64, 64]     [1, 512, 64, 64]     280,064              --                   1,140,852,224
# │    │    └─Bottleneck (2)                    [1, 512, 64, 64]     [1, 512, 64, 64]     280,064              --                   1,140,852,224
# │    │    └─Bottleneck (3)                    [1, 512, 64, 64]     [1, 512, 64, 64]     280,064              --                   1,140,852,224
# │    └─Sequential (layer3)                    [1, 512, 64, 64]     [1, 1024, 32, 32]    --                   --                   --
# │    │    └─Bottleneck (0)                    [1, 512, 64, 64]     [1, 1024, 32, 32]    1,512,448            --                   1,946,162,176
# │    │    └─Bottleneck (1)                    [1, 1024, 32, 32]    [1, 1024, 32, 32]    1,117,184            --                   1,140,853,760
# │    │    └─Bottleneck (2)                    [1, 1024, 32, 32]    [1, 1024, 32, 32]    1,117,184            --                   1,140,853,760
# │    │    └─Bottleneck (3)                    [1, 1024, 32, 32]    [1, 1024, 32, 32]    1,117,184            --                   1,140,853,760
# │    │    └─Bottleneck (4)                    [1, 1024, 32, 32]    [1, 1024, 32, 32]    1,117,184            --                   1,140,853,760
# │    │    └─Bottleneck (5)                    [1, 1024, 32, 32]    [1, 1024, 32, 32]    1,117,184            --                   1,140,853,760
# │    └─Sequential (layer4)                    [1, 1024, 32, 32]    [1, 2048, 16, 16]    --                   --                   --
# │    │    └─Bottleneck (0)                    [1, 1024, 32, 32]    [1, 2048, 16, 16]    6,039,552            --                   1,946,167,296
# │    │    └─Bottleneck (1)                    [1, 2048, 16, 16]    [1, 2048, 16, 16]    4,462,592            --                   1,140,856,832
# │    │    └─Bottleneck (2)                    [1, 2048, 16, 16]    [1, 2048, 16, 16]    4,462,592            --                   1,140,856,832
# ├─ASPP (aspp)                                 [1, 2048, 16, 16]    [1, 256, 16, 16]     --                   --                   --
# │    └─Conv2d (atrous1)                       [1, 2048, 16, 16]    [1, 256, 16, 16]     524,544              [1, 1]               134,283,264
# │    └─Conv2d (atrous6)                       [1, 2048, 16, 16]    [1, 256, 16, 16]     4,718,848            [3, 3]               1,208,025,088
# │    └─Conv2d (atrous12)                      [1, 2048, 16, 16]    [1, 256, 16, 16]     4,718,848            [3, 3]               1,208,025,088
# │    └─Conv2d (atrous18)                      [1, 2048, 16, 16]    [1, 256, 16, 16]     4,718,848            [3, 3]               1,208,025,088
# │    └─Sequential (global_pool)               [1, 2048, 16, 16]    [1, 256, 1, 1]       --                   --                   --
# │    │    └─AdaptiveAvgPool2d (0)             [1, 2048, 16, 16]    [1, 2048, 1, 1]      --                   --                   --
# │    │    └─Conv2d (1)                        [1, 2048, 1, 1]      [1, 256, 1, 1]       524,544              [1, 1]               524,544
# │    │    └─ReLU (2)                          [1, 256, 1, 1]       [1, 256, 1, 1]       --                   --                   --
# │    └─Conv2d (conv_out)                      [1, 1280, 16, 16]    [1, 256, 16, 16]     327,936              [1, 1]               83,951,616
# ├─UNetDecoder (decoder)                       [1, 256, 16, 16]     [1, 1, 512, 512]     --                   --                   --
# │    └─Sequential (up1)                       [1, 2304, 32, 32]    [1, 256, 32, 32]     --                   --                   --
# │    │    └─Conv2d (0)                        [1, 2304, 32, 32]    [1, 256, 32, 32]     5,308,672            [3, 3]               5,436,080,128
# │    │    └─ReLU (1)                          [1, 256, 32, 32]     [1, 256, 32, 32]     --                   --                   --
# │    │    └─Conv2d (2)                        [1, 256, 32, 32]     [1, 256, 32, 32]     590,080              [3, 3]               604,241,920
# │    │    └─ReLU (3)                          [1, 256, 32, 32]     [1, 256, 32, 32]     --                   --                   --
# │    └─Sequential (up2)                       [1, 1280, 64, 64]    [1, 128, 64, 64]     --                   --                   --
# │    │    └─Conv2d (0)                        [1, 1280, 64, 64]    [1, 128, 64, 64]     1,474,688            [3, 3]               6,040,322,048
# │    │    └─ReLU (1)                          [1, 128, 64, 64]     [1, 128, 64, 64]     --                   --                   --
# │    │    └─Conv2d (2)                        [1, 128, 64, 64]     [1, 128, 64, 64]     147,584              [3, 3]               604,504,064
# │    │    └─ReLU (3)                          [1, 128, 64, 64]     [1, 128, 64, 64]     --                   --                   --
# │    └─Sequential (up3)                       [1, 640, 128, 128]   [1, 64, 128, 128]    --                   --                   --
# │    │    └─Conv2d (0)                        [1, 640, 128, 128]   [1, 64, 128, 128]    368,704              [3, 3]               6,040,846,336
# │    │    └─ReLU (1)                          [1, 64, 128, 128]    [1, 64, 128, 128]    --                   --                   --
# │    │    └─Conv2d (2)                        [1, 64, 128, 128]    [1, 64, 128, 128]    36,928               [3, 3]               605,028,352
# │    │    └─ReLU (3)                          [1, 64, 128, 128]    [1, 64, 128, 128]    --                   --                   --
# │    └─Sequential (up4)                       [1, 320, 256, 256]   [1, 32, 256, 256]    --                   --                   --
# │    │    └─Conv2d (0)                        [1, 320, 256, 256]   [1, 32, 256, 256]    92,192               [3, 3]               6,041,894,912
# │    │    └─ReLU (1)                          [1, 32, 256, 256]    [1, 32, 256, 256]    --                   --                   --
# │    │    └─Conv2d (2)                        [1, 32, 256, 256]    [1, 32, 256, 256]    9,248                [3, 3]               606,076,928
# │    │    └─ReLU (3)                          [1, 32, 256, 256]    [1, 32, 256, 256]    --                   --                   --
# │    └─Conv2d (final)                         [1, 32, 512, 512]    [1, 1, 512, 512]     33                   [1, 1]               8,650,752
# =================================================================================================================================================
# Total params: 47,063,457
# Trainable params: 47,063,457
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 50.77
# =================================================================================================================================================
# Input size (MB): 1.05
# Forward/backward pass size (MB): 996.67
# Params size (MB): 188.25
# Estimated Total Size (MB): 1185.98
# =================================================================================================================================================

# %%
save_path = '/content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_ab_resASPP_Unet_paper_pre.pth'
torch.save(model, save_path)

print(f"Model disimpan di: {save_path}")
# Out:
# Model disimpan di: /content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_ab_resASPP_Unet_paper_pre.pth

# %%
save_path_bobot = "/content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_bobot_resASPP_Unet_paper_pre.pth"
torch.save(model.state_dict(), save_path_bobot)
print("Saved to:", save_path_bobot)
# Out:
# Saved to: /content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_bobot_resASPP_Unet_paper_pre.pth

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Pastikan cell definisi class ResASPP_UNet sudah dijalankan sebelumnya
with torch.serialization.safe_globals([ResASPP_UNet]):
    model = torch.load("/content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_ab_resASPP_Unet_paper_pre.pth",
                       map_location=device, weights_only=False)

model.eval()
print(" Model berhasil dimuat tanpa file .py terpisah.")
# Out:
#  Model berhasil dimuat tanpa file .py terpisah.

# %%
# Make sure the cell defining plot_history is run before this cell.
plot_history(history)

# %%
def visualize_prediction(model, dataset, index=0, device='cuda'):
    model.eval()

    image, true_mask, image_rgb = dataset[index]

    image_input = image.unsqueeze(0).to(device)

    with torch.no_grad():
        pred_mask = model(image_input)
        pred_mask = (pred_mask.squeeze().cpu().numpy() > 0.5).astype(float)

    true_mask_np = true_mask.squeeze().cpu().numpy()

    plt.figure(figsize=(12, 4))

    # RGB ASLI
    plt.subplot(1, 3, 1)
    plt.imshow(image_rgb)
    plt.title("Input RGB (Original)")
    plt.axis("off")

    # Ground truth
    plt.subplot(1, 3, 2)
    plt.imshow(true_mask_np, cmap='gray')
    plt.title("Ground Truth Mask")
    plt.axis("off")

    # Prediction
    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask, cmap='gray')
    plt.title("Predicted Mask")
    plt.axis("off")

    plt.tight_layout()
    plt.show()

# %%
visualize_prediction(model, val_dataset, index=0)

# %%
print(len(test_dataset.image_paths))
print(len(test_dataset.mask_paths))
# Out:
# 20
# 0

# %%
visualize_prediction(model, test_dataset, index=0)

# %%
import numpy as np

# Process fold_results to get a consistent list of metric dictionaries for averaging
processed_metrics = []
for fold_res in fold_results:
    if isinstance(fold_res, dict) and "metrics" in fold_res and isinstance(fold_res["metrics"], dict):
        processed_metrics.append(fold_res["metrics"])
    elif isinstance(fold_res, dict) and "loss" in fold_res: # Assuming 'loss' is a key present in direct metric dicts
        processed_metrics.append(fold_res)


print("\n=== CROSS VALIDATION RESULT ===")
if not processed_metrics:
    print("No valid metric dictionaries found in fold_results to average.")
else:
    # Use the keys from the first processed metric dictionary for averaging
    # This assumes all metric dictionaries have the same set of keys
    avg_results = {
        k: np.mean([res[k] for res in processed_metrics])
        for k in processed_metrics[0]
    }

    for k, v in avg_results.items():
        print(f"{k}: {v:.4f}")
# Out:
# === CROSS VALIDATION RESULT ===
# loss: 0.5048
# Accuracy: 0.9554
# Sensitivity: 0.7294
# Specificity: 0.9771
# Dice: 0.7408
# IoU: 0.5884
