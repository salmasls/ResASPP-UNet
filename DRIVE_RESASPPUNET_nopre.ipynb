# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install albumentations opencv-python
# Out:
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (2.0.8)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.13.0.92)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.12/dist-packages (from albumentations) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from albumentations) (1.16.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from albumentations) (6.0.3)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations) (2.12.3)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations) (4.13.0.92)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (4.6.0)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (6.5.16)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.4.2)

# %%
import os
import glob
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2

train_transform = A.Compose([
    A.Resize(512, 512),
    A.HorizontalFlip(p=0.7),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.7),
    A.RandomBrightnessContrast(p=0.7),
    ToTensorV2()
])

test_transform = A.Compose([
    A.Resize(512, 512),
    ToTensorV2()
])

# %%
import cv2
import numpy as np
from torch.utils.data import Dataset
from PIL import Image

class DRIVEDataset(Dataset):
    def __init__(self, image_paths, mask_paths, transform=None):
        self.image_paths = image_paths
        self.mask_paths = mask_paths
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        # === LOAD IMAGE ===
        image = cv2.imread(self.image_paths[idx])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = image.astype(np.float32) / 255.0

        # === no PREPROCESSING  ===

        mask = Image.open(self.mask_paths[idx]).convert("L")
        mask = np.array(mask)

        # === BINARISASI MASK  ===
        mask = (mask > 0).astype(np.float32)

        # === AUGMENTATION ===
        if self.transform:
            augmented = self.transform(image=image, mask=mask)
            image = augmented['image']
            mask  = augmented['mask']

        if mask.ndim == 2:
            mask = mask.unsqueeze(0)

        return image, mask

# %%
# Direktori input dan output
img_dir = "/content/drive/MyDrive/Colab Notebooks/DRIVE/training/images"
mask_dir = "/content/drive/MyDrive/Colab Notebooks/DRIVE/training/1st_manual"


from glob import glob
import os

train_imgs = sorted(glob(os.path.join(img_dir, "*.tif")))
train_masks = sorted(glob(os.path.join(mask_dir, "*.gif")))

test_imgs = sorted(glob("/content/drive/MyDrive/Colab Notebooks/DRIVE/test/images/*.tif"))
test_masks = sorted(glob("/content/drive/MyDrive/Colab Notebooks/DRIVE/test/mask/*.gif"))

# %%
print("Train images:", len(train_imgs))
print("Train masks:", len(train_masks))
print("Test images:", len(test_imgs))
print("Test masks:", len(test_masks))
# Out:
# Train images: 20
# Train masks: 20
# Test images: 20
# Test masks: 20

# %%
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader

kf = KFold(n_splits=10, shuffle=True, random_state=42)

for fold, (train_idx, val_idx) in enumerate(kf.split(train_imgs)):

    train_fold_imgs = [train_imgs[i] for i in train_idx]
    train_fold_masks = [train_masks[i] for i in train_idx]

    val_fold_imgs = [train_imgs[i] for i in val_idx]
    val_fold_masks = [train_masks[i] for i in val_idx]

    train_dataset = DRIVEDataset(
        train_fold_imgs,
        train_fold_masks,
        transform=train_transform   # AUGMENTASI DI SINI
    )

    val_dataset = DRIVEDataset(
        val_fold_imgs,
        val_fold_masks,
        transform=test_transform    # TANPA AUGMENTASI
    )

    train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=4)
    val_loader   = DataLoader(val_dataset, batch_size=4, shuffle=False)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()

# %%
test_dataset = DRIVEDataset(test_imgs, test_masks, transform=test_transform)
test_loader  = DataLoader(test_dataset, batch_size=4, shuffle=False)

# %%
print(len(train_fold_imgs), len(val_fold_imgs))
# Out:
# 18 2

# %%
import matplotlib.pyplot as plt

# ambil 1 sample dari train_dataset (yang sudah diaugmentasi)
image, mask = train_dataset[0]

# ubah tensor → numpy
image = image.permute(1, 2, 0).cpu().numpy()
mask = mask.squeeze().cpu().numpy()

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(image)
plt.title("Augmented Image")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(mask, cmap='gray')
plt.title("Mask")
plt.axis('off')

plt.show()

# %%
# === HITUNG JUMLAH DATA TRAINING & VALIDATION ===
print("========================================")
# Define all_files by combining training and test image paths
all_files = train_imgs + test_imgs
print("Jumlah total data:", len(all_files))
print("Jumlah data training :", len(train_dataset))
print("Jumlah data validation :", len(val_dataset))
print("Jumlah data test :", len(test_dataset))
print("========================================")
# Out:
# ========================================
# Jumlah total data: 40
# Jumlah data training : 18
# Jumlah data validation : 2
# Jumlah data test : 20
# ========================================

# %%
# === LOAD IMAGE ===
img = cv2.imread("/content/drive/MyDrive/Colab Notebooks/DRIVE/training/images/21_training.tif")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# === WITHOUT PREPROCESSING ===
preprocessed = img
# === LOAD MASK ===
mask = cv2.imread("/content/drive/MyDrive/Colab Notebooks/DRIVE/training/1st_manual/21_manual1.gif", cv2.IMREAD_GRAYSCALE)
mask = (mask > 0).astype("float32")
mask = mask[..., None]

# === AUGMENTATION ===
augmented = train_transform(image=preprocessed, mask=mask)

aug_img = augmented["image"]
aug_mask = augmented["mask"]

# === CONVERT UNTUK VISUALISASI ===
aug_img_np = aug_img.permute(1, 2, 0).cpu().numpy()
aug_mask_np = aug_mask.squeeze().cpu().numpy()

# === PLOT ===
plt.figure(figsize=(18, 6))

plt.subplot(1, 4, 1)
plt.imshow(img)
plt.title("Original")
plt.axis("off")

plt.subplot(1, 4, 2)
plt.imshow(preprocessed.squeeze())
plt.title("Preprocessing Greyscale")
plt.axis("off")

plt.subplot(1, 4, 3)
plt.imshow(aug_img_np.squeeze())
plt.title("Augmented Image")
plt.axis("off")

plt.subplot(1, 4, 4)
plt.imshow(aug_mask_np, cmap='gray')
plt.title("Augmented Mask")
plt.axis("off")

plt.show()

# %%
batch = next(iter(train_loader))
imgs, masks = batch

img = imgs[0]
mask = masks[0]

img_np = img.permute(1, 2, 0).cpu().numpy()
img_np = np.clip(img_np, 0, 1)

mask_np = mask.squeeze().cpu().numpy()

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(img_np)
plt.title("Sample Image (DataLoader)")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(mask_np, cmap='gray')
plt.title("Mask")
plt.axis("off")

plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()

# %%
print("MIN:", img.min().item())
print("MAX:", img.max().item())
# Out:
# MIN: 0.10899216681718826
# MAX: 0.9591322541236877

# %%
image, mask = train_dataset[0]
print(image.shape)
# Out:
# torch.Size([3, 512, 512])

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models

# === DeepLabV3 Encoder: ResNet Backbone ===
class ResNetEncoder(nn.Module):
    def __init__(self):
        super().__init__()
        resnet = models.resnet50(pretrained=True)
        self.initial = nn.Sequential(
            resnet.conv1,
            resnet.bn1,
            resnet.relu,
            resnet.maxpool
        )

        self.layer1 = resnet.layer1  # 256  # CHANGED (comment)
        self.layer2 = resnet.layer2  # 512  # CHANGED (comment)
        self.layer3 = resnet.layer3  # 1024 # CHANGED (comment)
        self.layer4 = resnet.layer4  # 2048 # CHANGED (comment)

    def forward(self, x):
        x0 = self.initial(x)
        x1 = self.layer1(x0)  # 256
        x2 = self.layer2(x1)  # 512
        x3 = self.layer3(x2)  # 1024
        x4 = self.layer4(x3)  # 2048
        return x1, x2, x3, x4


# === ASPP Module ===
class ASPP(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.atrous1 = nn.Conv2d(in_channels, out_channels, 1, padding=0, dilation=1)
        self.atrous6 = nn.Conv2d(in_channels, out_channels, 3, padding=6, dilation=6)
        self.atrous12 = nn.Conv2d(in_channels, out_channels, 3, padding=12, dilation=12)
        self.atrous18 = nn.Conv2d(in_channels, out_channels, 3, padding=18, dilation=18)
        self.global_pool = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(in_channels, out_channels, 1),
            nn.ReLU()
        )
        self.conv_out = nn.Conv2d(out_channels * 5, out_channels, 1)

    def forward(self, x):
        size = x.shape[2:]
        f1 = self.atrous1(x)
        f2 = self.atrous6(x)
        f3 = self.atrous12(x)
        f4 = self.atrous18(x)
        f5 = self.global_pool(x)
        f5 = F.interpolate(f5, size=size, mode='bilinear', align_corners=False)
        x = torch.cat([f1, f2, f3, f4, f5], dim=1)
        return self.conv_out(x)


class UNetDecoder(nn.Module):
    def __init__(self):
        super().__init__()

        # Correct skip channels for ResNet50
        # bridge (ASPP) out_channels = 256
        # x4 = 2048, x3 = 1024, x2 = 512, x1 = 256
        self.up1 = self.block(256, 2048, 256)  # bridge + x4
        self.up2 = self.block(256, 1024, 128)  # up1 + x3
        self.up3 = self.block(128, 512, 64)    # up2 + x2
        self.up4 = self.block(64, 256, 32)     # up3 + x1

        self.final = nn.Conv2d(32, 1, 1)

    def block(self, in_channels, skip_channels, out_channels):
        return nn.Sequential(
            nn.Conv2d(in_channels + skip_channels, out_channels, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, 3, padding=1),
            nn.ReLU(inplace=True),
        )

    def forward(self, x, skips):
        x1, x2, x3, x4 = skips

        # === UP 1 === (bridge + x4)
        x = F.interpolate(x, scale_factor=2, mode='bilinear', align_corners=False)
        if x4.shape[2:] != x.shape[2:]:
            x4 = F.interpolate(x4, size=x.shape[2:], mode='bilinear', align_corners=False)
        x = self.up1(torch.cat([x, x4], dim=1))

        # === UP 2 === (up1 + x3)
        x = F.interpolate(x, scale_factor=2, mode='bilinear', align_corners=False)
        if x3.shape[2:] != x.shape[2:]:
            x3 = F.interpolate(x3, size=x.shape[2:], mode='bilinear', align_corners=False)
        x = self.up2(torch.cat([x, x3], dim=1))

        # === UP 3 === (up2 + x2)
        x = F.interpolate(x, scale_factor=2, mode='bilinear', align_corners=False)
        if x2.shape[2:] != x.shape[2:]:
            x2 = F.interpolate(x2, size=x.shape[2:], mode='bilinear', align_corners=False)
        x = self.up3(torch.cat([x, x2], dim=1))

        # === UP 4 === (up3 + x1)
        x = F.interpolate(x, scale_factor=2, mode='bilinear', align_corners=False)
        if x1.shape[2:] != x.shape[2:]:
            x1 = F.interpolate(x1, size=x.shape[2:], mode='bilinear', align_corners=False)
        x = self.up4(torch.cat([x, x1], dim=1))

        x = F.interpolate(x, size=(512, 512), mode='bilinear', align_corners=False)

        return self.final(x)


# === Hybrid Model ===
class ResASPP_UNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = ResNetEncoder()
        self.aspp = ASPP(2048, 256)
        self.decoder = UNetDecoder()

    def forward(self, x):
        x1, x2, x3, x4 = self.encoder(x)
        bridge = self.aspp(x4)
        out = self.decoder(bridge, [x1, x2, x3, x4])  # CHANGED
        return out

# %%
import torch.nn as nn
import torch.nn.functional as F

class DiceLoss(nn.Module):
    def __init__(self, smooth=1e-6):
        super().__init__()
        self.smooth = smooth

    def forward(self, pred, target):
        pred = torch.sigmoid(pred)
        intersection = (pred * target).sum(dim=(2,3))
        union = pred.sum(dim=(2,3)) + target.sum(dim=(2,3))
        dice = (2 * intersection + self.smooth) / (union + self.smooth)
        return 1 - dice.mean()


class BoundaryLoss(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, pred, target):
        pred = torch.sigmoid(pred)

        sobel_x = torch.tensor([[1,0,-1],[2,0,-2],[1,0,-1]],
                               dtype=torch.float32).to(pred.device).view(1,1,3,3)
        sobel_y = sobel_x.permute(0,1,3,2)

        pred_edge = F.conv2d(pred, sobel_x, padding=1) + F.conv2d(pred, sobel_y, padding=1)
        target_edge = F.conv2d(target, sobel_x, padding=1) + F.conv2d(target, sobel_y, padding=1)

        return F.l1_loss(pred_edge, target_edge)


class TopologyLoss(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, pred, target):
        pred = torch.sigmoid(pred)
        return F.binary_cross_entropy_with_logits(pred, target)


class HybridLoss(nn.Module):
    def __init__(self, w_dice=1.0, w_boundary=0.5, w_topo=0.3):
        super().__init__()
        self.dice = DiceLoss()
        self.boundary = BoundaryLoss()
        self.topo = TopologyLoss()

        self.w_dice = w_dice
        self.w_boundary = w_boundary
        self.w_topo = w_topo

    def forward(self, pred, target):
        return (
            self.w_dice * self.dice(pred, target) +
            self.w_boundary * self.boundary(pred, target) +
            self.w_topo * self.topo(pred, target)
        )

class BCEDiceLoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.bce = nn.BCELoss()

    def forward(self, preds, targets):
        bce = self.bce(preds, targets)
        dice = 1 - dice_score(preds, targets)
        return bce + dice

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import time # Import the time module


def dice_score(preds, targets, threshold=0.5):
    preds = (preds > threshold).float()
    intersection = (preds * targets).sum()
    return (2. * intersection) / (preds.sum() + targets.sum() + 1e-8)

def accuracy_score(preds, targets, threshold=0.5):
    preds = (preds > threshold).float()
    correct = (preds == targets).float().sum()
    total = torch.numel(targets)
    return correct / total

def train_model(model, train_loader, val_loader, epochs=30, lr=1e-4, device='cuda'):
    model.to(device)
    criterion = HybridLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)

    history = {
        "train_loss": [],
        "val_loss": [],
        "train_acc": [],
        "val_acc": [],
        "train_dice": [],
        "val_dice": []
    }

    start_time = time.time()

    for epoch in range(epochs):
        model.train()
        running_loss = 0
        running_acc = 0
        running_dice = 0

        for images, masks in train_loader:
            images, masks = images.to(device), masks.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, masks)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            running_acc  += accuracy_score(outputs, masks).item()
            running_dice += dice_score(outputs, masks).item()

        train_loss = running_loss / len(train_loader)
        train_acc  = running_acc  / len(train_loader)
        train_dice = running_dice / len(train_loader)

        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['train_dice'].append(train_dice)


        # ==========================
        # VALIDATION
        # ==========================
        model.eval()
        val_loss = 0
        total_dice = 0
        total_acc = 0

        with torch.no_grad():
            for images, masks in val_loader:
                images, masks = images.to(device), masks.to(device)
                masks = (masks > 0).float()  # 🔥 TAMBAHKAN
                outputs = model(images)

                probs = torch.sigmoid(outputs)  # 🔥 TAMBAHKAN
                print("VAL probs min:", probs.min().item())  # 🔥 TAMBAHKAN
                print("VAL probs max:", probs.max().item())  # 🔥 TAMBAHKAN

                loss = criterion(outputs, masks)
                val_loss += loss.item()

                total_dice += dice_score(outputs, masks).item()
                total_acc  += accuracy_score(outputs, masks).item()

        val_loss /= len(val_loader)
        val_dice = total_dice / len(val_loader)
        val_acc  = total_acc  / len(val_loader)

        history['val_loss'].append(val_loss)
        history['val_dice'].append(val_dice)
        history['val_acc'].append(val_acc)

        print(f"Epoch {epoch+1}/{epochs} | "
              f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | "
              f"Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f} | "
              f"Train Dice: {train_dice:.4f} | Val Dice: {val_dice:.4f}")


    end_time = time.time() # Record the end time
    total_training_time = end_time - start_time
    print(f"\nTotal Training Time: {total_training_time:.2f} seconds")

    return model, history

# %%
import matplotlib.pyplot as plt

def plot_history(history):
    plt.figure(figsize=(18, 5))


    # Plot Loss
    plt.subplot(1,3,1)
    plt.plot(history['train_loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Val Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Plot Accuracy
    plt.subplot(1,3,2)
    plt.plot(history['train_acc'], label='Train Accuracy')
    plt.plot(history['val_acc'], label='Val Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Dice Score
    plt.subplot(1, 3, 3)
    plt.plot(history['train_dice'], label='Train Dice', color='blue')
    plt.plot(history['val_dice'], label='Val Dice', color='orange')
    plt.title('Dice Score per Epoch')
    plt.xlabel('Epoch')
    plt.ylabel('Dice')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# %%
def plot_history(history, title_suffix=""):
    plt.figure(figsize=(18, 5))

    # Loss
    plt.subplot(1,3,1)
    plt.plot(history['train_loss'], label='Train Loss')
    if 'val_loss' in history:
        plt.plot(history['val_loss'], label='Val Loss')
    plt.title(f'Loss {title_suffix}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Accuracy
    plt.subplot(1,3,2)
    plt.plot(history['train_acc'], label='Train Acc')
    if 'val_acc' in history:
        plt.plot(history['val_acc'], label='Val Acc')
    plt.title(f'Accuracy {title_suffix}')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Dice
    plt.subplot(1,3,3)
    plt.plot(history['train_dice'], label='Train Dice')
    if 'val_dice' in history:
        plt.plot(history['val_dice'], label='Val Dice')
    plt.title(f'Dice Score {title_suffix}')
    plt.xlabel('Epoch')
    plt.ylabel('Dice')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# %%
pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
def evaluate_test(model, loader, device):
    model.eval()

    total_loss = 0
    # total_dice = 0 # These are not explicitly used in the return, removed for clarity
    # total_acc  = 0 # These are not explicitly used in the return, removed for clarity

    criterion = HybridLoss()


    TP, TN, FP, FN = 0, 0, 0, 0
    dice_total, iou_total, n = 0, 0, 0

    with torch.no_grad():
        for images, masks in loader:
            images, masks = images.to(device), masks.to(device)

            outputs = model(images)
            preds = (torch.sigmoid(outputs) > 0.5).float()

            loss = criterion(outputs, masks) # Calculate loss
            total_loss += loss.item() # Accumulate loss

            TP += ((preds == 1) & (masks == 1)).sum().item()
            TN += ((preds == 0) & (masks == 0)).sum().item()
            FP += ((preds == 1) & (masks == 0)).sum().item()
            FN += ((preds == 0) & (masks == 1)).sum().item()

            intersection = (preds * masks).sum(dim=(2,3))
            union = preds.sum(dim=(2,3)) + masks.sum(dim=(2,3))

            dice = (2 * intersection + 1e-6) / (union + 1e-6)
            iou = (intersection + 1e-6) / (union - intersection + 1e-6)

            dice_total += dice.mean().item()
            iou_total += iou.mean().item()
            n += 1

    return {
        "loss": total_loss / n, # Added loss to the return dictionary
        "Accuracy": (TP + TN) / (TP + TN + FP + FN + 1e-6),
        "Sensitivity": TP / (TP + FN + 1e-6),
        "Specificity": TN / (TN + FP + 1e-6),
        "Dice": dice_total / n,
        "IoU": iou_total / n
    }

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

fold_results = []

import os

# Folder penyimpanan
save_dir = "/content/drive/MyDrive/Colab Notebooks/DRIVE/"
os.makedirs(save_dir, exist_ok=True)

for fold, (train_idx, val_idx) in enumerate(kf.split(train_imgs)):
    print(f"\n===== FOLD {fold+1} ====")

    train_fold_imgs = [train_imgs[i] for i in train_idx]
    train_fold_masks = [train_masks[i] for i in train_idx]

    val_fold_imgs = [train_imgs[i] for i in val_idx]
    val_fold_masks = [train_masks[i] for i in val_idx]

    # Dataset
    train_dataset = DRIVEDataset(train_fold_imgs, train_fold_masks, transform=train_transform)
    val_dataset   = DRIVEDataset(val_fold_imgs, val_fold_masks, transform=test_transform)

    train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=4)
    val_loader   = DataLoader(val_dataset, batch_size=4, shuffle=False, num_workers=4)

    model = ResASPP_UNet().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
    criterion = HybridLoss()

    num_epochs = 100

    #History
    history = {
        "train_loss": [],
        "val_loss": [],
        "train_dice": [],
        "val_dice": [],
        "train_acc": [],
        "val_acc": []
    }

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0
        running_dice = 0
        running_acc  = 0

        for images, masks in train_loader:
            images, masks = images.to(device), masks.to(device)
            masks = (masks > 0).float()  # 🔥 TAMBAHKAN

            outputs = model(images)
            preds = torch.sigmoid(outputs)

            loss = criterion(outputs, masks)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            running_dice += dice_score(preds, masks).item()
            running_acc  += accuracy_score(preds, masks).item()

        # === TRAIN METRICS ===
        train_loss = running_loss / len(train_loader)
        train_dice = running_dice / len(train_loader)
        train_acc  = running_acc  / len(train_loader)

        # === VALIDATION ===
        val_metrics = evaluate_test(model, val_loader, device)

        # === SIMPAN HISTORY ===
        history["train_loss"].append(train_loss)
        history["train_dice"].append(train_dice)
        history["train_acc"].append(train_acc)

        history["val_loss"].append(val_metrics["loss"])
        history["val_dice"].append(val_metrics["Dice"])
        history["val_acc"].append(val_metrics["Accuracy"])

        # Print train model
        print(f"Fold {fold+1} | Epoch {epoch+1}/{num_epochs} | "
              f"Train Loss: {train_loss:.4f} | Val Loss: {val_metrics['loss']:.4f} | "
              f"Train Acc: {train_acc:.4f} | Val Acc: {val_metrics['Accuracy']:.4f} | "
              f"Train Dice: {train_dice:.4f} | Val Dice: {val_metrics['Dice']:.4f}")
# Out:
# ===== FOLD 1 ====
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 152MB/s]
# Fold 1 | Epoch 1/100 | Train Loss: 1.3192 | Val Loss: 1.3172 | Train Acc: 0.9115 | Val Acc: 0.9194 | Train Dice: 0.0002 | Val Dice: 0.0000
# Fold 1 | Epoch 2/100 | Train Loss: 1.3149 | Val Loss: 1.3029 | Train Acc: 0.9132 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 3/100 | Train Loss: 1.2741 | Val Loss: 1.2510 | Train Acc: 0.9124 | Val Acc: 0.9194 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 1 | Epoch 4/100 | Train Loss: 1.1934 | Val Loss: 1.2099 | Train Acc: 0.9147 | Val Acc: 0.9194 | Train Dice: 0.0410 | Val Dice: 0.0000
# Fold 1 | Epoch 5/100 | Train Loss: 1.1702 | Val Loss: 1.1749 | Train Acc: 0.8879 | Val Acc: 0.8923 | Train Dice: 0.3496 | Val Dice: 0.3324
# Fold 1 | Epoch 6/100 | Train Loss: 1.1460 | Val Loss: 1.1541 | Train Acc: 0.8546 | Val Acc: 0.8443 | Train Dice: 0.3499 | Val Dice: 0.3115
# Fold 1 | Epoch 7/100 | Train Loss: 1.1118 | Val Loss: 1.1246 | Train Acc: 0.8511 | Val Acc: 0.8540 | Train Dice: 0.3426 | Val Dice: 0.2977
# Fold 1 | Epoch 8/100 | Train Loss: 1.0843 | Val Loss: 1.1086 | Train Acc: 0.8568 | Val Acc: 0.8420 | Train Dice: 0.3437 | Val Dice: 0.3050
# Fold 1 | Epoch 9/100 | Train Loss: 1.0938 | Val Loss: 1.0841 | Train Acc: 0.8794 | Val Acc: 0.8521 | Train Dice: 0.3247 | Val Dice: 0.3344
# Fold 1 | Epoch 10/100 | Train Loss: 1.1145 | Val Loss: 1.0994 | Train Acc: 0.7888 | Val Acc: 0.8153 | Train Dice: 0.3220 | Val Dice: 0.3180
# Fold 1 | Epoch 11/100 | Train Loss: 1.0821 | Val Loss: 1.0601 | Train Acc: 0.8651 | Val Acc: 0.8779 | Train Dice: 0.3475 | Val Dice: 0.3560
# Fold 1 | Epoch 12/100 | Train Loss: 1.0623 | Val Loss: 1.0517 | Train Acc: 0.8853 | Val Acc: 0.8967 | Train Dice: 0.3603 | Val Dice: 0.3638
# Fold 1 | Epoch 13/100 | Train Loss: 1.0408 | Val Loss: 1.0714 | Train Acc: 0.8803 | Val Acc: 0.9180 | Train Dice: 0.3906 | Val Dice: 0.3323
# Fold 1 | Epoch 14/100 | Train Loss: 1.0225 | Val Loss: 1.0024 | Train Acc: 0.9037 | Val Acc: 0.9154 | Train Dice: 0.4143 | Val Dice: 0.4241
# Fold 1 | Epoch 15/100 | Train Loss: 0.9919 | Val Loss: 0.9881 | Train Acc: 0.8995 | Val Acc: 0.9233 | Train Dice: 0.4489 | Val Dice: 0.4301
# Fold 1 | Epoch 16/100 | Train Loss: 0.9605 | Val Loss: 0.9589 | Train Acc: 0.9094 | Val Acc: 0.9261 | Train Dice: 0.4865 | Val Dice: 0.4656
# Fold 1 | Epoch 17/100 | Train Loss: 0.9328 | Val Loss: 0.9392 | Train Acc: 0.9151 | Val Acc: 0.9308 | Train Dice: 0.5223 | Val Dice: 0.4853
# Fold 1 | Epoch 18/100 | Train Loss: 0.9117 | Val Loss: 0.9341 | Train Acc: 0.9196 | Val Acc: 0.9336 | Train Dice: 0.5437 | Val Dice: 0.4821
# Fold 1 | Epoch 19/100 | Train Loss: 0.8914 | Val Loss: 0.9254 | Train Acc: 0.9226 | Val Acc: 0.9349 | Train Dice: 0.5613 | Val Dice: 0.4810
# Fold 1 | Epoch 20/100 | Train Loss: 0.8713 | Val Loss: 0.8694 | Train Acc: 0.9239 | Val Acc: 0.9361 | Train Dice: 0.5790 | Val Dice: 0.5470
# Fold 1 | Epoch 21/100 | Train Loss: 0.8474 | Val Loss: 0.8382 | Train Acc: 0.9286 | Val Acc: 0.9370 | Train Dice: 0.5971 | Val Dice: 0.5893
# Fold 1 | Epoch 22/100 | Train Loss: 0.8361 | Val Loss: 0.8337 | Train Acc: 0.9301 | Val Acc: 0.9390 | Train Dice: 0.6041 | Val Dice: 0.5869
# Fold 1 | Epoch 23/100 | Train Loss: 0.8151 | Val Loss: 0.8905 | Train Acc: 0.9313 | Val Acc: 0.9383 | Train Dice: 0.6227 | Val Dice: 0.5002
# Fold 1 | Epoch 24/100 | Train Loss: 0.8169 | Val Loss: 0.8673 | Train Acc: 0.9302 | Val Acc: 0.9404 | Train Dice: 0.6220 | Val Dice: 0.5270
# Fold 1 | Epoch 25/100 | Train Loss: 0.8031 | Val Loss: 0.7857 | Train Acc: 0.9350 | Val Acc: 0.9391 | Train Dice: 0.6313 | Val Dice: 0.6380
# Fold 1 | Epoch 26/100 | Train Loss: 0.7817 | Val Loss: 0.7829 | Train Acc: 0.9404 | Val Acc: 0.9357 | Train Dice: 0.6483 | Val Dice: 0.6442
# Fold 1 | Epoch 27/100 | Train Loss: 0.7790 | Val Loss: 0.7866 | Train Acc: 0.9359 | Val Acc: 0.9452 | Train Dice: 0.6537 | Val Dice: 0.6283
# Fold 1 | Epoch 28/100 | Train Loss: 0.7711 | Val Loss: 0.7646 | Train Acc: 0.9388 | Val Acc: 0.9456 | Train Dice: 0.6542 | Val Dice: 0.6501
# Fold 1 | Epoch 29/100 | Train Loss: 0.7541 | Val Loss: 0.7560 | Train Acc: 0.9437 | Val Acc: 0.9419 | Train Dice: 0.6682 | Val Dice: 0.6606
# Fold 1 | Epoch 30/100 | Train Loss: 0.7466 | Val Loss: 0.7500 | Train Acc: 0.9423 | Val Acc: 0.9480 | Train Dice: 0.6787 | Val Dice: 0.6603
# Fold 1 | Epoch 31/100 | Train Loss: 0.7394 | Val Loss: 0.7430 | Train Acc: 0.9440 | Val Acc: 0.9434 | Train Dice: 0.6796 | Val Dice: 0.6716
# Fold 1 | Epoch 32/100 | Train Loss: 0.7305 | Val Loss: 0.7435 | Train Acc: 0.9469 | Val Acc: 0.9417 | Train Dice: 0.6871 | Val Dice: 0.6722
# Fold 1 | Epoch 33/100 | Train Loss: 0.7238 | Val Loss: 0.7370 | Train Acc: 0.9458 | Val Acc: 0.9500 | Train Dice: 0.6937 | Val Dice: 0.6651
# Fold 1 | Epoch 34/100 | Train Loss: 0.7216 | Val Loss: 0.7359 | Train Acc: 0.9474 | Val Acc: 0.9425 | Train Dice: 0.6942 | Val Dice: 0.6777
# Fold 1 | Epoch 35/100 | Train Loss: 0.7085 | Val Loss: 0.7208 | Train Acc: 0.9480 | Val Acc: 0.9495 | Train Dice: 0.7013 | Val Dice: 0.6841
# Fold 1 | Epoch 36/100 | Train Loss: 0.7058 | Val Loss: 0.7190 | Train Acc: 0.9478 | Val Acc: 0.9493 | Train Dice: 0.7067 | Val Dice: 0.6828
# Fold 1 | Epoch 37/100 | Train Loss: 0.6950 | Val Loss: 0.7175 | Train Acc: 0.9502 | Val Acc: 0.9491 | Train Dice: 0.7109 | Val Dice: 0.6852
# Fold 1 | Epoch 38/100 | Train Loss: 0.7013 | Val Loss: 0.7136 | Train Acc: 0.9492 | Val Acc: 0.9460 | Train Dice: 0.7055 | Val Dice: 0.6918
# Fold 1 | Epoch 39/100 | Train Loss: 0.6943 | Val Loss: 0.7079 | Train Acc: 0.9505 | Val Acc: 0.9464 | Train Dice: 0.7107 | Val Dice: 0.6937
# Fold 1 | Epoch 40/100 | Train Loss: 0.6905 | Val Loss: 0.7129 | Train Acc: 0.9500 | Val Acc: 0.9528 | Train Dice: 0.7137 | Val Dice: 0.6790
# Fold 1 | Epoch 41/100 | Train Loss: 0.6916 | Val Loss: 0.7013 | Train Acc: 0.9496 | Val Acc: 0.9497 | Train Dice: 0.7142 | Val Dice: 0.6933
# Fold 1 | Epoch 42/100 | Train Loss: 0.6973 | Val Loss: 0.7042 | Train Acc: 0.9506 | Val Acc: 0.9474 | Train Dice: 0.7048 | Val Dice: 0.6973
# Fold 1 | Epoch 43/100 | Train Loss: 0.6783 | Val Loss: 0.6953 | Train Acc: 0.9513 | Val Acc: 0.9532 | Train Dice: 0.7220 | Val Dice: 0.6976
# Fold 1 | Epoch 44/100 | Train Loss: 0.6732 | Val Loss: 0.6950 | Train Acc: 0.9520 | Val Acc: 0.9525 | Train Dice: 0.7263 | Val Dice: 0.6974
# Fold 1 | Epoch 45/100 | Train Loss: 0.6709 | Val Loss: 0.6872 | Train Acc: 0.9536 | Val Acc: 0.9541 | Train Dice: 0.7271 | Val Dice: 0.7006
# Fold 1 | Epoch 46/100 | Train Loss: 0.6645 | Val Loss: 0.6790 | Train Acc: 0.9543 | Val Acc: 0.9531 | Train Dice: 0.7276 | Val Dice: 0.7092
# Fold 1 | Epoch 47/100 | Train Loss: 0.6571 | Val Loss: 0.6919 | Train Acc: 0.9552 | Val Acc: 0.9497 | Train Dice: 0.7334 | Val Dice: 0.7044
# Fold 1 | Epoch 48/100 | Train Loss: 0.6559 | Val Loss: 0.6837 | Train Acc: 0.9549 | Val Acc: 0.9529 | Train Dice: 0.7339 | Val Dice: 0.7046
# Fold 1 | Epoch 49/100 | Train Loss: 0.6592 | Val Loss: 0.6781 | Train Acc: 0.9543 | Val Acc: 0.9510 | Train Dice: 0.7342 | Val Dice: 0.7119
# Fold 1 | Epoch 50/100 | Train Loss: 0.6534 | Val Loss: 0.6857 | Train Acc: 0.9550 | Val Acc: 0.9549 | Train Dice: 0.7350 | Val Dice: 0.6976
# Fold 1 | Epoch 51/100 | Train Loss: 0.6562 | Val Loss: 0.6735 | Train Acc: 0.9542 | Val Acc: 0.9544 | Train Dice: 0.7340 | Val Dice: 0.7096
# Fold 1 | Epoch 52/100 | Train Loss: 0.6561 | Val Loss: 0.6800 | Train Acc: 0.9546 | Val Acc: 0.9496 | Train Dice: 0.7348 | Val Dice: 0.7130
# Fold 1 | Epoch 53/100 | Train Loss: 0.6520 | Val Loss: 0.6794 | Train Acc: 0.9547 | Val Acc: 0.9495 | Train Dice: 0.7364 | Val Dice: 0.7135
# Fold 1 | Epoch 54/100 | Train Loss: 0.6506 | Val Loss: 0.6705 | Train Acc: 0.9545 | Val Acc: 0.9545 | Train Dice: 0.7375 | Val Dice: 0.7142
# Fold 1 | Epoch 55/100 | Train Loss: 0.6440 | Val Loss: 0.6702 | Train Acc: 0.9560 | Val Acc: 0.9540 | Train Dice: 0.7424 | Val Dice: 0.7135
# Fold 1 | Epoch 56/100 | Train Loss: 0.6410 | Val Loss: 0.6715 | Train Acc: 0.9569 | Val Acc: 0.9511 | Train Dice: 0.7425 | Val Dice: 0.7172
# Fold 1 | Epoch 57/100 | Train Loss: 0.6459 | Val Loss: 0.6728 | Train Acc: 0.9560 | Val Acc: 0.9508 | Train Dice: 0.7403 | Val Dice: 0.7172
# Fold 1 | Epoch 58/100 | Train Loss: 0.6452 | Val Loss: 0.6715 | Train Acc: 0.9554 | Val Acc: 0.9561 | Train Dice: 0.7406 | Val Dice: 0.7058
# Fold 1 | Epoch 59/100 | Train Loss: 0.6398 | Val Loss: 0.6615 | Train Acc: 0.9561 | Val Acc: 0.9538 | Train Dice: 0.7444 | Val Dice: 0.7216
# Fold 1 | Epoch 60/100 | Train Loss: 0.6414 | Val Loss: 0.6744 | Train Acc: 0.9563 | Val Acc: 0.9503 | Train Dice: 0.7439 | Val Dice: 0.7165
# Fold 1 | Epoch 61/100 | Train Loss: 0.6341 | Val Loss: 0.6601 | Train Acc: 0.9570 | Val Acc: 0.9564 | Train Dice: 0.7489 | Val Dice: 0.7169
# Fold 1 | Epoch 62/100 | Train Loss: 0.6395 | Val Loss: 0.6586 | Train Acc: 0.9559 | Val Acc: 0.9570 | Train Dice: 0.7440 | Val Dice: 0.7173
# Fold 1 | Epoch 63/100 | Train Loss: 0.6357 | Val Loss: 0.6622 | Train Acc: 0.9572 | Val Acc: 0.9534 | Train Dice: 0.7476 | Val Dice: 0.7230
# Fold 1 | Epoch 64/100 | Train Loss: 0.6225 | Val Loss: 0.6594 | Train Acc: 0.9591 | Val Acc: 0.9524 | Train Dice: 0.7546 | Val Dice: 0.7259
# Fold 1 | Epoch 65/100 | Train Loss: 0.6259 | Val Loss: 0.6571 | Train Acc: 0.9582 | Val Acc: 0.9550 | Train Dice: 0.7538 | Val Dice: 0.7239
# Fold 1 | Epoch 66/100 | Train Loss: 0.6208 | Val Loss: 0.6568 | Train Acc: 0.9589 | Val Acc: 0.9568 | Train Dice: 0.7571 | Val Dice: 0.7207
# Fold 1 | Epoch 67/100 | Train Loss: 0.6268 | Val Loss: 0.6505 | Train Acc: 0.9579 | Val Acc: 0.9563 | Train Dice: 0.7526 | Val Dice: 0.7261
# Fold 1 | Epoch 68/100 | Train Loss: 0.6252 | Val Loss: 0.6503 | Train Acc: 0.9582 | Val Acc: 0.9560 | Train Dice: 0.7533 | Val Dice: 0.7281
# Fold 1 | Epoch 69/100 | Train Loss: 0.6190 | Val Loss: 0.6490 | Train Acc: 0.9592 | Val Acc: 0.9568 | Train Dice: 0.7573 | Val Dice: 0.7246
# Fold 1 | Epoch 70/100 | Train Loss: 0.6191 | Val Loss: 0.6492 | Train Acc: 0.9583 | Val Acc: 0.9556 | Train Dice: 0.7574 | Val Dice: 0.7257
# Fold 1 | Epoch 71/100 | Train Loss: 0.6206 | Val Loss: 0.6411 | Train Acc: 0.9585 | Val Acc: 0.9572 | Train Dice: 0.7564 | Val Dice: 0.7329
# Fold 1 | Epoch 72/100 | Train Loss: 0.6164 | Val Loss: 0.6463 | Train Acc: 0.9590 | Val Acc: 0.9563 | Train Dice: 0.7592 | Val Dice: 0.7297
# Fold 1 | Epoch 73/100 | Train Loss: 0.6211 | Val Loss: 0.6593 | Train Acc: 0.9584 | Val Acc: 0.9517 | Train Dice: 0.7551 | Val Dice: 0.7266
# Fold 1 | Epoch 74/100 | Train Loss: 0.6353 | Val Loss: 0.6507 | Train Acc: 0.9563 | Val Acc: 0.9535 | Train Dice: 0.7464 | Val Dice: 0.7298
# Fold 1 | Epoch 75/100 | Train Loss: 0.6235 | Val Loss: 0.6536 | Train Acc: 0.9577 | Val Acc: 0.9575 | Train Dice: 0.7558 | Val Dice: 0.7203
# Fold 1 | Epoch 76/100 | Train Loss: 0.6193 | Val Loss: 0.6424 | Train Acc: 0.9579 | Val Acc: 0.9561 | Train Dice: 0.7594 | Val Dice: 0.7337
# Fold 1 | Epoch 77/100 | Train Loss: 0.6162 | Val Loss: 0.6514 | Train Acc: 0.9592 | Val Acc: 0.9537 | Train Dice: 0.7566 | Val Dice: 0.7294
# Fold 1 | Epoch 78/100 | Train Loss: 0.6098 | Val Loss: 0.6437 | Train Acc: 0.9600 | Val Acc: 0.9574 | Train Dice: 0.7640 | Val Dice: 0.7298
# Fold 1 | Epoch 79/100 | Train Loss: 0.6109 | Val Loss: 0.6458 | Train Acc: 0.9590 | Val Acc: 0.9576 | Train Dice: 0.7644 | Val Dice: 0.7259
# Fold 1 | Epoch 80/100 | Train Loss: 0.6081 | Val Loss: 0.6476 | Train Acc: 0.9601 | Val Acc: 0.9540 | Train Dice: 0.7630 | Val Dice: 0.7321
# Fold 1 | Epoch 81/100 | Train Loss: 0.6137 | Val Loss: 0.6402 | Train Acc: 0.9591 | Val Acc: 0.9558 | Train Dice: 0.7623 | Val Dice: 0.7358
# Fold 1 | Epoch 82/100 | Train Loss: 0.6080 | Val Loss: 0.6399 | Train Acc: 0.9596 | Val Acc: 0.9559 | Train Dice: 0.7660 | Val Dice: 0.7341
# Fold 1 | Epoch 83/100 | Train Loss: 0.6049 | Val Loss: 0.6453 | Train Acc: 0.9602 | Val Acc: 0.9549 | Train Dice: 0.7686 | Val Dice: 0.7301
# Fold 1 | Epoch 84/100 | Train Loss: 0.6011 | Val Loss: 0.6361 | Train Acc: 0.9608 | Val Acc: 0.9579 | Train Dice: 0.7676 | Val Dice: 0.7334
# Fold 1 | Epoch 85/100 | Train Loss: 0.6111 | Val Loss: 0.6383 | Train Acc: 0.9595 | Val Acc: 0.9563 | Train Dice: 0.7625 | Val Dice: 0.7343
# Fold 1 | Epoch 86/100 | Train Loss: 0.6023 | Val Loss: 0.6353 | Train Acc: 0.9605 | Val Acc: 0.9575 | Train Dice: 0.7673 | Val Dice: 0.7357
# Fold 1 | Epoch 87/100 | Train Loss: 0.6077 | Val Loss: 0.6337 | Train Acc: 0.9591 | Val Acc: 0.9575 | Train Dice: 0.7650 | Val Dice: 0.7365
# Fold 1 | Epoch 88/100 | Train Loss: 0.6031 | Val Loss: 0.6636 | Train Acc: 0.9597 | Val Acc: 0.9577 | Train Dice: 0.7675 | Val Dice: 0.7043
# Fold 1 | Epoch 89/100 | Train Loss: 0.6177 | Val Loss: 0.6335 | Train Acc: 0.9578 | Val Acc: 0.9574 | Train Dice: 0.7569 | Val Dice: 0.7376
# Fold 1 | Epoch 90/100 | Train Loss: 0.6044 | Val Loss: 0.6348 | Train Acc: 0.9608 | Val Acc: 0.9565 | Train Dice: 0.7650 | Val Dice: 0.7396
# Fold 1 | Epoch 91/100 | Train Loss: 0.5997 | Val Loss: 0.6302 | Train Acc: 0.9606 | Val Acc: 0.9574 | Train Dice: 0.7700 | Val Dice: 0.7407
# Fold 1 | Epoch 92/100 | Train Loss: 0.5954 | Val Loss: 0.6420 | Train Acc: 0.9618 | Val Acc: 0.9549 | Train Dice: 0.7743 | Val Dice: 0.7330
# Fold 1 | Epoch 93/100 | Train Loss: 0.5951 | Val Loss: 0.6336 | Train Acc: 0.9606 | Val Acc: 0.9572 | Train Dice: 0.7721 | Val Dice: 0.7356
# Fold 1 | Epoch 94/100 | Train Loss: 0.5952 | Val Loss: 0.6321 | Train Acc: 0.9612 | Val Acc: 0.9568 | Train Dice: 0.7716 | Val Dice: 0.7387
# Fold 1 | Epoch 95/100 | Train Loss: 0.5883 | Val Loss: 0.6351 | Train Acc: 0.9628 | Val Acc: 0.9578 | Train Dice: 0.7764 | Val Dice: 0.7325
# Fold 1 | Epoch 96/100 | Train Loss: 0.5919 | Val Loss: 0.6301 | Train Acc: 0.9615 | Val Acc: 0.9568 | Train Dice: 0.7753 | Val Dice: 0.7405
# Fold 1 | Epoch 97/100 | Train Loss: 0.6050 | Val Loss: 0.6293 | Train Acc: 0.9601 | Val Acc: 0.9575 | Train Dice: 0.7663 | Val Dice: 0.7398
# Fold 1 | Epoch 98/100 | Train Loss: 0.5873 | Val Loss: 0.6371 | Train Acc: 0.9619 | Val Acc: 0.9581 | Train Dice: 0.7788 | Val Dice: 0.7313
# Fold 1 | Epoch 99/100 | Train Loss: 0.5916 | Val Loss: 0.6314 | Train Acc: 0.9614 | Val Acc: 0.9582 | Train Dice: 0.7732 | Val Dice: 0.7365
# Fold 1 | Epoch 100/100 | Train Loss: 0.5941 | Val Loss: 0.6365 | Train Acc: 0.9612 | Val Acc: 0.9571 | Train Dice: 0.7713 | Val Dice: 0.7344
#
# ===== FOLD 2 ====
# Fold 2 | Epoch 1/100 | Train Loss: 1.3190 | Val Loss: 1.3284 | Train Acc: 0.9168 | Val Acc: 0.9005 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 2 | Epoch 2/100 | Train Loss: 1.3145 | Val Loss: 1.3186 | Train Acc: 0.9162 | Val Acc: 0.9005 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 2 | Epoch 3/100 | Train Loss: 1.2807 | Val Loss: 1.2758 | Train Acc: 0.9169 | Val Acc: 0.9005 | Train Dice: 0.0094 | Val Dice: 0.0000
# Fold 2 | Epoch 4/100 | Train Loss: 1.1966 | Val Loss: 1.2851 | Train Acc: 0.9153 | Val Acc: 0.9017 | Train Dice: 0.2100 | Val Dice: 0.0439
# Fold 2 | Epoch 5/100 | Train Loss: 1.1574 | Val Loss: 1.2116 | Train Acc: 0.8464 | Val Acc: 0.8755 | Train Dice: 0.3245 | Val Dice: 0.2741
# Fold 2 | Epoch 6/100 | Train Loss: 1.1285 | Val Loss: 1.1614 | Train Acc: 0.8388 | Val Acc: 0.8250 | Train Dice: 0.3264 | Val Dice: 0.3205
# Fold 2 | Epoch 7/100 | Train Loss: 1.1028 | Val Loss: 1.1453 | Train Acc: 0.8447 | Val Acc: 0.8311 | Train Dice: 0.3258 | Val Dice: 0.3134
# Fold 2 | Epoch 8/100 | Train Loss: 1.0918 | Val Loss: 1.1456 | Train Acc: 0.8796 | Val Acc: 0.8069 | Train Dice: 0.3327 | Val Dice: 0.3086
# Fold 2 | Epoch 9/100 | Train Loss: 1.0864 | Val Loss: 1.1258 | Train Acc: 0.8409 | Val Acc: 0.8388 | Train Dice: 0.3278 | Val Dice: 0.3284
# Fold 2 | Epoch 10/100 | Train Loss: 1.0770 | Val Loss: 1.1180 | Train Acc: 0.8802 | Val Acc: 0.8397 | Train Dice: 0.3370 | Val Dice: 0.3469
# Fold 2 | Epoch 11/100 | Train Loss: 1.0473 | Val Loss: 1.0781 | Train Acc: 0.8680 | Val Acc: 0.8846 | Train Dice: 0.3773 | Val Dice: 0.4012
# Fold 2 | Epoch 12/100 | Train Loss: 1.0242 | Val Loss: 1.0591 | Train Acc: 0.9049 | Val Acc: 0.8728 | Train Dice: 0.4150 | Val Dice: 0.4211
# Fold 2 | Epoch 13/100 | Train Loss: 1.0172 | Val Loss: 1.0341 | Train Acc: 0.8961 | Val Acc: 0.9061 | Train Dice: 0.4236 | Val Dice: 0.4428
# Fold 2 | Epoch 14/100 | Train Loss: 0.9781 | Val Loss: 0.9996 | Train Acc: 0.9048 | Val Acc: 0.9111 | Train Dice: 0.4703 | Val Dice: 0.4827
# Fold 2 | Epoch 15/100 | Train Loss: 0.9400 | Val Loss: 0.9842 | Train Acc: 0.9146 | Val Acc: 0.9160 | Train Dice: 0.5109 | Val Dice: 0.4804
# Fold 2 | Epoch 16/100 | Train Loss: 0.9061 | Val Loss: 0.9787 | Train Acc: 0.9212 | Val Acc: 0.9181 | Train Dice: 0.5428 | Val Dice: 0.4631
# Fold 2 | Epoch 17/100 | Train Loss: 0.8879 | Val Loss: 0.9267 | Train Acc: 0.9234 | Val Acc: 0.9219 | Train Dice: 0.5583 | Val Dice: 0.5299
# Fold 2 | Epoch 18/100 | Train Loss: 0.8612 | Val Loss: 0.9321 | Train Acc: 0.9258 | Val Acc: 0.9241 | Train Dice: 0.5807 | Val Dice: 0.5107
# Fold 2 | Epoch 19/100 | Train Loss: 0.8451 | Val Loss: 0.9534 | Train Acc: 0.9284 | Val Acc: 0.9239 | Train Dice: 0.5934 | Val Dice: 0.4786
# Fold 2 | Epoch 20/100 | Train Loss: 0.8214 | Val Loss: 0.8862 | Train Acc: 0.9339 | Val Acc: 0.9290 | Train Dice: 0.6114 | Val Dice: 0.5637
# Fold 2 | Epoch 21/100 | Train Loss: 0.8059 | Val Loss: 0.9208 | Train Acc: 0.9340 | Val Acc: 0.9276 | Train Dice: 0.6253 | Val Dice: 0.5157
# Fold 2 | Epoch 22/100 | Train Loss: 0.8018 | Val Loss: 0.8666 | Train Acc: 0.9336 | Val Acc: 0.9320 | Train Dice: 0.6322 | Val Dice: 0.5824
# Fold 2 | Epoch 23/100 | Train Loss: 0.7910 | Val Loss: 0.8156 | Train Acc: 0.9396 | Val Acc: 0.9296 | Train Dice: 0.6391 | Val Dice: 0.6450
# Fold 2 | Epoch 24/100 | Train Loss: 0.7717 | Val Loss: 0.8587 | Train Acc: 0.9414 | Val Acc: 0.9339 | Train Dice: 0.6535 | Val Dice: 0.5815
# Fold 2 | Epoch 25/100 | Train Loss: 0.7672 | Val Loss: 0.8318 | Train Acc: 0.9400 | Val Acc: 0.9359 | Train Dice: 0.6597 | Val Dice: 0.6121
# Fold 2 | Epoch 26/100 | Train Loss: 0.7495 | Val Loss: 0.7972 | Train Acc: 0.9460 | Val Acc: 0.9329 | Train Dice: 0.6676 | Val Dice: 0.6573
# Fold 2 | Epoch 27/100 | Train Loss: 0.7476 | Val Loss: 0.8242 | Train Acc: 0.9438 | Val Acc: 0.9367 | Train Dice: 0.6731 | Val Dice: 0.6215
# Fold 2 | Epoch 28/100 | Train Loss: 0.7353 | Val Loss: 0.7810 | Train Acc: 0.9456 | Val Acc: 0.9378 | Train Dice: 0.6823 | Val Dice: 0.6660
# Fold 2 | Epoch 29/100 | Train Loss: 0.7252 | Val Loss: 0.7691 | Train Acc: 0.9482 | Val Acc: 0.9392 | Train Dice: 0.6868 | Val Dice: 0.6754
# Fold 2 | Epoch 30/100 | Train Loss: 0.7156 | Val Loss: 0.8682 | Train Acc: 0.9469 | Val Acc: 0.9340 | Train Dice: 0.6996 | Val Dice: 0.5593
# Fold 2 | Epoch 31/100 | Train Loss: 0.7261 | Val Loss: 0.7632 | Train Acc: 0.9468 | Val Acc: 0.9355 | Train Dice: 0.6841 | Val Dice: 0.6828
# Fold 2 | Epoch 32/100 | Train Loss: 0.7208 | Val Loss: 0.7639 | Train Acc: 0.9475 | Val Acc: 0.9421 | Train Dice: 0.6878 | Val Dice: 0.6728
# Fold 2 | Epoch 33/100 | Train Loss: 0.7074 | Val Loss: 0.7628 | Train Acc: 0.9476 | Val Acc: 0.9418 | Train Dice: 0.7023 | Val Dice: 0.6786
# Fold 2 | Epoch 34/100 | Train Loss: 0.6937 | Val Loss: 0.7558 | Train Acc: 0.9533 | Val Acc: 0.9429 | Train Dice: 0.7088 | Val Dice: 0.6813
# Fold 2 | Epoch 35/100 | Train Loss: 0.6866 | Val Loss: 0.7471 | Train Acc: 0.9517 | Val Acc: 0.9439 | Train Dice: 0.7169 | Val Dice: 0.6857
# Fold 2 | Epoch 36/100 | Train Loss: 0.6866 | Val Loss: 0.7377 | Train Acc: 0.9529 | Val Acc: 0.9417 | Train Dice: 0.7152 | Val Dice: 0.7004
# Fold 2 | Epoch 37/100 | Train Loss: 0.6853 | Val Loss: 0.7482 | Train Acc: 0.9522 | Val Acc: 0.9426 | Train Dice: 0.7138 | Val Dice: 0.6888
# Fold 2 | Epoch 38/100 | Train Loss: 0.6798 | Val Loss: 0.7738 | Train Acc: 0.9514 | Val Acc: 0.9427 | Train Dice: 0.7209 | Val Dice: 0.6570
# Fold 2 | Epoch 39/100 | Train Loss: 0.6777 | Val Loss: 0.7243 | Train Acc: 0.9535 | Val Acc: 0.9429 | Train Dice: 0.7183 | Val Dice: 0.7081
# Fold 2 | Epoch 40/100 | Train Loss: 0.6691 | Val Loss: 0.7459 | Train Acc: 0.9542 | Val Acc: 0.9450 | Train Dice: 0.7261 | Val Dice: 0.6832
# Fold 2 | Epoch 41/100 | Train Loss: 0.6659 | Val Loss: 0.7344 | Train Acc: 0.9539 | Val Acc: 0.9430 | Train Dice: 0.7306 | Val Dice: 0.7005
# Fold 2 | Epoch 42/100 | Train Loss: 0.6605 | Val Loss: 0.7315 | Train Acc: 0.9555 | Val Acc: 0.9445 | Train Dice: 0.7310 | Val Dice: 0.6984
# Fold 2 | Epoch 43/100 | Train Loss: 0.6608 | Val Loss: 0.7499 | Train Acc: 0.9537 | Val Acc: 0.9450 | Train Dice: 0.7318 | Val Dice: 0.6746
# Fold 2 | Epoch 44/100 | Train Loss: 0.6695 | Val Loss: 0.7244 | Train Acc: 0.9539 | Val Acc: 0.9421 | Train Dice: 0.7225 | Val Dice: 0.7098
# Fold 2 | Epoch 45/100 | Train Loss: 0.6706 | Val Loss: 0.7139 | Train Acc: 0.9538 | Val Acc: 0.9447 | Train Dice: 0.7233 | Val Dice: 0.7145
# Fold 2 | Epoch 46/100 | Train Loss: 0.6638 | Val Loss: 0.7500 | Train Acc: 0.9525 | Val Acc: 0.9453 | Train Dice: 0.7308 | Val Dice: 0.6736
# Fold 2 | Epoch 47/100 | Train Loss: 0.6502 | Val Loss: 0.7271 | Train Acc: 0.9568 | Val Acc: 0.9433 | Train Dice: 0.7367 | Val Dice: 0.7062
# Fold 2 | Epoch 48/100 | Train Loss: 0.6496 | Val Loss: 0.7258 | Train Acc: 0.9558 | Val Acc: 0.9460 | Train Dice: 0.7364 | Val Dice: 0.7008
# Fold 2 | Epoch 49/100 | Train Loss: 0.6504 | Val Loss: 0.7132 | Train Acc: 0.9561 | Val Acc: 0.9464 | Train Dice: 0.7349 | Val Dice: 0.7102
# Fold 2 | Epoch 50/100 | Train Loss: 0.6489 | Val Loss: 0.7134 | Train Acc: 0.9556 | Val Acc: 0.9463 | Train Dice: 0.7383 | Val Dice: 0.7100
# Fold 2 | Epoch 51/100 | Train Loss: 0.6448 | Val Loss: 0.7460 | Train Acc: 0.9553 | Val Acc: 0.9455 | Train Dice: 0.7420 | Val Dice: 0.6751
# Fold 2 | Epoch 52/100 | Train Loss: 0.6451 | Val Loss: 0.7054 | Train Acc: 0.9563 | Val Acc: 0.9466 | Train Dice: 0.7377 | Val Dice: 0.7158
# Fold 2 | Epoch 53/100 | Train Loss: 0.6349 | Val Loss: 0.7166 | Train Acc: 0.9577 | Val Acc: 0.9451 | Train Dice: 0.7455 | Val Dice: 0.7100
# Fold 2 | Epoch 54/100 | Train Loss: 0.6352 | Val Loss: 0.7618 | Train Acc: 0.9567 | Val Acc: 0.9443 | Train Dice: 0.7471 | Val Dice: 0.6600
# Fold 2 | Epoch 55/100 | Train Loss: 0.6410 | Val Loss: 0.7035 | Train Acc: 0.9580 | Val Acc: 0.9441 | Train Dice: 0.7408 | Val Dice: 0.7215
# Fold 2 | Epoch 56/100 | Train Loss: 0.6464 | Val Loss: 0.6964 | Train Acc: 0.9564 | Val Acc: 0.9479 | Train Dice: 0.7345 | Val Dice: 0.7231
# Fold 2 | Epoch 57/100 | Train Loss: 0.6320 | Val Loss: 0.7281 | Train Acc: 0.9565 | Val Acc: 0.9466 | Train Dice: 0.7486 | Val Dice: 0.6920
# Fold 2 | Epoch 58/100 | Train Loss: 0.6342 | Val Loss: 0.7045 | Train Acc: 0.9596 | Val Acc: 0.9449 | Train Dice: 0.7420 | Val Dice: 0.7209
# Fold 2 | Epoch 59/100 | Train Loss: 0.6523 | Val Loss: 0.7218 | Train Acc: 0.9548 | Val Acc: 0.9476 | Train Dice: 0.7329 | Val Dice: 0.6924
# Fold 2 | Epoch 60/100 | Train Loss: 0.6303 | Val Loss: 0.6945 | Train Acc: 0.9576 | Val Acc: 0.9477 | Train Dice: 0.7467 | Val Dice: 0.7238
# Fold 2 | Epoch 61/100 | Train Loss: 0.6292 | Val Loss: 0.7036 | Train Acc: 0.9588 | Val Acc: 0.9481 | Train Dice: 0.7479 | Val Dice: 0.7117
# Fold 2 | Epoch 62/100 | Train Loss: 0.6247 | Val Loss: 0.7195 | Train Acc: 0.9584 | Val Acc: 0.9475 | Train Dice: 0.7535 | Val Dice: 0.6958
# Fold 2 | Epoch 63/100 | Train Loss: 0.6336 | Val Loss: 0.7009 | Train Acc: 0.9579 | Val Acc: 0.9434 | Train Dice: 0.7445 | Val Dice: 0.7231
# Fold 2 | Epoch 64/100 | Train Loss: 0.6379 | Val Loss: 0.7314 | Train Acc: 0.9556 | Val Acc: 0.9470 | Train Dice: 0.7437 | Val Dice: 0.6854
# Fold 2 | Epoch 65/100 | Train Loss: 0.6248 | Val Loss: 0.7055 | Train Acc: 0.9588 | Val Acc: 0.9461 | Train Dice: 0.7522 | Val Dice: 0.7172
# Fold 2 | Epoch 66/100 | Train Loss: 0.6204 | Val Loss: 0.7067 | Train Acc: 0.9594 | Val Acc: 0.9481 | Train Dice: 0.7537 | Val Dice: 0.7076
# Fold 2 | Epoch 67/100 | Train Loss: 0.6182 | Val Loss: 0.7019 | Train Acc: 0.9596 | Val Acc: 0.9482 | Train Dice: 0.7559 | Val Dice: 0.7136
# Fold 2 | Epoch 68/100 | Train Loss: 0.6216 | Val Loss: 0.7158 | Train Acc: 0.9585 | Val Acc: 0.9472 | Train Dice: 0.7544 | Val Dice: 0.6996
# Fold 2 | Epoch 69/100 | Train Loss: 0.6184 | Val Loss: 0.6887 | Train Acc: 0.9594 | Val Acc: 0.9486 | Train Dice: 0.7553 | Val Dice: 0.7241
# Fold 2 | Epoch 70/100 | Train Loss: 0.6145 | Val Loss: 0.7033 | Train Acc: 0.9601 | Val Acc: 0.9474 | Train Dice: 0.7579 | Val Dice: 0.7158
# Fold 2 | Epoch 71/100 | Train Loss: 0.6188 | Val Loss: 0.7029 | Train Acc: 0.9584 | Val Acc: 0.9480 | Train Dice: 0.7579 | Val Dice: 0.7098
# Fold 2 | Epoch 72/100 | Train Loss: 0.6203 | Val Loss: 0.6868 | Train Acc: 0.9588 | Val Acc: 0.9498 | Train Dice: 0.7531 | Val Dice: 0.7212
# Fold 2 | Epoch 73/100 | Train Loss: 0.6114 | Val Loss: 0.6876 | Train Acc: 0.9604 | Val Acc: 0.9485 | Train Dice: 0.7603 | Val Dice: 0.7254
# Fold 2 | Epoch 74/100 | Train Loss: 0.6063 | Val Loss: 0.6957 | Train Acc: 0.9609 | Val Acc: 0.9481 | Train Dice: 0.7647 | Val Dice: 0.7170
# Fold 2 | Epoch 75/100 | Train Loss: 0.6083 | Val Loss: 0.6883 | Train Acc: 0.9601 | Val Acc: 0.9495 | Train Dice: 0.7606 | Val Dice: 0.7209
# Fold 2 | Epoch 76/100 | Train Loss: 0.6054 | Val Loss: 0.6917 | Train Acc: 0.9609 | Val Acc: 0.9481 | Train Dice: 0.7623 | Val Dice: 0.7226
# Fold 2 | Epoch 77/100 | Train Loss: 0.6050 | Val Loss: 0.6924 | Train Acc: 0.9603 | Val Acc: 0.9476 | Train Dice: 0.7648 | Val Dice: 0.7219
# Fold 2 | Epoch 78/100 | Train Loss: 0.6049 | Val Loss: 0.6863 | Train Acc: 0.9599 | Val Acc: 0.9492 | Train Dice: 0.7652 | Val Dice: 0.7239
# Fold 2 | Epoch 79/100 | Train Loss: 0.6094 | Val Loss: 0.7074 | Train Acc: 0.9598 | Val Acc: 0.9488 | Train Dice: 0.7610 | Val Dice: 0.7036
# Fold 2 | Epoch 80/100 | Train Loss: 0.6005 | Val Loss: 0.7229 | Train Acc: 0.9608 | Val Acc: 0.9475 | Train Dice: 0.7664 | Val Dice: 0.6875
# Fold 2 | Epoch 81/100 | Train Loss: 0.6015 | Val Loss: 0.6943 | Train Acc: 0.9612 | Val Acc: 0.9482 | Train Dice: 0.7668 | Val Dice: 0.7201
# Fold 2 | Epoch 82/100 | Train Loss: 0.5948 | Val Loss: 0.7046 | Train Acc: 0.9621 | Val Acc: 0.9483 | Train Dice: 0.7709 | Val Dice: 0.7100
# Fold 2 | Epoch 83/100 | Train Loss: 0.6027 | Val Loss: 0.6924 | Train Acc: 0.9609 | Val Acc: 0.9493 | Train Dice: 0.7650 | Val Dice: 0.7194
# Fold 2 | Epoch 84/100 | Train Loss: 0.6091 | Val Loss: 0.6985 | Train Acc: 0.9601 | Val Acc: 0.9443 | Train Dice: 0.7602 | Val Dice: 0.7247
# Fold 2 | Epoch 85/100 | Train Loss: 0.6064 | Val Loss: 0.6869 | Train Acc: 0.9602 | Val Acc: 0.9480 | Train Dice: 0.7619 | Val Dice: 0.7264
# Fold 2 | Epoch 86/100 | Train Loss: 0.5951 | Val Loss: 0.7091 | Train Acc: 0.9617 | Val Acc: 0.9488 | Train Dice: 0.7720 | Val Dice: 0.6999
# Fold 2 | Epoch 87/100 | Train Loss: 0.6068 | Val Loss: 0.6880 | Train Acc: 0.9606 | Val Acc: 0.9487 | Train Dice: 0.7636 | Val Dice: 0.7237
# Fold 2 | Epoch 88/100 | Train Loss: 0.5945 | Val Loss: 0.6920 | Train Acc: 0.9618 | Val Acc: 0.9492 | Train Dice: 0.7711 | Val Dice: 0.7142
# Fold 2 | Epoch 89/100 | Train Loss: 0.5913 | Val Loss: 0.6958 | Train Acc: 0.9617 | Val Acc: 0.9496 | Train Dice: 0.7721 | Val Dice: 0.7115
# Fold 2 | Epoch 90/100 | Train Loss: 0.5911 | Val Loss: 0.6980 | Train Acc: 0.9621 | Val Acc: 0.9477 | Train Dice: 0.7732 | Val Dice: 0.7167
# Fold 2 | Epoch 91/100 | Train Loss: 0.5915 | Val Loss: 0.6803 | Train Acc: 0.9620 | Val Acc: 0.9495 | Train Dice: 0.7733 | Val Dice: 0.7279
# Fold 2 | Epoch 92/100 | Train Loss: 0.5820 | Val Loss: 0.7090 | Train Acc: 0.9636 | Val Acc: 0.9485 | Train Dice: 0.7788 | Val Dice: 0.7011
# Fold 2 | Epoch 93/100 | Train Loss: 0.5953 | Val Loss: 0.7087 | Train Acc: 0.9612 | Val Acc: 0.9486 | Train Dice: 0.7685 | Val Dice: 0.6981
# Fold 2 | Epoch 94/100 | Train Loss: 0.5937 | Val Loss: 0.7076 | Train Acc: 0.9614 | Val Acc: 0.9489 | Train Dice: 0.7692 | Val Dice: 0.6983
# Fold 2 | Epoch 95/100 | Train Loss: 0.5932 | Val Loss: 0.6846 | Train Acc: 0.9623 | Val Acc: 0.9486 | Train Dice: 0.7692 | Val Dice: 0.7262
# Fold 2 | Epoch 96/100 | Train Loss: 0.5898 | Val Loss: 0.6827 | Train Acc: 0.9628 | Val Acc: 0.9482 | Train Dice: 0.7717 | Val Dice: 0.7287
# Fold 2 | Epoch 97/100 | Train Loss: 0.5932 | Val Loss: 0.6998 | Train Acc: 0.9617 | Val Acc: 0.9494 | Train Dice: 0.7703 | Val Dice: 0.7065
# Fold 2 | Epoch 98/100 | Train Loss: 0.5913 | Val Loss: 0.6959 | Train Acc: 0.9614 | Val Acc: 0.9493 | Train Dice: 0.7728 | Val Dice: 0.7125
# Fold 2 | Epoch 99/100 | Train Loss: 0.5975 | Val Loss: 0.6781 | Train Acc: 0.9619 | Val Acc: 0.9476 | Train Dice: 0.7680 | Val Dice: 0.7353
# Fold 2 | Epoch 100/100 | Train Loss: 0.5927 | Val Loss: 0.7041 | Train Acc: 0.9615 | Val Acc: 0.9487 | Train Dice: 0.7723 | Val Dice: 0.7080
#
# ===== FOLD 3 ====
# Fold 3 | Epoch 1/100 | Train Loss: 1.3250 | Val Loss: 1.3108 | Train Acc: 0.9082 | Val Acc: 0.9163 | Train Dice: 0.0144 | Val Dice: 0.0000
# Fold 3 | Epoch 2/100 | Train Loss: 1.3182 | Val Loss: 1.3004 | Train Acc: 0.9135 | Val Acc: 0.9163 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 3 | Epoch 3/100 | Train Loss: 1.2826 | Val Loss: 1.2390 | Train Acc: 0.9129 | Val Acc: 0.9163 | Train Dice: 0.0015 | Val Dice: 0.0000
# Fold 3 | Epoch 4/100 | Train Loss: 1.2012 | Val Loss: 1.1756 | Train Acc: 0.9122 | Val Acc: 0.9207 | Train Dice: 0.1898 | Val Dice: 0.1754
# Fold 3 | Epoch 5/100 | Train Loss: 1.1680 | Val Loss: 1.1468 | Train Acc: 0.8406 | Val Acc: 0.8769 | Train Dice: 0.3390 | Val Dice: 0.3424
# Fold 3 | Epoch 6/100 | Train Loss: 1.1441 | Val Loss: 1.1163 | Train Acc: 0.8333 | Val Acc: 0.8356 | Train Dice: 0.3216 | Val Dice: 0.3192
# Fold 3 | Epoch 7/100 | Train Loss: 1.1152 | Val Loss: 1.0774 | Train Acc: 0.8354 | Val Acc: 0.8500 | Train Dice: 0.3179 | Val Dice: 0.3334
# Fold 3 | Epoch 8/100 | Train Loss: 1.1016 | Val Loss: 1.0787 | Train Acc: 0.8498 | Val Acc: 0.8393 | Train Dice: 0.3228 | Val Dice: 0.3321
# Fold 3 | Epoch 9/100 | Train Loss: 1.0970 | Val Loss: 1.0781 | Train Acc: 0.8552 | Val Acc: 0.8373 | Train Dice: 0.3283 | Val Dice: 0.3352
# Fold 3 | Epoch 10/100 | Train Loss: 1.0947 | Val Loss: 1.0597 | Train Acc: 0.8537 | Val Acc: 0.9017 | Train Dice: 0.3287 | Val Dice: 0.3382
# Fold 3 | Epoch 11/100 | Train Loss: 1.0785 | Val Loss: 1.0535 | Train Acc: 0.8601 | Val Acc: 0.9042 | Train Dice: 0.3424 | Val Dice: 0.3467
# Fold 3 | Epoch 12/100 | Train Loss: 1.0632 | Val Loss: 1.0421 | Train Acc: 0.8815 | Val Acc: 0.9090 | Train Dice: 0.3578 | Val Dice: 0.3707
# Fold 3 | Epoch 13/100 | Train Loss: 1.0491 | Val Loss: 1.0168 | Train Acc: 0.8917 | Val Acc: 0.8954 | Train Dice: 0.4038 | Val Dice: 0.4129
# Fold 3 | Epoch 14/100 | Train Loss: 1.0313 | Val Loss: 0.9883 | Train Acc: 0.8931 | Val Acc: 0.8982 | Train Dice: 0.4267 | Val Dice: 0.4613
# Fold 3 | Epoch 15/100 | Train Loss: 1.0140 | Val Loss: 1.0061 | Train Acc: 0.8811 | Val Acc: 0.9260 | Train Dice: 0.4483 | Val Dice: 0.3945
# Fold 3 | Epoch 16/100 | Train Loss: 0.9794 | Val Loss: 0.9330 | Train Acc: 0.9109 | Val Acc: 0.9218 | Train Dice: 0.4822 | Val Dice: 0.5131
# Fold 3 | Epoch 17/100 | Train Loss: 0.9621 | Val Loss: 0.9348 | Train Acc: 0.9105 | Val Acc: 0.9287 | Train Dice: 0.4942 | Val Dice: 0.4782
# Fold 3 | Epoch 18/100 | Train Loss: 0.9256 | Val Loss: 0.9061 | Train Acc: 0.9151 | Val Acc: 0.9305 | Train Dice: 0.5269 | Val Dice: 0.5054
# Fold 3 | Epoch 19/100 | Train Loss: 0.9004 | Val Loss: 0.8624 | Train Acc: 0.9217 | Val Acc: 0.9307 | Train Dice: 0.5511 | Val Dice: 0.5667
# Fold 3 | Epoch 20/100 | Train Loss: 0.8847 | Val Loss: 0.8389 | Train Acc: 0.9229 | Val Acc: 0.9329 | Train Dice: 0.5668 | Val Dice: 0.5899
# Fold 3 | Epoch 21/100 | Train Loss: 0.8631 | Val Loss: 0.8182 | Train Acc: 0.9256 | Val Acc: 0.9371 | Train Dice: 0.5891 | Val Dice: 0.6100
# Fold 3 | Epoch 22/100 | Train Loss: 0.8436 | Val Loss: 0.7982 | Train Acc: 0.9302 | Val Acc: 0.9392 | Train Dice: 0.6060 | Val Dice: 0.6317
# Fold 3 | Epoch 23/100 | Train Loss: 0.8337 | Val Loss: 0.7866 | Train Acc: 0.9322 | Val Acc: 0.9400 | Train Dice: 0.6137 | Val Dice: 0.6410
# Fold 3 | Epoch 24/100 | Train Loss: 0.8056 | Val Loss: 0.7871 | Train Acc: 0.9352 | Val Acc: 0.9441 | Train Dice: 0.6332 | Val Dice: 0.6322
# Fold 3 | Epoch 25/100 | Train Loss: 0.8060 | Val Loss: 0.7755 | Train Acc: 0.9350 | Val Acc: 0.9453 | Train Dice: 0.6328 | Val Dice: 0.6439
# Fold 3 | Epoch 26/100 | Train Loss: 0.7867 | Val Loss: 0.7601 | Train Acc: 0.9378 | Val Acc: 0.9458 | Train Dice: 0.6486 | Val Dice: 0.6619
# Fold 3 | Epoch 27/100 | Train Loss: 0.7692 | Val Loss: 0.7463 | Train Acc: 0.9419 | Val Acc: 0.9462 | Train Dice: 0.6658 | Val Dice: 0.6751
# Fold 3 | Epoch 28/100 | Train Loss: 0.7687 | Val Loss: 0.7437 | Train Acc: 0.9420 | Val Acc: 0.9411 | Train Dice: 0.6650 | Val Dice: 0.6774
# Fold 3 | Epoch 29/100 | Train Loss: 0.7603 | Val Loss: 0.7422 | Train Acc: 0.9410 | Val Acc: 0.9494 | Train Dice: 0.6689 | Val Dice: 0.6719
# Fold 3 | Epoch 30/100 | Train Loss: 0.7394 | Val Loss: 0.7368 | Train Acc: 0.9438 | Val Acc: 0.9495 | Train Dice: 0.6852 | Val Dice: 0.6775
# Fold 3 | Epoch 31/100 | Train Loss: 0.7357 | Val Loss: 0.7200 | Train Acc: 0.9457 | Val Acc: 0.9480 | Train Dice: 0.6827 | Val Dice: 0.6902
# Fold 3 | Epoch 32/100 | Train Loss: 0.7213 | Val Loss: 0.7197 | Train Acc: 0.9472 | Val Acc: 0.9510 | Train Dice: 0.6935 | Val Dice: 0.6870
# Fold 3 | Epoch 33/100 | Train Loss: 0.7189 | Val Loss: 0.7140 | Train Acc: 0.9473 | Val Acc: 0.9514 | Train Dice: 0.6965 | Val Dice: 0.6899
# Fold 3 | Epoch 34/100 | Train Loss: 0.7133 | Val Loss: 0.7062 | Train Acc: 0.9479 | Val Acc: 0.9512 | Train Dice: 0.6983 | Val Dice: 0.6979
# Fold 3 | Epoch 35/100 | Train Loss: 0.7074 | Val Loss: 0.7109 | Train Acc: 0.9495 | Val Acc: 0.9474 | Train Dice: 0.7033 | Val Dice: 0.6979
# Fold 3 | Epoch 36/100 | Train Loss: 0.7047 | Val Loss: 0.7116 | Train Acc: 0.9490 | Val Acc: 0.9488 | Train Dice: 0.7059 | Val Dice: 0.6972
# Fold 3 | Epoch 37/100 | Train Loss: 0.6956 | Val Loss: 0.7243 | Train Acc: 0.9493 | Val Acc: 0.9520 | Train Dice: 0.7155 | Val Dice: 0.6793
# Fold 3 | Epoch 38/100 | Train Loss: 0.6899 | Val Loss: 0.7001 | Train Acc: 0.9521 | Val Acc: 0.9479 | Train Dice: 0.7132 | Val Dice: 0.7054
# Fold 3 | Epoch 39/100 | Train Loss: 0.6942 | Val Loss: 0.6983 | Train Acc: 0.9507 | Val Acc: 0.9525 | Train Dice: 0.7115 | Val Dice: 0.7007
# Fold 3 | Epoch 40/100 | Train Loss: 0.6831 | Val Loss: 0.6980 | Train Acc: 0.9508 | Val Acc: 0.9527 | Train Dice: 0.7214 | Val Dice: 0.7014
# Fold 3 | Epoch 41/100 | Train Loss: 0.6770 | Val Loss: 0.6940 | Train Acc: 0.9531 | Val Acc: 0.9507 | Train Dice: 0.7209 | Val Dice: 0.7078
# Fold 3 | Epoch 42/100 | Train Loss: 0.6844 | Val Loss: 0.6978 | Train Acc: 0.9515 | Val Acc: 0.9524 | Train Dice: 0.7168 | Val Dice: 0.7008
# Fold 3 | Epoch 43/100 | Train Loss: 0.6749 | Val Loss: 0.7142 | Train Acc: 0.9510 | Val Acc: 0.9528 | Train Dice: 0.7251 | Val Dice: 0.6837
# Fold 3 | Epoch 44/100 | Train Loss: 0.6773 | Val Loss: 0.6873 | Train Acc: 0.9537 | Val Acc: 0.9503 | Train Dice: 0.7182 | Val Dice: 0.7144
# Fold 3 | Epoch 45/100 | Train Loss: 0.6764 | Val Loss: 0.6913 | Train Acc: 0.9534 | Val Acc: 0.9533 | Train Dice: 0.7213 | Val Dice: 0.7062
# Fold 3 | Epoch 46/100 | Train Loss: 0.6680 | Val Loss: 0.6862 | Train Acc: 0.9529 | Val Acc: 0.9528 | Train Dice: 0.7288 | Val Dice: 0.7111
# Fold 3 | Epoch 47/100 | Train Loss: 0.6668 | Val Loss: 0.6851 | Train Acc: 0.9549 | Val Acc: 0.9528 | Train Dice: 0.7276 | Val Dice: 0.7122
# Fold 3 | Epoch 48/100 | Train Loss: 0.6540 | Val Loss: 0.6921 | Train Acc: 0.9549 | Val Acc: 0.9523 | Train Dice: 0.7368 | Val Dice: 0.7058
# Fold 3 | Epoch 49/100 | Train Loss: 0.6573 | Val Loss: 0.6849 | Train Acc: 0.9553 | Val Acc: 0.9508 | Train Dice: 0.7332 | Val Dice: 0.7134
# Fold 3 | Epoch 50/100 | Train Loss: 0.6573 | Val Loss: 0.7132 | Train Acc: 0.9530 | Val Acc: 0.9534 | Train Dice: 0.7367 | Val Dice: 0.6793
# Fold 3 | Epoch 51/100 | Train Loss: 0.6619 | Val Loss: 0.6778 | Train Acc: 0.9542 | Val Acc: 0.9527 | Train Dice: 0.7271 | Val Dice: 0.7178
# Fold 3 | Epoch 52/100 | Train Loss: 0.6504 | Val Loss: 0.6802 | Train Acc: 0.9562 | Val Acc: 0.9535 | Train Dice: 0.7375 | Val Dice: 0.7140
# Fold 3 | Epoch 53/100 | Train Loss: 0.6470 | Val Loss: 0.6903 | Train Acc: 0.9552 | Val Acc: 0.9522 | Train Dice: 0.7428 | Val Dice: 0.7054
# Fold 3 | Epoch 54/100 | Train Loss: 0.6428 | Val Loss: 0.6862 | Train Acc: 0.9561 | Val Acc: 0.9545 | Train Dice: 0.7431 | Val Dice: 0.7029
# Fold 3 | Epoch 55/100 | Train Loss: 0.6418 | Val Loss: 0.6721 | Train Acc: 0.9568 | Val Acc: 0.9539 | Train Dice: 0.7446 | Val Dice: 0.7190
# Fold 3 | Epoch 56/100 | Train Loss: 0.6556 | Val Loss: 0.6887 | Train Acc: 0.9543 | Val Acc: 0.9541 | Train Dice: 0.7340 | Val Dice: 0.7039
# Fold 3 | Epoch 57/100 | Train Loss: 0.6394 | Val Loss: 0.6791 | Train Acc: 0.9556 | Val Acc: 0.9543 | Train Dice: 0.7471 | Val Dice: 0.7115
# Fold 3 | Epoch 58/100 | Train Loss: 0.6310 | Val Loss: 0.6714 | Train Acc: 0.9583 | Val Acc: 0.9530 | Train Dice: 0.7473 | Val Dice: 0.7207
# Fold 3 | Epoch 59/100 | Train Loss: 0.6291 | Val Loss: 0.6864 | Train Acc: 0.9578 | Val Acc: 0.9551 | Train Dice: 0.7520 | Val Dice: 0.7018
# Fold 3 | Epoch 60/100 | Train Loss: 0.6494 | Val Loss: 0.6535 | Train Acc: 0.9554 | Val Acc: 0.9560 | Train Dice: 0.7383 | Val Dice: 0.7294
# Fold 3 | Epoch 61/100 | Train Loss: 0.6256 | Val Loss: 0.6850 | Train Acc: 0.9579 | Val Acc: 0.9545 | Train Dice: 0.7542 | Val Dice: 0.7048
# Fold 3 | Epoch 62/100 | Train Loss: 0.6299 | Val Loss: 0.6625 | Train Acc: 0.9581 | Val Acc: 0.9530 | Train Dice: 0.7523 | Val Dice: 0.7269
# Fold 3 | Epoch 63/100 | Train Loss: 0.6464 | Val Loss: 0.6657 | Train Acc: 0.9560 | Val Acc: 0.9541 | Train Dice: 0.7402 | Val Dice: 0.7232
# Fold 3 | Epoch 64/100 | Train Loss: 0.6301 | Val Loss: 0.7072 | Train Acc: 0.9564 | Val Acc: 0.9535 | Train Dice: 0.7530 | Val Dice: 0.6855
# Fold 3 | Epoch 65/100 | Train Loss: 0.6375 | Val Loss: 0.6597 | Train Acc: 0.9566 | Val Acc: 0.9528 | Train Dice: 0.7461 | Val Dice: 0.7299
# Fold 3 | Epoch 66/100 | Train Loss: 0.6341 | Val Loss: 0.6717 | Train Acc: 0.9575 | Val Acc: 0.9551 | Train Dice: 0.7494 | Val Dice: 0.7158
# Fold 3 | Epoch 67/100 | Train Loss: 0.6267 | Val Loss: 0.6773 | Train Acc: 0.9572 | Val Acc: 0.9543 | Train Dice: 0.7567 | Val Dice: 0.7121
# Fold 3 | Epoch 68/100 | Train Loss: 0.6269 | Val Loss: 0.6505 | Train Acc: 0.9587 | Val Acc: 0.9552 | Train Dice: 0.7529 | Val Dice: 0.7343
# Fold 3 | Epoch 69/100 | Train Loss: 0.6214 | Val Loss: 0.6842 | Train Acc: 0.9577 | Val Acc: 0.9549 | Train Dice: 0.7581 | Val Dice: 0.7028
# Fold 3 | Epoch 70/100 | Train Loss: 0.6204 | Val Loss: 0.6712 | Train Acc: 0.9592 | Val Acc: 0.9544 | Train Dice: 0.7562 | Val Dice: 0.7189
# Fold 3 | Epoch 71/100 | Train Loss: 0.6186 | Val Loss: 0.6578 | Train Acc: 0.9590 | Val Acc: 0.9553 | Train Dice: 0.7591 | Val Dice: 0.7271
# Fold 3 | Epoch 72/100 | Train Loss: 0.6240 | Val Loss: 0.6629 | Train Acc: 0.9579 | Val Acc: 0.9554 | Train Dice: 0.7555 | Val Dice: 0.7226
# Fold 3 | Epoch 73/100 | Train Loss: 0.6128 | Val Loss: 0.6704 | Train Acc: 0.9593 | Val Acc: 0.9566 | Train Dice: 0.7613 | Val Dice: 0.7105
# Fold 3 | Epoch 74/100 | Train Loss: 0.6180 | Val Loss: 0.6517 | Train Acc: 0.9592 | Val Acc: 0.9557 | Train Dice: 0.7583 | Val Dice: 0.7320
# Fold 3 | Epoch 75/100 | Train Loss: 0.6168 | Val Loss: 0.6603 | Train Acc: 0.9591 | Val Acc: 0.9565 | Train Dice: 0.7594 | Val Dice: 0.7223
# Fold 3 | Epoch 76/100 | Train Loss: 0.6068 | Val Loss: 0.6599 | Train Acc: 0.9595 | Val Acc: 0.9564 | Train Dice: 0.7661 | Val Dice: 0.7225
# Fold 3 | Epoch 77/100 | Train Loss: 0.6117 | Val Loss: 0.6555 | Train Acc: 0.9596 | Val Acc: 0.9561 | Train Dice: 0.7628 | Val Dice: 0.7271
# Fold 3 | Epoch 78/100 | Train Loss: 0.6057 | Val Loss: 0.6640 | Train Acc: 0.9600 | Val Acc: 0.9564 | Train Dice: 0.7658 | Val Dice: 0.7193
# Fold 3 | Epoch 79/100 | Train Loss: 0.6078 | Val Loss: 0.6649 | Train Acc: 0.9597 | Val Acc: 0.9559 | Train Dice: 0.7650 | Val Dice: 0.7185
# Fold 3 | Epoch 80/100 | Train Loss: 0.6067 | Val Loss: 0.6641 | Train Acc: 0.9600 | Val Acc: 0.9553 | Train Dice: 0.7647 | Val Dice: 0.7217
# Fold 3 | Epoch 81/100 | Train Loss: 0.6151 | Val Loss: 0.6591 | Train Acc: 0.9597 | Val Acc: 0.9536 | Train Dice: 0.7598 | Val Dice: 0.7284
# Fold 3 | Epoch 82/100 | Train Loss: 0.6164 | Val Loss: 0.6562 | Train Acc: 0.9581 | Val Acc: 0.9576 | Train Dice: 0.7595 | Val Dice: 0.7226
# Fold 3 | Epoch 83/100 | Train Loss: 0.6106 | Val Loss: 0.6695 | Train Acc: 0.9591 | Val Acc: 0.9553 | Train Dice: 0.7645 | Val Dice: 0.7178
# Fold 3 | Epoch 84/100 | Train Loss: 0.5999 | Val Loss: 0.6434 | Train Acc: 0.9610 | Val Acc: 0.9572 | Train Dice: 0.7693 | Val Dice: 0.7352
# Fold 3 | Epoch 85/100 | Train Loss: 0.5997 | Val Loss: 0.6522 | Train Acc: 0.9611 | Val Acc: 0.9559 | Train Dice: 0.7696 | Val Dice: 0.7303
# Fold 3 | Epoch 86/100 | Train Loss: 0.5940 | Val Loss: 0.6504 | Train Acc: 0.9615 | Val Acc: 0.9578 | Train Dice: 0.7733 | Val Dice: 0.7269
# Fold 3 | Epoch 87/100 | Train Loss: 0.5975 | Val Loss: 0.6445 | Train Acc: 0.9608 | Val Acc: 0.9573 | Train Dice: 0.7709 | Val Dice: 0.7340
# Fold 3 | Epoch 88/100 | Train Loss: 0.5988 | Val Loss: 0.6377 | Train Acc: 0.9614 | Val Acc: 0.9556 | Train Dice: 0.7694 | Val Dice: 0.7412
# Fold 3 | Epoch 89/100 | Train Loss: 0.5976 | Val Loss: 0.6468 | Train Acc: 0.9607 | Val Acc: 0.9578 | Train Dice: 0.7712 | Val Dice: 0.7313
# Fold 3 | Epoch 90/100 | Train Loss: 0.5955 | Val Loss: 0.6493 | Train Acc: 0.9610 | Val Acc: 0.9580 | Train Dice: 0.7737 | Val Dice: 0.7273
# Fold 3 | Epoch 91/100 | Train Loss: 0.5967 | Val Loss: 0.6523 | Train Acc: 0.9611 | Val Acc: 0.9552 | Train Dice: 0.7712 | Val Dice: 0.7322
# Fold 3 | Epoch 92/100 | Train Loss: 0.6026 | Val Loss: 0.6448 | Train Acc: 0.9602 | Val Acc: 0.9575 | Train Dice: 0.7677 | Val Dice: 0.7321
# Fold 3 | Epoch 93/100 | Train Loss: 0.5911 | Val Loss: 0.6638 | Train Acc: 0.9610 | Val Acc: 0.9572 | Train Dice: 0.7762 | Val Dice: 0.7165
# Fold 3 | Epoch 94/100 | Train Loss: 0.5909 | Val Loss: 0.6600 | Train Acc: 0.9618 | Val Acc: 0.9568 | Train Dice: 0.7744 | Val Dice: 0.7193
# Fold 3 | Epoch 95/100 | Train Loss: 0.5888 | Val Loss: 0.6489 | Train Acc: 0.9624 | Val Acc: 0.9561 | Train Dice: 0.7751 | Val Dice: 0.7327
# Fold 3 | Epoch 96/100 | Train Loss: 0.5877 | Val Loss: 0.6547 | Train Acc: 0.9622 | Val Acc: 0.9569 | Train Dice: 0.7776 | Val Dice: 0.7242
# Fold 3 | Epoch 97/100 | Train Loss: 0.5865 | Val Loss: 0.6459 | Train Acc: 0.9620 | Val Acc: 0.9582 | Train Dice: 0.7772 | Val Dice: 0.7282
# Fold 3 | Epoch 98/100 | Train Loss: 0.5938 | Val Loss: 0.6431 | Train Acc: 0.9615 | Val Acc: 0.9560 | Train Dice: 0.7719 | Val Dice: 0.7374
# Fold 3 | Epoch 99/100 | Train Loss: 0.5852 | Val Loss: 0.6401 | Train Acc: 0.9628 | Val Acc: 0.9577 | Train Dice: 0.7771 | Val Dice: 0.7364
# Fold 3 | Epoch 100/100 | Train Loss: 0.5851 | Val Loss: 0.6527 | Train Acc: 0.9618 | Val Acc: 0.9571 | Train Dice: 0.7790 | Val Dice: 0.7260
#
# ===== FOLD 4 ====
# Fold 4 | Epoch 1/100 | Train Loss: 1.3249 | Val Loss: 1.3140 | Train Acc: 0.2222 | Val Acc: 0.8918 | Train Dice: 0.1806 | Val Dice: 0.0005
# Fold 4 | Epoch 2/100 | Train Loss: 1.3180 | Val Loss: 1.2992 | Train Acc: 0.8959 | Val Acc: 0.9010 | Train Dice: 0.2178 | Val Dice: 0.0000
# Fold 4 | Epoch 3/100 | Train Loss: 1.2744 | Val Loss: 1.2999 | Train Acc: 0.9149 | Val Acc: 0.9010 | Train Dice: 0.0056 | Val Dice: 0.0000
# Fold 4 | Epoch 4/100 | Train Loss: 1.2032 | Val Loss: 1.2103 | Train Acc: 0.9131 | Val Acc: 0.9018 | Train Dice: 0.1426 | Val Dice: 0.0694
# Fold 4 | Epoch 5/100 | Train Loss: 1.1796 | Val Loss: 1.1776 | Train Acc: 0.8786 | Val Acc: 0.8635 | Train Dice: 0.3250 | Val Dice: 0.3058
# Fold 4 | Epoch 6/100 | Train Loss: 1.1616 | Val Loss: 1.1734 | Train Acc: 0.8498 | Val Acc: 0.8992 | Train Dice: 0.3428 | Val Dice: 0.2954
# Fold 4 | Epoch 7/100 | Train Loss: 1.1452 | Val Loss: 1.1249 | Train Acc: 0.8750 | Val Acc: 0.8470 | Train Dice: 0.3613 | Val Dice: 0.3754
# Fold 4 | Epoch 8/100 | Train Loss: 1.1164 | Val Loss: 1.0983 | Train Acc: 0.8472 | Val Acc: 0.8818 | Train Dice: 0.3435 | Val Dice: 0.3774
# Fold 4 | Epoch 9/100 | Train Loss: 1.0864 | Val Loss: 1.0691 | Train Acc: 0.8613 | Val Acc: 0.8888 | Train Dice: 0.3524 | Val Dice: 0.3959
# Fold 4 | Epoch 10/100 | Train Loss: 1.0678 | Val Loss: 1.1056 | Train Acc: 0.8708 | Val Acc: 0.9098 | Train Dice: 0.3613 | Val Dice: 0.3263
# Fold 4 | Epoch 11/100 | Train Loss: 1.0698 | Val Loss: 1.0189 | Train Acc: 0.8666 | Val Acc: 0.8795 | Train Dice: 0.3682 | Val Dice: 0.4383
# Fold 4 | Epoch 12/100 | Train Loss: 1.0370 | Val Loss: 1.0095 | Train Acc: 0.8989 | Val Acc: 0.9060 | Train Dice: 0.4082 | Val Dice: 0.4503
# Fold 4 | Epoch 13/100 | Train Loss: 1.0026 | Val Loss: 1.0472 | Train Acc: 0.9034 | Val Acc: 0.9143 | Train Dice: 0.4552 | Val Dice: 0.3797
# Fold 4 | Epoch 14/100 | Train Loss: 0.9751 | Val Loss: 1.0223 | Train Acc: 0.9113 | Val Acc: 0.9159 | Train Dice: 0.4846 | Val Dice: 0.3963
# Fold 4 | Epoch 15/100 | Train Loss: 0.9398 | Val Loss: 0.9716 | Train Acc: 0.9175 | Val Acc: 0.9188 | Train Dice: 0.5122 | Val Dice: 0.4553
# Fold 4 | Epoch 16/100 | Train Loss: 0.9149 | Val Loss: 0.9547 | Train Acc: 0.9195 | Val Acc: 0.9216 | Train Dice: 0.5407 | Val Dice: 0.4649
# Fold 4 | Epoch 17/100 | Train Loss: 0.8917 | Val Loss: 0.8997 | Train Acc: 0.9246 | Val Acc: 0.9247 | Train Dice: 0.5583 | Val Dice: 0.5287
# Fold 4 | Epoch 18/100 | Train Loss: 0.8623 | Val Loss: 0.9128 | Train Acc: 0.9276 | Val Acc: 0.9259 | Train Dice: 0.5833 | Val Dice: 0.5109
# Fold 4 | Epoch 19/100 | Train Loss: 0.8446 | Val Loss: 0.9324 | Train Acc: 0.9316 | Val Acc: 0.9251 | Train Dice: 0.6014 | Val Dice: 0.4810
# Fold 4 | Epoch 20/100 | Train Loss: 0.8397 | Val Loss: 0.9057 | Train Acc: 0.9302 | Val Acc: 0.9273 | Train Dice: 0.5960 | Val Dice: 0.5091
# Fold 4 | Epoch 21/100 | Train Loss: 0.8156 | Val Loss: 0.8316 | Train Acc: 0.9353 | Val Acc: 0.9335 | Train Dice: 0.6254 | Val Dice: 0.6012
# Fold 4 | Epoch 22/100 | Train Loss: 0.7981 | Val Loss: 0.7840 | Train Acc: 0.9399 | Val Acc: 0.9348 | Train Dice: 0.6392 | Val Dice: 0.6564
# Fold 4 | Epoch 23/100 | Train Loss: 0.7875 | Val Loss: 0.7750 | Train Acc: 0.9418 | Val Acc: 0.9363 | Train Dice: 0.6451 | Val Dice: 0.6628
# Fold 4 | Epoch 24/100 | Train Loss: 0.7723 | Val Loss: 0.7705 | Train Acc: 0.9418 | Val Acc: 0.9370 | Train Dice: 0.6565 | Val Dice: 0.6639
# Fold 4 | Epoch 25/100 | Train Loss: 0.7667 | Val Loss: 0.7908 | Train Acc: 0.9420 | Val Acc: 0.9382 | Train Dice: 0.6641 | Val Dice: 0.6370
# Fold 4 | Epoch 26/100 | Train Loss: 0.7504 | Val Loss: 0.7836 | Train Acc: 0.9436 | Val Acc: 0.9396 | Train Dice: 0.6755 | Val Dice: 0.6444
# Fold 4 | Epoch 27/100 | Train Loss: 0.7461 | Val Loss: 0.7458 | Train Acc: 0.9449 | Val Acc: 0.9395 | Train Dice: 0.6758 | Val Dice: 0.6813
# Fold 4 | Epoch 28/100 | Train Loss: 0.7341 | Val Loss: 0.7383 | Train Acc: 0.9477 | Val Acc: 0.9404 | Train Dice: 0.6836 | Val Dice: 0.6863
# Fold 4 | Epoch 29/100 | Train Loss: 0.7206 | Val Loss: 0.7330 | Train Acc: 0.9493 | Val Acc: 0.9423 | Train Dice: 0.6925 | Val Dice: 0.6904
# Fold 4 | Epoch 30/100 | Train Loss: 0.7266 | Val Loss: 0.7264 | Train Acc: 0.9471 | Val Acc: 0.9434 | Train Dice: 0.6909 | Val Dice: 0.6952
# Fold 4 | Epoch 31/100 | Train Loss: 0.7148 | Val Loss: 0.7207 | Train Acc: 0.9480 | Val Acc: 0.9447 | Train Dice: 0.7002 | Val Dice: 0.6962
# Fold 4 | Epoch 32/100 | Train Loss: 0.7093 | Val Loss: 0.7302 | Train Acc: 0.9486 | Val Acc: 0.9440 | Train Dice: 0.7010 | Val Dice: 0.6864
# Fold 4 | Epoch 33/100 | Train Loss: 0.7078 | Val Loss: 0.7139 | Train Acc: 0.9506 | Val Acc: 0.9432 | Train Dice: 0.7003 | Val Dice: 0.7056
# Fold 4 | Epoch 34/100 | Train Loss: 0.6939 | Val Loss: 0.7273 | Train Acc: 0.9513 | Val Acc: 0.9445 | Train Dice: 0.7122 | Val Dice: 0.6891
# Fold 4 | Epoch 35/100 | Train Loss: 0.6873 | Val Loss: 0.7133 | Train Acc: 0.9528 | Val Acc: 0.9443 | Train Dice: 0.7163 | Val Dice: 0.7030
# Fold 4 | Epoch 36/100 | Train Loss: 0.6887 | Val Loss: 0.7016 | Train Acc: 0.9524 | Val Acc: 0.9442 | Train Dice: 0.7132 | Val Dice: 0.7120
# ...
# Fold 9 | Epoch 88/100 | Train Loss: 0.6010 | Val Loss: 0.6596 | Train Acc: 0.9612 | Val Acc: 0.9530 | Train Dice: 0.7691 | Val Dice: 0.7267
# Fold 9 | Epoch 89/100 | Train Loss: 0.6106 | Val Loss: 0.6472 | Train Acc: 0.9591 | Val Acc: 0.9595 | Train Dice: 0.7639 | Val Dice: 0.7271
# Fold 9 | Epoch 90/100 | Train Loss: 0.6002 | Val Loss: 0.6451 | Train Acc: 0.9601 | Val Acc: 0.9591 | Train Dice: 0.7714 | Val Dice: 0.7292
# Fold 9 | Epoch 91/100 | Train Loss: 0.5921 | Val Loss: 0.6481 | Train Acc: 0.9627 | Val Acc: 0.9570 | Train Dice: 0.7755 | Val Dice: 0.7310
# Fold 9 | Epoch 92/100 | Train Loss: 0.5923 | Val Loss: 0.6344 | Train Acc: 0.9613 | Val Acc: 0.9599 | Train Dice: 0.7763 | Val Dice: 0.7354
# Fold 9 | Epoch 93/100 | Train Loss: 0.5928 | Val Loss: 0.6537 | Train Acc: 0.9618 | Val Acc: 0.9567 | Train Dice: 0.7745 | Val Dice: 0.7250
# Fold 9 | Epoch 94/100 | Train Loss: 0.5992 | Val Loss: 0.6296 | Train Acc: 0.9610 | Val Acc: 0.9588 | Train Dice: 0.7708 | Val Dice: 0.7408
# Fold 9 | Epoch 95/100 | Train Loss: 0.5867 | Val Loss: 0.6448 | Train Acc: 0.9622 | Val Acc: 0.9576 | Train Dice: 0.7778 | Val Dice: 0.7308
# Fold 9 | Epoch 96/100 | Train Loss: 0.5892 | Val Loss: 0.6414 | Train Acc: 0.9618 | Val Acc: 0.9578 | Train Dice: 0.7782 | Val Dice: 0.7338
# Fold 9 | Epoch 97/100 | Train Loss: 0.5810 | Val Loss: 0.6434 | Train Acc: 0.9627 | Val Acc: 0.9591 | Train Dice: 0.7836 | Val Dice: 0.7286
# Fold 9 | Epoch 98/100 | Train Loss: 0.5870 | Val Loss: 0.6535 | Train Acc: 0.9622 | Val Acc: 0.9578 | Train Dice: 0.7781 | Val Dice: 0.7252
# Fold 9 | Epoch 99/100 | Train Loss: 0.5833 | Val Loss: 0.6307 | Train Acc: 0.9628 | Val Acc: 0.9590 | Train Dice: 0.7813 | Val Dice: 0.7390
# Fold 9 | Epoch 100/100 | Train Loss: 0.5842 | Val Loss: 0.6455 | Train Acc: 0.9623 | Val Acc: 0.9573 | Train Dice: 0.7807 | Val Dice: 0.7307
#
# ===== FOLD 10 ====
# Fold 10 | Epoch 1/100 | Train Loss: 1.3159 | Val Loss: 1.3230 | Train Acc: 0.9143 | Val Acc: 0.9126 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 10 | Epoch 2/100 | Train Loss: 1.3072 | Val Loss: 1.3012 | Train Acc: 0.9134 | Val Acc: 0.9126 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 10 | Epoch 3/100 | Train Loss: 1.2542 | Val Loss: 1.2365 | Train Acc: 0.9129 | Val Acc: 0.9126 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 10 | Epoch 4/100 | Train Loss: 1.1921 | Val Loss: 1.1918 | Train Acc: 0.9132 | Val Acc: 0.9126 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 10 | Epoch 5/100 | Train Loss: 1.1725 | Val Loss: 1.1784 | Train Acc: 0.9141 | Val Acc: 0.9126 | Train Dice: 0.0000 | Val Dice: 0.0000
# Fold 10 | Epoch 6/100 | Train Loss: 1.1585 | Val Loss: 1.1702 | Train Acc: 0.9154 | Val Acc: 0.9137 | Train Dice: 0.0346 | Val Dice: 0.0266
# Fold 10 | Epoch 7/100 | Train Loss: 1.1314 | Val Loss: 1.1677 | Train Acc: 0.9229 | Val Acc: 0.9167 | Train Dice: 0.3835 | Val Dice: 0.1132
# Fold 10 | Epoch 8/100 | Train Loss: 1.0967 | Val Loss: 1.1210 | Train Acc: 0.9208 | Val Acc: 0.9225 | Train Dice: 0.4512 | Val Dice: 0.3094
# Fold 10 | Epoch 9/100 | Train Loss: 1.0461 | Val Loss: 1.0194 | Train Acc: 0.9153 | Val Acc: 0.9209 | Train Dice: 0.4789 | Val Dice: 0.4844
# Fold 10 | Epoch 10/100 | Train Loss: 0.9810 | Val Loss: 1.0759 | Train Acc: 0.9102 | Val Acc: 0.9230 | Train Dice: 0.5110 | Val Dice: 0.3275
# Fold 10 | Epoch 11/100 | Train Loss: 0.9555 | Val Loss: 0.9556 | Train Acc: 0.9100 | Val Acc: 0.9240 | Train Dice: 0.4931 | Val Dice: 0.4864
# Fold 10 | Epoch 12/100 | Train Loss: 0.9304 | Val Loss: 0.9946 | Train Acc: 0.9035 | Val Acc: 0.9266 | Train Dice: 0.5392 | Val Dice: 0.4294
# Fold 10 | Epoch 13/100 | Train Loss: 0.9015 | Val Loss: 0.8924 | Train Acc: 0.9286 | Val Acc: 0.9214 | Train Dice: 0.5530 | Val Dice: 0.5843
# Fold 10 | Epoch 14/100 | Train Loss: 0.8864 | Val Loss: 0.8786 | Train Acc: 0.9247 | Val Acc: 0.9315 | Train Dice: 0.5771 | Val Dice: 0.5627
# Fold 10 | Epoch 15/100 | Train Loss: 0.8435 | Val Loss: 0.9113 | Train Acc: 0.9277 | Val Acc: 0.9326 | Train Dice: 0.6069 | Val Dice: 0.5107
# Fold 10 | Epoch 16/100 | Train Loss: 0.8328 | Val Loss: 0.8385 | Train Acc: 0.9308 | Val Acc: 0.9354 | Train Dice: 0.6090 | Val Dice: 0.6068
# Fold 10 | Epoch 17/100 | Train Loss: 0.8122 | Val Loss: 0.8356 | Train Acc: 0.9361 | Val Acc: 0.9247 | Train Dice: 0.6254 | Val Dice: 0.6266
# Fold 10 | Epoch 18/100 | Train Loss: 0.7992 | Val Loss: 0.8425 | Train Acc: 0.9344 | Val Acc: 0.9398 | Train Dice: 0.6431 | Val Dice: 0.5977
# Fold 10 | Epoch 19/100 | Train Loss: 0.7877 | Val Loss: 0.8065 | Train Acc: 0.9382 | Val Acc: 0.9313 | Train Dice: 0.6503 | Val Dice: 0.6520
# Fold 10 | Epoch 20/100 | Train Loss: 0.7678 | Val Loss: 0.7819 | Train Acc: 0.9442 | Val Acc: 0.9418 | Train Dice: 0.6641 | Val Dice: 0.6639
# Fold 10 | Epoch 21/100 | Train Loss: 0.7544 | Val Loss: 0.7885 | Train Acc: 0.9423 | Val Acc: 0.9436 | Train Dice: 0.6749 | Val Dice: 0.6489
# Fold 10 | Epoch 22/100 | Train Loss: 0.7468 | Val Loss: 0.7732 | Train Acc: 0.9460 | Val Acc: 0.9369 | Train Dice: 0.6755 | Val Dice: 0.6669
# Fold 10 | Epoch 23/100 | Train Loss: 0.7317 | Val Loss: 0.7613 | Train Acc: 0.9461 | Val Acc: 0.9446 | Train Dice: 0.6885 | Val Dice: 0.6722
# Fold 10 | Epoch 24/100 | Train Loss: 0.7219 | Val Loss: 0.7594 | Train Acc: 0.9471 | Val Acc: 0.9456 | Train Dice: 0.6954 | Val Dice: 0.6694
# Fold 10 | Epoch 25/100 | Train Loss: 0.7165 | Val Loss: 0.7468 | Train Acc: 0.9491 | Val Acc: 0.9447 | Train Dice: 0.6964 | Val Dice: 0.6810
# Fold 10 | Epoch 26/100 | Train Loss: 0.7122 | Val Loss: 0.7412 | Train Acc: 0.9491 | Val Acc: 0.9475 | Train Dice: 0.6991 | Val Dice: 0.6798
# Fold 10 | Epoch 27/100 | Train Loss: 0.7005 | Val Loss: 0.7508 | Train Acc: 0.9493 | Val Acc: 0.9474 | Train Dice: 0.7080 | Val Dice: 0.6684
# Fold 10 | Epoch 28/100 | Train Loss: 0.7021 | Val Loss: 0.7384 | Train Acc: 0.9494 | Val Acc: 0.9454 | Train Dice: 0.7057 | Val Dice: 0.6853
# Fold 10 | Epoch 29/100 | Train Loss: 0.6942 | Val Loss: 0.7346 | Train Acc: 0.9519 | Val Acc: 0.9420 | Train Dice: 0.7089 | Val Dice: 0.6929
# Fold 10 | Epoch 30/100 | Train Loss: 0.6926 | Val Loss: 0.7217 | Train Acc: 0.9510 | Val Acc: 0.9482 | Train Dice: 0.7137 | Val Dice: 0.6975
# Fold 10 | Epoch 31/100 | Train Loss: 0.6816 | Val Loss: 0.7254 | Train Acc: 0.9513 | Val Acc: 0.9471 | Train Dice: 0.7216 | Val Dice: 0.6943
# Fold 10 | Epoch 32/100 | Train Loss: 0.6788 | Val Loss: 0.7246 | Train Acc: 0.9524 | Val Acc: 0.9443 | Train Dice: 0.7216 | Val Dice: 0.6979
# Fold 10 | Epoch 33/100 | Train Loss: 0.6767 | Val Loss: 0.7281 | Train Acc: 0.9517 | Val Acc: 0.9493 | Train Dice: 0.7220 | Val Dice: 0.6859
# Fold 10 | Epoch 34/100 | Train Loss: 0.6817 | Val Loss: 0.7077 | Train Acc: 0.9509 | Val Acc: 0.9500 | Train Dice: 0.7223 | Val Dice: 0.7051
# Fold 10 | Epoch 35/100 | Train Loss: 0.6772 | Val Loss: 0.7121 | Train Acc: 0.9531 | Val Acc: 0.9479 | Train Dice: 0.7184 | Val Dice: 0.7044
# Fold 10 | Epoch 36/100 | Train Loss: 0.6622 | Val Loss: 0.7146 | Train Acc: 0.9544 | Val Acc: 0.9460 | Train Dice: 0.7322 | Val Dice: 0.7040
# Fold 10 | Epoch 37/100 | Train Loss: 0.6757 | Val Loss: 0.7075 | Train Acc: 0.9520 | Val Acc: 0.9493 | Train Dice: 0.7231 | Val Dice: 0.7036
# Fold 10 | Epoch 38/100 | Train Loss: 0.6600 | Val Loss: 0.7150 | Train Acc: 0.9529 | Val Acc: 0.9509 | Train Dice: 0.7331 | Val Dice: 0.6916
# Fold 10 | Epoch 39/100 | Train Loss: 0.6704 | Val Loss: 0.7455 | Train Acc: 0.9540 | Val Acc: 0.9362 | Train Dice: 0.7249 | Val Dice: 0.6862
# Fold 10 | Epoch 40/100 | Train Loss: 0.6634 | Val Loss: 0.7068 | Train Acc: 0.9543 | Val Acc: 0.9498 | Train Dice: 0.7310 | Val Dice: 0.7035
# Fold 10 | Epoch 41/100 | Train Loss: 0.6617 | Val Loss: 0.7034 | Train Acc: 0.9536 | Val Acc: 0.9461 | Train Dice: 0.7316 | Val Dice: 0.7102
# Fold 10 | Epoch 42/100 | Train Loss: 0.6598 | Val Loss: 0.6984 | Train Acc: 0.9559 | Val Acc: 0.9487 | Train Dice: 0.7335 | Val Dice: 0.7129
# Fold 10 | Epoch 43/100 | Train Loss: 0.6497 | Val Loss: 0.6950 | Train Acc: 0.9542 | Val Acc: 0.9503 | Train Dice: 0.7404 | Val Dice: 0.7140
# Fold 10 | Epoch 44/100 | Train Loss: 0.6547 | Val Loss: 0.7053 | Train Acc: 0.9561 | Val Acc: 0.9447 | Train Dice: 0.7356 | Val Dice: 0.7101
# Fold 10 | Epoch 45/100 | Train Loss: 0.6436 | Val Loss: 0.6961 | Train Acc: 0.9550 | Val Acc: 0.9507 | Train Dice: 0.7436 | Val Dice: 0.7128
# Fold 10 | Epoch 46/100 | Train Loss: 0.6374 | Val Loss: 0.6996 | Train Acc: 0.9570 | Val Acc: 0.9468 | Train Dice: 0.7472 | Val Dice: 0.7129
# Fold 10 | Epoch 47/100 | Train Loss: 0.6318 | Val Loss: 0.7079 | Train Acc: 0.9574 | Val Acc: 0.9511 | Train Dice: 0.7506 | Val Dice: 0.6944
# Fold 10 | Epoch 48/100 | Train Loss: 0.6430 | Val Loss: 0.6911 | Train Acc: 0.9564 | Val Acc: 0.9508 | Train Dice: 0.7418 | Val Dice: 0.7129
# Fold 10 | Epoch 49/100 | Train Loss: 0.6305 | Val Loss: 0.6981 | Train Acc: 0.9583 | Val Acc: 0.9462 | Train Dice: 0.7503 | Val Dice: 0.7130
# Fold 10 | Epoch 50/100 | Train Loss: 0.6348 | Val Loss: 0.6849 | Train Acc: 0.9565 | Val Acc: 0.9503 | Train Dice: 0.7480 | Val Dice: 0.7176
# Fold 10 | Epoch 51/100 | Train Loss: 0.6405 | Val Loss: 0.6902 | Train Acc: 0.9562 | Val Acc: 0.9523 | Train Dice: 0.7437 | Val Dice: 0.7112
# Fold 10 | Epoch 52/100 | Train Loss: 0.6343 | Val Loss: 0.6769 | Train Acc: 0.9575 | Val Acc: 0.9512 | Train Dice: 0.7467 | Val Dice: 0.7256
# Fold 10 | Epoch 53/100 | Train Loss: 0.6406 | Val Loss: 0.6786 | Train Acc: 0.9568 | Val Acc: 0.9505 | Train Dice: 0.7418 | Val Dice: 0.7221
# Fold 10 | Epoch 54/100 | Train Loss: 0.6240 | Val Loss: 0.6918 | Train Acc: 0.9579 | Val Acc: 0.9519 | Train Dice: 0.7547 | Val Dice: 0.7072
# Fold 10 | Epoch 55/100 | Train Loss: 0.6214 | Val Loss: 0.6809 | Train Acc: 0.9593 | Val Acc: 0.9511 | Train Dice: 0.7557 | Val Dice: 0.7220
# Fold 10 | Epoch 56/100 | Train Loss: 0.6183 | Val Loss: 0.6761 | Train Acc: 0.9593 | Val Acc: 0.9537 | Train Dice: 0.7559 | Val Dice: 0.7194
# Fold 10 | Epoch 57/100 | Train Loss: 0.6201 | Val Loss: 0.7077 | Train Acc: 0.9581 | Val Acc: 0.9519 | Train Dice: 0.7572 | Val Dice: 0.6920
# Fold 10 | Epoch 58/100 | Train Loss: 0.6246 | Val Loss: 0.6904 | Train Acc: 0.9579 | Val Acc: 0.9474 | Train Dice: 0.7542 | Val Dice: 0.7173
# Fold 10 | Epoch 59/100 | Train Loss: 0.6262 | Val Loss: 0.6900 | Train Acc: 0.9589 | Val Acc: 0.9482 | Train Dice: 0.7513 | Val Dice: 0.7193
# Fold 10 | Epoch 60/100 | Train Loss: 0.6251 | Val Loss: 0.6843 | Train Acc: 0.9575 | Val Acc: 0.9533 | Train Dice: 0.7569 | Val Dice: 0.7153
# Fold 10 | Epoch 61/100 | Train Loss: 0.6173 | Val Loss: 0.6848 | Train Acc: 0.9595 | Val Acc: 0.9484 | Train Dice: 0.7578 | Val Dice: 0.7218
# Fold 10 | Epoch 62/100 | Train Loss: 0.6125 | Val Loss: 0.6842 | Train Acc: 0.9604 | Val Acc: 0.9505 | Train Dice: 0.7604 | Val Dice: 0.7195
# Fold 10 | Epoch 63/100 | Train Loss: 0.6139 | Val Loss: 0.6817 | Train Acc: 0.9585 | Val Acc: 0.9521 | Train Dice: 0.7627 | Val Dice: 0.7176
# Fold 10 | Epoch 64/100 | Train Loss: 0.6110 | Val Loss: 0.6816 | Train Acc: 0.9602 | Val Acc: 0.9494 | Train Dice: 0.7633 | Val Dice: 0.7241
# Fold 10 | Epoch 65/100 | Train Loss: 0.6090 | Val Loss: 0.6736 | Train Acc: 0.9602 | Val Acc: 0.9520 | Train Dice: 0.7630 | Val Dice: 0.7244
# Fold 10 | Epoch 66/100 | Train Loss: 0.6028 | Val Loss: 0.6849 | Train Acc: 0.9607 | Val Acc: 0.9512 | Train Dice: 0.7671 | Val Dice: 0.7171
# Fold 10 | Epoch 67/100 | Train Loss: 0.6077 | Val Loss: 0.6684 | Train Acc: 0.9602 | Val Acc: 0.9537 | Train Dice: 0.7634 | Val Dice: 0.7242
# Fold 10 | Epoch 68/100 | Train Loss: 0.6096 | Val Loss: 0.6720 | Train Acc: 0.9602 | Val Acc: 0.9514 | Train Dice: 0.7628 | Val Dice: 0.7282
# Fold 10 | Epoch 69/100 | Train Loss: 0.6036 | Val Loss: 0.6648 | Train Acc: 0.9608 | Val Acc: 0.9528 | Train Dice: 0.7661 | Val Dice: 0.7287
# Fold 10 | Epoch 70/100 | Train Loss: 0.6051 | Val Loss: 0.6688 | Train Acc: 0.9604 | Val Acc: 0.9519 | Train Dice: 0.7680 | Val Dice: 0.7261
# Fold 10 | Epoch 71/100 | Train Loss: 0.6007 | Val Loss: 0.6654 | Train Acc: 0.9606 | Val Acc: 0.9532 | Train Dice: 0.7686 | Val Dice: 0.7273
# Fold 10 | Epoch 72/100 | Train Loss: 0.5981 | Val Loss: 0.6646 | Train Acc: 0.9614 | Val Acc: 0.9530 | Train Dice: 0.7699 | Val Dice: 0.7273
# Fold 10 | Epoch 73/100 | Train Loss: 0.6085 | Val Loss: 0.6709 | Train Acc: 0.9600 | Val Acc: 0.9524 | Train Dice: 0.7630 | Val Dice: 0.7238
# Fold 10 | Epoch 74/100 | Train Loss: 0.5989 | Val Loss: 0.6613 | Train Acc: 0.9614 | Val Acc: 0.9536 | Train Dice: 0.7700 | Val Dice: 0.7309
# Fold 10 | Epoch 75/100 | Train Loss: 0.5920 | Val Loss: 0.6708 | Train Acc: 0.9621 | Val Acc: 0.9533 | Train Dice: 0.7740 | Val Dice: 0.7234
# Fold 10 | Epoch 76/100 | Train Loss: 0.5968 | Val Loss: 0.6670 | Train Acc: 0.9611 | Val Acc: 0.9543 | Train Dice: 0.7705 | Val Dice: 0.7233
# Fold 10 | Epoch 77/100 | Train Loss: 0.5962 | Val Loss: 0.6611 | Train Acc: 0.9616 | Val Acc: 0.9530 | Train Dice: 0.7696 | Val Dice: 0.7320
# Fold 10 | Epoch 78/100 | Train Loss: 0.5982 | Val Loss: 0.6658 | Train Acc: 0.9610 | Val Acc: 0.9512 | Train Dice: 0.7696 | Val Dice: 0.7310
# Fold 10 | Epoch 79/100 | Train Loss: 0.5893 | Val Loss: 0.6585 | Train Acc: 0.9623 | Val Acc: 0.9539 | Train Dice: 0.7747 | Val Dice: 0.7331
# Fold 10 | Epoch 80/100 | Train Loss: 0.5869 | Val Loss: 0.6636 | Train Acc: 0.9627 | Val Acc: 0.9532 | Train Dice: 0.7767 | Val Dice: 0.7290
# Fold 10 | Epoch 81/100 | Train Loss: 0.5858 | Val Loss: 0.6609 | Train Acc: 0.9624 | Val Acc: 0.9531 | Train Dice: 0.7770 | Val Dice: 0.7305
# Fold 10 | Epoch 82/100 | Train Loss: 0.5897 | Val Loss: 0.6596 | Train Acc: 0.9617 | Val Acc: 0.9536 | Train Dice: 0.7738 | Val Dice: 0.7311
# Fold 10 | Epoch 83/100 | Train Loss: 0.5894 | Val Loss: 0.6639 | Train Acc: 0.9621 | Val Acc: 0.9523 | Train Dice: 0.7751 | Val Dice: 0.7321
# Fold 10 | Epoch 84/100 | Train Loss: 0.5800 | Val Loss: 0.6709 | Train Acc: 0.9638 | Val Acc: 0.9497 | Train Dice: 0.7817 | Val Dice: 0.7300
# Fold 10 | Epoch 85/100 | Train Loss: 0.5868 | Val Loss: 0.6573 | Train Acc: 0.9621 | Val Acc: 0.9539 | Train Dice: 0.7756 | Val Dice: 0.7325
# Fold 10 | Epoch 86/100 | Train Loss: 0.5847 | Val Loss: 0.6597 | Train Acc: 0.9622 | Val Acc: 0.9524 | Train Dice: 0.7780 | Val Dice: 0.7320
# Fold 10 | Epoch 87/100 | Train Loss: 0.6013 | Val Loss: 0.6503 | Train Acc: 0.9607 | Val Acc: 0.9537 | Train Dice: 0.7678 | Val Dice: 0.7394
# Fold 10 | Epoch 88/100 | Train Loss: 0.5911 | Val Loss: 0.6606 | Train Acc: 0.9614 | Val Acc: 0.9545 | Train Dice: 0.7756 | Val Dice: 0.7283
# Fold 10 | Epoch 89/100 | Train Loss: 0.5871 | Val Loss: 0.6544 | Train Acc: 0.9620 | Val Acc: 0.9531 | Train Dice: 0.7766 | Val Dice: 0.7341
# Fold 10 | Epoch 90/100 | Train Loss: 0.5858 | Val Loss: 0.6568 | Train Acc: 0.9620 | Val Acc: 0.9532 | Train Dice: 0.7791 | Val Dice: 0.7372
# Fold 10 | Epoch 91/100 | Train Loss: 0.5736 | Val Loss: 0.6581 | Train Acc: 0.9641 | Val Acc: 0.9529 | Train Dice: 0.7852 | Val Dice: 0.7356
# Fold 10 | Epoch 92/100 | Train Loss: 0.5790 | Val Loss: 0.6583 | Train Acc: 0.9630 | Val Acc: 0.9548 | Train Dice: 0.7823 | Val Dice: 0.7292
# Fold 10 | Epoch 93/100 | Train Loss: 0.5760 | Val Loss: 0.6561 | Train Acc: 0.9634 | Val Acc: 0.9553 | Train Dice: 0.7832 | Val Dice: 0.7268
# Fold 10 | Epoch 94/100 | Train Loss: 0.5874 | Val Loss: 0.6578 | Train Acc: 0.9620 | Val Acc: 0.9522 | Train Dice: 0.7763 | Val Dice: 0.7353
# Fold 10 | Epoch 95/100 | Train Loss: 0.5815 | Val Loss: 0.6772 | Train Acc: 0.9628 | Val Acc: 0.9480 | Train Dice: 0.7781 | Val Dice: 0.7281
# Fold 10 | Epoch 96/100 | Train Loss: 0.5924 | Val Loss: 0.6528 | Train Acc: 0.9621 | Val Acc: 0.9530 | Train Dice: 0.7722 | Val Dice: 0.7397
# Fold 10 | Epoch 97/100 | Train Loss: 0.5838 | Val Loss: 0.6605 | Train Acc: 0.9613 | Val Acc: 0.9554 | Train Dice: 0.7778 | Val Dice: 0.7255
# Fold 10 | Epoch 98/100 | Train Loss: 0.5915 | Val Loss: 0.6597 | Train Acc: 0.9615 | Val Acc: 0.9518 | Train Dice: 0.7740 | Val Dice: 0.7356
# Fold 10 | Epoch 99/100 | Train Loss: 0.5882 | Val Loss: 0.6460 | Train Acc: 0.9624 | Val Acc: 0.9551 | Train Dice: 0.7767 | Val Dice: 0.7410
# Fold 10 | Epoch 100/100 | Train Loss: 0.5774 | Val Loss: 0.6598 | Train Acc: 0.9626 | Val Acc: 0.9545 | Train Dice: 0.7837 | Val Dice: 0.7238

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# === FINAL EVALUATION ===
final_metrics = evaluate_test(model, val_loader, device)


fold_results.append({
    "metrics": final_metrics,
    "history": history
})

# %%
save_path_bobot = os.path.join(
    save_dir,
    f"DRIVE_model_bobot_ResASPPUnet_paper_nopre_fold{fold+1}.pth"
)

torch.save({
    'model_state_dict': model.state_dict(),
    'metrics': final_metrics,
    'history': history
}, save_path_bobot)

print(f"✅ Model + history fold {fold+1} disimpan di:")
print(save_path_bobot)
# Out:
# ✅ Model + history fold 10 disimpan di:
# /content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_bobot_ResASPPUnet_paper_nopre_fold10.pth

# %%
model = ResASPP_UNet()
path = "/content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_bobot_ResASPPUnet_paper_nopre_fold10.pth"
checkpoint = torch.load(path, map_location=device)

model.load_state_dict(checkpoint['model_state_dict'])

model.to(device)
model.eval()

# optional
print(checkpoint['metrics'])
# Out:
# {'loss': 0.659763753414154, 'Accuracy': 0.9545230865460309, 'Sensitivity': 0.682011656065265, 'Specificity': 0.9806154971503618, 'Dice': 0.7238460779190063, 'IoU': 0.5673718452453613}

# %%
import matplotlib.pyplot as plt

def plot_history(history):
    plt.figure(figsize=(18, 5))


    # Plot Loss
    plt.subplot(1,3,1)
    plt.plot(history['train_loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Val Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Plot Accuracy
    plt.subplot(1,3,2)
    plt.plot(history['train_acc'], label='Train Accuracy')
    plt.plot(history['val_acc'], label='Val Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Dice Score
    plt.subplot(1, 3, 3)
    plt.plot(history['train_dice'], label='Train Dice', color='blue')
    plt.plot(history['val_dice'], label='Val Dice', color='orange')
    plt.title('Dice Score per Epoch')
    plt.xlabel('Epoch')
    plt.ylabel('Dice')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# %%
save_path = '/content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_ab_ResASPPUnet_paper_nopre.pth'
torch.save(model, save_path)

print(f"Model disimpan di: {save_path}")
# Out:
# Model disimpan di: /content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_ab_ResASPPUnet_paper_nopre.pth

# %%
save_path_bobot = "/content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_bobot_ResASPPUnet_paper_nopre.pth"
torch.save(model.state_dict(), save_path_bobot)
print("Saved to:", save_path_bobot)
# Out:
# Saved to: /content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_bobot_ResASPPUnet_paper_nopre.pth

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Pastikan cell definisi class ResASPPUNet sudah dijalankan sebelumnya
with torch.serialization.safe_globals([ResASPP_UNet]):
    model = torch.load("/content/drive/MyDrive/Colab Notebooks/DRIVE/DRIVE_model_ab_ResASPPUnet_paper_nopre.pth",
                       map_location=device, weights_only=False)

model.eval()
print("✅ Model berhasil dimuat tanpa file .py terpisah.")
# Out:
# ✅ Model berhasil dimuat tanpa file .py terpisah.

# %%
# Make sure the cell defining plot_history is run before this cell.
plot_history(history)

# %%
#Visualisasi Prediksi
def visualize_prediction(model, dataset, index=0, device='cuda'): # Add device as an argument with default 'cuda'
    model.eval()
    image, true_mask = dataset[index]
    image_input = image.unsqueeze(0).to(device)

    with torch.no_grad():
        pred_mask = model(image_input)
        pred_mask = (pred_mask.squeeze().cpu().numpy() > 0.5).astype(float)

    image_np = image.permute(1, 2, 0).numpy()
    true_mask_np = true_mask.squeeze().numpy()

    plt.figure(figsize=(12, 4))

    plt.subplot(1, 3, 1)
    plt.imshow(image_np)
    plt.title("Input Image")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(true_mask_np, cmap='gray')
    plt.title("Ground Truth Mask")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask, cmap='gray')
    plt.title("Predicted Mask")
    plt.axis("off")

    plt.tight_layout()
    plt.show()

# %%
visualize_prediction(model, val_dataset, index=0)

# %%
print(len(test_dataset.image_paths))
print(len(test_dataset.mask_paths))
# Out:
# 20
# 20

# %%
visualize_prediction(model, test_dataset, index=0)

# %%
def visualize_prediction(model, dataset, index=0):
    import torch
    import matplotlib.pyplot as plt

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()

    img, mask = dataset[index]  # img: (C,H,W)

    img_tensor = img.unsqueeze(0).to(device)  # pindah ke GPU

    with torch.no_grad():
        pred = model(img_tensor)

    pred = pred.squeeze().cpu().numpy()  # balik ke CPU untuk numpy
    img_np = img.permute(1,2,0).cpu().numpy()
    mask_np = mask.squeeze().cpu().numpy()

    plt.figure(figsize=(12,4))

    plt.subplot(1,3,1)
    plt.title("Input Image")
    plt.imshow(img_np)

    plt.subplot(1,3,2)
    plt.title("Ground Truth")
    plt.imshow(mask_np, cmap='gray')

    plt.subplot(1,3,3)
    plt.title("Prediction")
    plt.imshow(pred > 0.5, cmap='gray')

    plt.show()

# %%
visualize_prediction(model, val_dataset, index=0)

# %%
import numpy as np

# Process fold_results to get a consistent list of metric dictionaries for averaging
processed_metrics = []
for fold_res in fold_results:
    if isinstance(fold_res, dict) and "metrics" in fold_res and isinstance(fold_res["metrics"], dict):
        processed_metrics.append(fold_res["metrics"])
    elif isinstance(fold_res, dict) and "loss" in fold_res: # Assuming 'loss' is a key present in direct metric dicts
        processed_metrics.append(fold_res)


print("\n=== CROSS VALIDATION RESULT ===")
if not processed_metrics:
    print("No valid metric dictionaries found in fold_results to average.")
else:
    # Use the keys from the first processed metric dictionary for averaging
    # This assumes all metric dictionaries have the same set of keys
    avg_results = {
        k: np.mean([res[k] for res in processed_metrics])
        for k in processed_metrics[0]
    }

    for k, v in avg_results.items():
        print(f"{k}: {v:.4f}")
# Out:
# === CROSS VALIDATION RESULT ===
# loss: 0.6598
# Accuracy: 0.9545
# Sensitivity: 0.6820
# Specificity: 0.9806
# Dice: 0.7238
# IoU: 0.5674
